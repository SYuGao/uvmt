# %%
import sys
sys.path.append('C:\\projects\\UTNCE\\src\\utnce202402')

# %%
from simplify import *
from prepare import *
from routing import *
from percolation_plot import *
from generate import *
from transfer import *
from copy import deepcopy
from shapely.geometry import Point
from pyproj import Proj, Transformer

# %%
osm_path = "C:\\projects\\UTNCE\\data\\Amsterdam.large.pbf"

# %% [markdown]
# # Subway-single network

# %% [markdown]
# ## Generate Baseline network

# %%
# Obtain sub-stations in the city
city_sub_stations = sub_stations(osm_path)

# %%
# Obtain subway network data
city_sub_network = subway_network(osm_path)

# Prepare the network edges and nodes based on sub-stations and subway network
edges, nodes = prepare_network(city_sub_network, city_sub_stations)

# Expand the edges if required
edges = expand_edges(edges)

# Obtain sub-routes in the city
city_sub_routes = sub_routes(osm_path)

# Sort the sub-routes
city_sub_routes = sorted_routes(city_sub_routes)

# Check the name and assign a column
check_name = check_to_column(city_sub_routes, city_sub_stations)
# Out:
# endpoints: 100%|██████████████████████████████████████████████████████████████████| 711/711 [00:00<00:00, 31989.77it/s]
# endpoints: 100%|██████████████████████████████████████████████████████████████████| 962/962 [00:00<00:00, 43230.06it/s]
# topology: 100%|████████████████████████████████████████████████████████████████████| 962/962 [00:00<00:00, 8446.08it/s]

# %%
# delete 3 pairs useless and wrong edges 
edges.drop(edges[(edges['from_id'] == 771) & (edges['to_id'] == 761)].index, inplace=True)
edges.drop(edges[(edges['from_id'] == 771) & (edges['to_id'] == 766)].index, inplace=True)
edges.drop(edges[(edges['from_id'] == 762) & (edges['to_id'] == 771)].index, inplace=True)
edges.drop(edges[(edges['from_id'] == 767) & (edges['to_id'] == 771)].index, inplace=True)

edges.drop(edges[(edges['from_id'] == 780) & (edges['to_id'] == 773)].index, inplace=True)
edges.drop(edges[(edges['from_id'] == 780) & (edges['to_id'] == 772)].index, inplace=True)
edges.drop(edges[(edges['from_id'] == 774) & (edges['to_id'] == 780)].index, inplace=True)
edges.drop(edges[(edges['from_id'] == 775) & (edges['to_id'] == 780)].index, inplace=True)

edges.drop(edges[(edges['from_id'] == 180) & (edges['to_id'] == 345)].index, inplace=True)

# %%
city_sub_stations[city_sub_stations.name == 'Zuid']
# Out:
#           osm_id public_transport railway  tram subway highway   bus  name  \
# 134    250222259    stop_position    stop  None    yes    None  None  Zuid
# 1882  4073737796    stop_position    stop  None    yes    None  None  Zuid
# 1883  4073737797    stop_position    stop  None    yes    None  None  Zuid
# 1884  4073737798    stop_position    stop  None    yes    None  None  Zuid
#
#                       geometry     geo_x      geo_y
# 134   POINT (4.87398 52.33904)  4.873978  52.339035
# 1882  POINT (4.87436 52.33916)  4.874360  52.339156
# 1883  POINT (4.87434 52.33921)  4.874338  52.339214
# 1884  POINT (4.87396 52.33932)  4.873963  52.339322

# %%
# revise Zuid metro stations' coordinates, replace 712 with 180 and 345 nodes to avoid wrong shortest-path edges
geometry_value1 = nodes.loc[nodes['id'] == 180, 'geometry'].values[0]
geometry_value2 = nodes.loc[nodes['id'] == 345, 'geometry'].values[0]

city_sub_stations.loc[city_sub_stations['osm_id'] == '4073737797', 'geometry'] = geometry_value1
city_sub_stations.loc[city_sub_stations['osm_id'] == '4073737797', 'geo_x'] = geometry_value1.x
city_sub_stations.loc[city_sub_stations['osm_id'] == '4073737797', 'geo_y'] = geometry_value1.y

city_sub_stations.loc[city_sub_stations['osm_id'] == '4073737796', 'geometry'] = geometry_value2
city_sub_stations.loc[city_sub_stations['osm_id'] == '4073737796', 'geo_x'] = geometry_value2.x
city_sub_stations.loc[city_sub_stations['osm_id'] == '4073737796', 'geo_y'] = geometry_value2.y

# %%
edges
# Out:
#          osm_id                                           geometry railway  \
# 0      23157994  LINESTRING (4.9236699 52.3361909, 4.9236979 52...  subway
# 1      23158053  LINESTRING (4.9642294 52.2945339, 4.9644259 52...  subway
# 2      23158054  LINESTRING (4.9622901 52.2955678, 4.9624673 52...  subway
# 3      23189033  LINESTRING (4.8467318 52.3952137, 4.8471439 52...  subway
# 4      23189039  LINESTRING (4.8409161 52.3937679, 4.8416087 52...  subway
# ..          ...                                                ...     ...
# 957  1131538381  LINESTRING (4.9200955 52.3417374, 4.9200444 52...  subway
# 958  1131538382  LINESTRING (4.9201445 52.3416568, 4.9200955 52...  subway
# 959  1131538383  LINESTRING (4.9200365 52.3417239, 4.9200773 52...  subway
# 960  1131538384  LINESTRING (4.9197172 52.3423576, 4.9197589 52...  subway
# 961  1131538385  LINESTRING (4.9194179 52.3424458, 4.919254 52....  subway
#
#     service   id  from_id  to_id    distance      time  weights     to_from  \
# 0      None    0        0      1  258.660599  0.010346      258      (0, 1)
# 1      None    1        2      3  215.433271  0.008617      215      (2, 3)
# 2      None    2        4      5  121.794737  0.004872      121      (4, 5)
# 3      None    3        6      7   28.046592  0.001122       28      (6, 7)
# 4      None    4        8    492  382.935219  0.015317      382    (8, 492)
# ..      ...  ...      ...    ...         ...       ...      ...         ...
# 957    None  957      803    463   73.656989  0.002946       73  (803, 463)
# 958    None  958      462    803    9.568427  0.000383        9  (462, 803)
# 959    None  959      804    246    9.568874  0.000383        9  (804, 246)
# 960    None  960      463    804   73.789113  0.002952       73  (463, 804)
# 961    None  961      249    256   40.444210  0.001618       40  (249, 256)
#
#         from_to
# 0        (1, 0)
# 1        (3, 2)
# 2        (5, 4)
# 3        (7, 6)
# 4      (492, 8)
# ..          ...
# 957  (463, 803)
# 958  (803, 462)
# 959  (246, 804)
# 960  (804, 463)
# 961  (256, 249)
#
# [953 rows x 12 columns]

# %%
gpd.GeoDataFrame(edges[['osm_id', 'geometry', 'id', 'from_id', 'to_id', 'distance', 'time', 'weights']]).to_file('sub_edges_0304.GPKG',driver='GPKG')
gpd.GeoDataFrame(city_sub_stations[['osm_id', 'geometry','name']]).to_file('city_sub_stations_0304.GPKG',driver='GPKG')

# %%
replacement_dict = {
     'Amsterdam Centraal': 'Centraal Station',
}

# %%
# Replace values in the 'to' column of the metro routes using the replacement dictionary
city_sub_routes['to'] = city_sub_routes['to'].replace(replacement_dict, regex=True).str.strip()

# Reset the index of the metro routes
city_sub_routes = city_sub_routes.reset_index(drop=True)

# Check if the values in the 'to' column of the metro routes match the station names
check_name = check_to_column(city_sub_routes, city_sub_stations)

# %%
# Create a dictionary mapping start stations to their corresponding routes
city_sub_start_station_name_dict = start_station_dict(city_sub_routes)

# Create a dictionary mapping subway lines to their corresponding routes
city_sub_line_dict = line_dict(city_sub_routes)

# Create a list of all station names in the city's subway network
city_all_sub_stations_name = all_station_list(city_sub_stations)

# Create a dictionary mapping subway lines to the ordered list of stations on each line
city_sub_order_route_dict = order_stations_inline(city_sub_line_dict, city_all_sub_stations_name, city_sub_routes, city_sub_start_station_name_dict)

# %%
# revise station sequence of 51_1 route
df51_1 = pd.read_excel('C:\\projects\\UTNCE\\data\\Metro 51 Centraal Station = Isolatorweg.xlsx',header=None)
df51_1 = df51_1[0::4].reset_index(drop=True)
df51_1.columns = ['name']
df51_1.name[9] = 'Zuid' 
df51_1.name[13] = 'Lelylaan' 
df51_1.name[16] = 'De Vlugtlaan' 

df = city_sub_order_route_dict['Metro 51: Centraal Station => Isolatorweg']
df_reordered = pd.merge(df51_1,df,on='name')

desired_order = ['id', 'name', 'geometry', 'geo_x', 'geo_y']
df_reordered = df_reordered[desired_order]

key_to_replace = 'Metro 51: Centraal Station => Isolatorweg'
city_sub_order_route_dict[key_to_replace] = df_reordered

# city_sub_order_route_dict

# %%
# Create a dictionary mapping subway lines to the pairs of station IDs on each line
city_sub_order_id_pairs = id_pairs_inline(city_sub_line_dict, city_sub_order_route_dict, nodes)

# %%
# revise order_id_pairs of 52 routes--De pijp station where two nodes are too close
df_order_id_52_1 = city_sub_order_id_pairs['Metro 52: Noord => Zuid']
df_order_id_52_1
df_order_id_52_1.e_id[4] = 863
df_order_id_52_1.s_id[5] = 863

df_order_id_52_2 = city_sub_order_id_pairs['Metro 52: Zuid => Noord']
df_order_id_52_2
df_order_id_52_2.s_id[2] = 864
df_order_id_52_2.e_id[1] = 864

# %%
# Create a graph representing the subway network using the extracted edges and nodes
G = create_ground_graph(edges, nodes)

# Calculate the shortest path pairs for each subway line
city_sub_shortest_path_pairs = city_sub_order_id_pairs.copy()
duplicate_row_count = city_sub_order_id_pairs.copy()
city_sub_shortest_path_edges = city_sub_order_id_pairs.copy()
city_sub_edges = city_sub_order_id_pairs.copy()

for line in city_sub_order_id_pairs.keys():
    # Calculate all shortest paths for the current line using the subway network edges
    city_sub_shortest_path_pairs[line] = all_shortest_paths(G, city_sub_order_id_pairs[line], edges)

    # Count the duplicate rows, calculate the weighted edges for shortest paths,
    # and update the subway network edges for the current line
    duplicate_row_count[line], city_sub_shortest_path_edges[line], city_sub_edges[line] = edges_with_count_weight(city_sub_shortest_path_pairs[line], edges)
    sub_edges = city_sub_edges[line]

# # Plot the subway routes with even indices
# plot_routes_even(city_sub_routes, edges, city_sub_shortest_path_edges)

# # Plot the subway routes with odd indices
# plot_routes_odd(city_sub_routes, edges, city_sub_shortest_path_edges)
    
# Plot all subway routes
plot_routes(city_sub_routes, edges, city_sub_shortest_path_edges)

# %%
df51_1 = city_sub_shortest_path_edges['Metro 50: Gein => Isolatorweg']
df51_2 = city_sub_shortest_path_edges['Metro 50: Isolatorweg => Gein']

df52_1 = city_sub_shortest_path_edges['Metro 52: Noord => Zuid'] 
df52_2 = city_sub_shortest_path_edges['Metro 52: Zuid => Noord']

df53_1 = city_sub_shortest_path_edges['Metro 53: Centraal Station => Gaasperplas']
df53_2 = city_sub_shortest_path_edges['Metro 53: Gaasperplas => Centraal Station']

df54_1 = city_sub_shortest_path_edges['Metro 54: Centraal Station => Gein']
df54_2 = city_sub_shortest_path_edges['Metro 54: Gein => Centraal Station']

# %%
gpd.GeoDataFrame(df51_1[['osm_id', 'geometry','id']]).to_file('df51_1_0304.GPKG',driver='GPKG')
gpd.GeoDataFrame(df51_2[['osm_id', 'geometry','id']]).to_file('df51_2_0304.GPKG',driver='GPKG')
gpd.GeoDataFrame(df52_1[['osm_id', 'geometry','id']]).to_file('df52_1_0304.GPKG',driver='GPKG')
gpd.GeoDataFrame(df52_2[['osm_id', 'geometry','id']]).to_file('df52_2_0304.GPKG',driver='GPKG')
gpd.GeoDataFrame(df53_1[['osm_id', 'geometry','id']]).to_file('df53_1_0304.GPKG',driver='GPKG')
gpd.GeoDataFrame(df53_2[['osm_id', 'geometry','id']]).to_file('df53_2_0304.GPKG',driver='GPKG')
gpd.GeoDataFrame(df54_1[['osm_id', 'geometry','id']]).to_file('df54_1_0304.GPKG',driver='GPKG')
gpd.GeoDataFrame(df54_2[['osm_id', 'geometry','id']]).to_file('df54_2_0304.GPKG',driver='GPKG')

# %% [markdown]
# ## Add columns to stations

# %%
city_sub_order_route_dict = add_ref_to_orderroutes_or_shortestpath_dict(city_sub_order_route_dict, city_sub_routes)

# %%
city_sub_new_nodes = add_columns_to_nodes(city_sub_order_route_dict, nodes)

# %%
city_sub_new_nodes
# Out:
#                     geometry  degree   id                 name     geo_x  \
# 0   POINT (4.98916 52.29641)       2  328                 Gein  4.989161
# 1   POINT (4.97400 52.29564)       2  855           Reigersbos  4.974000
# 2   POINT (4.96013 52.29813)       2  854          Holendrecht  4.960126
# 3   POINT (4.95213 52.30687)       2  810            Bullewijk  4.952129
# 4   POINT (4.94762 52.31181)       2  809        Bijlmer ArenA  4.947618
# ..                       ...     ...  ...                  ...       ...
# 82  POINT (4.96734 52.32837)       2  824    Verrijn Stuartweg  4.967335
# 83  POINT (4.95669 52.33041)       2  823  Station Diemen Zuid  4.956688
# 84  POINT (4.94628 52.32683)       2  829         Venserpolder  4.946277
# 85  POINT (4.93028 52.32974)       2  827      Van der Madeweg  4.930285
# 86  POINT (4.92105 52.34029)       2  833           Spaklerweg  4.921045
#
#         geo_y         coordinate_value  \
# 0   52.296407  (4.9891612, 52.2964067)
# 1   52.295637  (4.9740002, 52.2956365)
# 2   52.298132  (4.9601264, 52.2981319)
# 3   52.306869   (4.9521292, 52.306869)
# 4   52.311806   (4.9476178, 52.311806)
# ..        ...                      ...
# 82  52.328367  (4.9673352, 52.3283668)
# 83  52.330406  (4.9566878, 52.3304057)
# 84  52.326833  (4.9462773, 52.3268326)
# 85  52.329735  (4.9302846, 52.3297352)
# 86  52.340287  (4.9210454, 52.3402871)
#
#                               route_name_list   route         ref    transfer
# 0               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# 1               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# 2               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# 3               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# 4               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# ..                                        ...     ...         ...         ...
# 82  Metro 53: Gaasperplas => Centraal Station  subway          53        None
# 83  Metro 53: Gaasperplas => Centraal Station  subway          53        None
# 84  Metro 53: Gaasperplas => Centraal Station  subway          53        None
# 85  Metro 53: Gaasperplas => Centraal Station  subway  50, 53, 54  50, 53, 54
# 86  Metro 53: Gaasperplas => Centraal Station  subway  51, 53, 54  51, 53, 54
#
# [87 rows x 11 columns]

# %% [markdown]
# ## Add columns to edges

# %%
city_sub_shortest_path_edges = add_ref_to_orderroutes_or_shortestpath_dict(city_sub_shortest_path_edges, city_sub_routes)

# %%
city_sub_new_edges = add_columns_to_edges(city_sub_shortest_path_edges,edges)

# %%
column_to_drop = 'count_weight'
city_sub_new_edges = city_sub_new_edges.drop(columns=column_to_drop)

# %%
city_sub_new_edges
# Out:
#          osm_id                                           geometry railway  \
# 0      23157994  LINESTRING (4.9236699 52.3361909, 4.9236979 52...  subway
# 1      23158053  LINESTRING (4.9642294 52.2945339, 4.9644259 52...  subway
# 2      23158054  LINESTRING (4.9622901 52.2955678, 4.9624673 52...  subway
# 3      23189033  LINESTRING (4.8467318 52.3952137, 4.8471439 52...  subway
# 4      23189039  LINESTRING (4.8409161 52.3937679, 4.8416087 52...  subway
# ..          ...                                                ...     ...
# 948  1131538381  LINESTRING (4.9200955 52.3417374, 4.9200444 52...  subway
# 949  1131538382  LINESTRING (4.9201445 52.3416568, 4.9200955 52...  subway
# 950  1131538383  LINESTRING (4.9200365 52.3417239, 4.9200773 52...  subway
# 951  1131538384  LINESTRING (4.9197172 52.3423576, 4.9197589 52...  subway
# 952  1131538385  LINESTRING (4.9194179 52.3424458, 4.919254 52....  subway
#
#     service   id  from_id  to_id    distance      time  weights     to_from  \
# 0      None    0        0      1  258.660599  0.010346      258      (0, 1)
# 1      None    1        2      3  215.433271  0.008617      215      (2, 3)
# 2      None    2        4      5  121.794737  0.004872      121      (4, 5)
# 3      None    3        6      7   28.046592  0.001122       28      (6, 7)
# 4      None    4        8    492  382.935219  0.015317      382    (8, 492)
# ..      ...  ...      ...    ...         ...       ...      ...         ...
# 948    None  957      803    463   73.656989  0.002946       73  (803, 463)
# 949    None  958      462    803    9.568427  0.000383        9  (462, 803)
# 950    None  959      804    246    9.568874  0.000383        9  (804, 246)
# 951    None  960      463    804   73.789113  0.002952       73  (463, 804)
# 952    None  961      249    256   40.444210  0.001618       40  (249, 256)
#
#         from_to                            route_name_list   route         ref
# 0        (1, 0)  Metro 51: Isolatorweg => Centraal Station  subway          51
# 1        (3, 2)              Metro 50: Isolatorweg => Gein  subway      50, 54
# 2        (5, 4)              Metro 50: Isolatorweg => Gein  subway      50, 54
# 3        (7, 6)                                        NaN     NaN         NaN
# 4      (492, 8)              Metro 50: Isolatorweg => Gein  subway      50, 51
# ..          ...                                        ...     ...         ...
# 948  (463, 803)  Metro 53: Gaasperplas => Centraal Station  subway      53, 54
# 949  (803, 462)  Metro 53: Gaasperplas => Centraal Station  subway      53, 54
# 950  (246, 804)  Metro 51: Isolatorweg => Centraal Station  subway          51
# 951  (804, 463)  Metro 51: Isolatorweg => Centraal Station  subway          51
# 952  (256, 249)  Metro 51: Centraal Station => Isolatorweg  subway  51, 53, 54
#
# [953 rows x 15 columns]

# %% [markdown]
# # Create original points dataframe and OD pair list

# %%
origin_df = pd.DataFrame()
each_o_point = pd.DataFrame()
for route_name, station_df in city_sub_order_route_dict.items():
    each_o_point = station_df.loc[[0]]
    origin_df = pd.concat([origin_df,each_o_point])
origin_df.drop_duplicates(subset='geometry', inplace=True)
selected_columns = ['geometry','geo_x','geo_y','name']
origin_df = origin_df[selected_columns].reset_index(drop=True)
origin_df
# Out:
#                        geometry     geo_x      geo_y              name
# 0  POINT (4.9891612 52.2964067)  4.989161  52.296407              Gein
# 1  POINT (4.8505967 52.3952329)  4.850597  52.395233       Isolatorweg
# 2  POINT (4.9008686 52.3773546)  4.900869  52.377355  Centraal Station
# 3   POINT (4.932402 52.4021571)  4.932402  52.402157             Noord
# 4  POINT (4.8780248 52.3393025)  4.878025  52.339303              Zuid
# 5  POINT (4.9842364 52.3115025)  4.984236  52.311503       Gaasperplas

# %%
origin_name_df = origin_df[['name']]
origin_name_df
# Out:
#                name
# 0              Gein
# 1       Isolatorweg
# 2  Centraal Station
# 3             Noord
# 4              Zuid
# 5       Gaasperplas

# %%
merged_df = pd.merge(city_sub_new_nodes,origin_name_df, on='name', how='left', indicator=True)
destination_df = merged_df[merged_df['_merge'] == 'left_only'].drop('_merge', axis=1).reset_index(drop=True)
destination_df
# Out:
#                     geometry  degree   id                 name     geo_x  \
# 0   POINT (4.97400 52.29564)       2  855           Reigersbos  4.974000
# 1   POINT (4.96013 52.29813)       2  854          Holendrecht  4.960126
# 2   POINT (4.95213 52.30687)       2  810            Bullewijk  4.952129
# 3   POINT (4.94762 52.31181)       2  809        Bijlmer ArenA  4.947618
# 4   POINT (4.94140 52.31861)       2  808          Strandvliet  4.941398
# ..                       ...     ...  ...                  ...       ...
# 66  POINT (4.96734 52.32837)       2  824    Verrijn Stuartweg  4.967335
# 67  POINT (4.95669 52.33041)       2  823  Station Diemen Zuid  4.956688
# 68  POINT (4.94628 52.32683)       2  829         Venserpolder  4.946277
# 69  POINT (4.93028 52.32974)       2  827      Van der Madeweg  4.930285
# 70  POINT (4.92105 52.34029)       2  833           Spaklerweg  4.921045
#
#         geo_y         coordinate_value  \
# 0   52.295637  (4.9740002, 52.2956365)
# 1   52.298132  (4.9601264, 52.2981319)
# 2   52.306869   (4.9521292, 52.306869)
# 3   52.311806   (4.9476178, 52.311806)
# 4   52.318612  (4.9413977, 52.3186119)
# ..        ...                      ...
# 66  52.328367  (4.9673352, 52.3283668)
# 67  52.330406  (4.9566878, 52.3304057)
# 68  52.326833  (4.9462773, 52.3268326)
# 69  52.329735  (4.9302846, 52.3297352)
# 70  52.340287  (4.9210454, 52.3402871)
#
#                               route_name_list   route         ref    transfer
# 0               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# 1               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# 2               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# 3               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# 4               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# ..                                        ...     ...         ...         ...
# 66  Metro 53: Gaasperplas => Centraal Station  subway          53        None
# 67  Metro 53: Gaasperplas => Centraal Station  subway          53        None
# 68  Metro 53: Gaasperplas => Centraal Station  subway          53        None
# 69  Metro 53: Gaasperplas => Centraal Station  subway  50, 53, 54  50, 53, 54
# 70  Metro 53: Gaasperplas => Centraal Station  subway  51, 53, 54  51, 53, 54
#
# [71 rows x 11 columns]

# %%
OD_list = []

for index_origin, row_origin in origin_df.iterrows():
    o_geo_x = row_origin['geo_x']
    o_geo_y = row_origin['geo_y']
       
    for index_destination, row_destination in destination_df.iterrows():
        d_geo_x = row_destination['geo_x']
        d_geo_y = row_destination['geo_y']
        
        # Append a dictionary to the list
        OD_list.append({
            's_coordinates_x': o_geo_x,
            's_coordinates_y': o_geo_y,
            'e_coordinates_x': d_geo_x,
            'e_coordinates_y': d_geo_y
        })

# Create a DataFrame from the list of dictionaries
OD_df = pd.DataFrame(OD_list)  
OD_df
# Out:
#      s_coordinates_x  s_coordinates_y  e_coordinates_x  e_coordinates_y
# 0           4.989161        52.296407         4.974000        52.295637
# 1           4.989161        52.296407         4.960126        52.298132
# 2           4.989161        52.296407         4.952129        52.306869
# 3           4.989161        52.296407         4.947618        52.311806
# 4           4.989161        52.296407         4.941398        52.318612
# ..               ...              ...              ...              ...
# 421         4.984236        52.311503         4.967335        52.328367
# 422         4.984236        52.311503         4.956688        52.330406
# 423         4.984236        52.311503         4.946277        52.326833
# 424         4.984236        52.311503         4.930285        52.329735
# 425         4.984236        52.311503         4.921045        52.340287
#
# [426 rows x 4 columns]

# %%
# convert coordinates in station_df from degree to meter
def convert_deg_to_meter(new_nodes_df):
    # Convert the 'geometry' column to a Point object
    new_nodes_df['geometry'] = new_nodes_df.apply(lambda row: Point(row['geo_x'], row['geo_y']), axis=1)
    
    # Define the coordinate reference systems (CRS)
    crs_deg = 'EPSG:4326'  # WGS 84, the standard coordinate system for GPS
    crs_meter = 'EPSG:3857'  # World Mercator, commonly used for distance calculations

    # Create a transformer to convert from degrees to meters
    transformer = Transformer.from_crs(crs_deg, crs_meter, always_xy=True)

    # Apply the transformer to each Point in the 'geometry' column
    new_nodes_df['geometry'] = new_nodes_df['geometry'].apply(lambda point: Point(transformer.transform(point.x, point.y)))
    
    return new_nodes_df

# %%
origin_df = pd.DataFrame()
each_o_point = pd.DataFrame()
for route_name, station_df in city_sub_order_route_dict.items():
    each_o_point = station_df.loc[[0]]
    origin_df = pd.concat([origin_df,each_o_point])
origin_df.drop_duplicates(subset='geometry', inplace=True)
selected_columns = ['geometry','geo_x','geo_y','name']
origin_df = origin_df[selected_columns].reset_index(drop=True)
origin_df = convert_deg_to_meter(origin_df)
origin_df['o_geo_x'] = origin_df['geometry'].apply(lambda point: point.x)
origin_df['o_geo_y'] = origin_df['geometry'].apply(lambda point: point.y)
origin_df
# Out:
#                                       geometry     geo_x      geo_y  \
# 0  POINT (555390.8842695578 6853898.051924179)  4.989161  52.296407
# 1  POINT (539965.9546875331 6871906.554933311)  4.850597  52.395233
# 2  POINT (545562.1969967436 6868645.715657004)  4.900869  52.377355
# 3  POINT (549072.4790277241 6873169.820906038)  4.932402  52.402157
# 4  POINT (542608.8018504054 6861693.645104517)  4.874338  52.339214
# 5   POINT (554842.658041299 6856646.265439138)  4.984236  52.311503
#
#                name        o_geo_x       o_geo_y
# 0              Gein  555390.884270  6.853898e+06
# 1       Isolatorweg  539965.954688  6.871907e+06
# 2  Centraal Station  545562.196997  6.868646e+06
# 3             Noord  549072.479028  6.873170e+06
# 4              Zuid  542608.801850  6.861694e+06
# 5       Gaasperplas  554842.658041  6.856646e+06

# %%
destination_df1 = pd.DataFrame()
each_d_point = pd.DataFrame()
for route_name, station_df in city_tram_order_route_dict.items():
    each_d_point = station_df.loc[[0]]
    destination_df1 = pd.concat([destination_df1,each_d_point])
destination_df1.drop_duplicates(subset='geometry', inplace=True)
selected_columns = ['geometry', 'geo_x', 'geo_y']
destination_df1 = destination_df1[selected_columns].reset_index(drop=True)
destination_df1
# Out:
#                         geometry     geo_x      geo_y
# 0   POINT (4.9326128 52.3607965)  4.932613  52.360796
# 1   POINT (4.7747567 52.3537327)  4.774757  52.353733
# 2   POINT (4.8992878 52.3783193)  4.899288  52.378319
# 3    POINT (4.9178945 52.347445)  4.917895  52.347445
# 4    POINT (4.8992178 52.378303)  4.899218  52.378303
# 5   POINT (4.8029118 52.3772607)  4.802912  52.377261
# 6   POINT (4.9003629 52.3778505)  4.900363  52.377851
# 7   POINT (4.9510568 52.3652467)  4.951057  52.365247
# 8   POINT (4.8991546 52.3782813)  4.899155  52.378281
# 9   POINT (4.7864929 52.3554481)  4.786493  52.355448
# 10  POINT (4.8392172 52.3879696)  4.839217   52.38797
# 11  POINT (4.9697229 52.3364299)  4.969723   52.33643
# 12  POINT (4.8993575 52.3783416)  4.899357  52.378342
# 13  POINT (4.8036706 52.3449284)  4.803671  52.344928
# 14  POINT (4.9003819 52.3778942)  4.900382  52.377894
# 15  POINT (4.8659833 52.3352308)  4.865983  52.335231
# 16  POINT (4.8310348 52.2748113)  4.831035  52.274811
# 17  POINT (4.8731849 52.3408165)  4.873185  52.340817
# 18  POINT (5.0049024 52.3511345)  5.004902  52.351135
# 19  POINT (4.9009769 52.3778507)  4.900977  52.377851
# 20  POINT (4.8698541 52.3842644)  4.869854  52.384264
# 21   POINT (4.889801 52.3362207)  4.889801  52.336221
# 22  POINT (4.9003434 52.3778058)  4.900343  52.377806
# 23  POINT (4.8670933 52.3012694)  4.867093  52.301269
# 24   POINT (4.8821775 52.383238)  4.882178  52.383238
# 25  POINT (4.9373223 52.3766133)  4.937322  52.376613
# 26  POINT (4.8186019 52.3728449)  4.818602  52.372845

# %%
destination_df2 = pd.DataFrame()
each_d_point = pd.DataFrame()
for route_name, station_df in city_bus_order_route_dict.items():
    each_d_point = station_df.loc[[0]]
    destination_df2 = pd.concat([destination_df2,each_d_point])
destination_df2.drop_duplicates(subset='geometry', inplace=True)
selected_columns = ['geometry', 'geo_x', 'geo_y']
destination_df2 = destination_df2[selected_columns].reset_index(drop=True)
destination_df2
# Out:
#                         geometry     geo_x      geo_y
# 0   POINT (4.8720355 52.3408188)  4.872035  52.340819
# 1   POINT (4.8388077 52.3877091)  4.838808  52.387709
# 2   POINT (4.8231898 52.3462931)   4.82319  52.346293
# 3   POINT (4.8991236 52.3801466)  4.899124  52.380147
# 4   POINT (4.8007267 52.3754569)  4.800727  52.375457
# 5   POINT (4.8387698 52.3880096)   4.83877   52.38801
# 6   POINT (4.9394896 52.3676768)   4.93949  52.367677
# 7   POINT (4.7809214 52.3918165)  4.780921  52.391816
# 8   POINT (4.8362683 52.3893183)  4.836268  52.389318
# 9   POINT (4.9337209 52.3610843)  4.933721  52.361084
# 10  POINT (4.9186931 52.3461675)  4.918693  52.346167
# 11  POINT (4.8814222 52.4202605)  4.881422   52.42026
# 12  POINT (4.9392596 52.3711842)   4.93926  52.371184
# 13  POINT (4.8470139 52.3781334)  4.847014  52.378133
# 14  POINT (4.8276171 52.3407116)  4.827617  52.340712
# 15  POINT (4.8143821 52.3355324)  4.814382  52.335532
# 16  POINT (4.9442866 52.3995789)  4.944287  52.399579
# 17  POINT (4.9193382 52.3892587)  4.919338  52.389259
# 18  POINT (4.8840331 52.4202952)  4.884033  52.420295
# 19  POINT (4.9529344 52.3926033)  4.952934  52.392603
# 20  POINT (4.9333136 52.4019497)  4.933314   52.40195
# 21   POINT (4.8387805 52.387923)  4.838781  52.387923
# 22  POINT (4.7610461 52.3094091)  4.761046  52.309409
# 23     POINT (4.838741 52.38822)  4.838741   52.38822
# 24   POINT (4.9331008 52.401784)  4.933101  52.401784
# 25  POINT (4.9187351 52.3462419)  4.918735  52.346242
# 26  POINT (4.9400811 52.3966867)  4.940081  52.396687
# 27  POINT (4.9058515 52.4014371)  4.905851  52.401437
# 28  POINT (4.9360391 52.3229106)  4.936039  52.322911
# 29  POINT (4.9454009 52.3357224)  4.945401  52.335722
# 30  POINT (4.9025698 52.3792093)   4.90257  52.379209
# 31  POINT (4.9467125 52.3722865)  4.946713  52.372287
# 32  POINT (4.9473672 52.3114329)  4.947367  52.311433
# 33   POINT (4.9858332 52.346927)  4.985833  52.346927
# 34   POINT (4.8731084 52.336651)  4.873108  52.336651
# 35  POINT (4.8791445 52.3318593)  4.879144  52.331859
# 36  POINT (4.8596699 52.3249815)   4.85967  52.324981
# 37  POINT (4.8794156 52.3308129)  4.879416  52.330813
# 38  POINT (4.9475277 52.3112615)  4.947528  52.311262
# 39  POINT (4.9851835 52.3110934)  4.985183  52.311093
# 40  POINT (4.8748925 52.3977687)  4.874892  52.397769
# 41  POINT (5.0369527 52.3037765)  5.036953  52.303776
# 42  POINT (4.9475708 52.3112176)  4.947571  52.311218
# 43  POINT (4.8051399 52.3602896)   4.80514   52.36029
# 44  POINT (4.8387533 52.3881185)  4.838753  52.388118
# 45  POINT (4.8345018 52.3566769)  4.834502  52.356677
# 46  POINT (4.9189201 52.3462172)   4.91892  52.346217
# 47  POINT (4.7745693 52.3543998)  4.774569    52.3544
# 48  POINT (4.8343566 52.3566723)  4.834357  52.356672
# 49  POINT (4.9459361 52.3771048)  4.945936  52.377105
# 50  POINT (4.9373557 52.3766138)  4.937356  52.376614
# 51  POINT (5.0144582 52.3483266)  5.014458  52.348327
# 52  POINT (4.9474683 52.3113329)  4.947468  52.311333
# 53  POINT (4.8216284 52.3396829)  4.821628  52.339683

# %%
destination_df = pd.concat([destination_df1,destination_df2])
destination_df.drop_duplicates(subset='geometry', inplace=True)
destination_df = destination_df.reset_index(drop=True)
destination_df = convert_deg_to_meter(destination_df)
destination_df['d_geo_x'] = destination_df['geometry'].apply(lambda point: point.x)
destination_df['d_geo_y'] = destination_df['geometry'].apply(lambda point: point.y)
destination_df
# Out:
#                                        geometry     geo_x      geo_y  \
# 0   POINT (549095.9451763834 6865626.846179629)  4.932613  52.360796
# 1   POINT (531523.4845057713 6864339.319824525)  4.774757  52.353733
# 2   POINT (545386.2231456975 6868821.634459545)  4.899288  52.378319
# 3   POINT (547457.5115150408 6863193.427138583)  4.917895  52.347445
# 4    POINT (545378.430781342 6868818.662025344)  4.899218  52.378303
# ..                                          ...       ...        ...
# 76  POINT (550579.0881480693 6868600.163762547)  4.945936  52.377105
# 77  POINT (549623.9223892669 6868510.628964382)  4.937356  52.376614
# 78  POINT (558206.9334281551 6863354.083216033)  5.014458  52.348327
# 79  POINT (550749.6518718628 6856615.384294278)  4.947468  52.311333
# 80  POINT (536741.2182823863 6861779.059349007)  4.821628  52.339683
#
#           d_geo_x       d_geo_y
# 0   549095.945176  6.865627e+06
# 1   531523.484506  6.864339e+06
# 2   545386.223146  6.868822e+06
# 3   547457.511515  6.863193e+06
# 4   545378.430781  6.868819e+06
# ..            ...           ...
# 76  550579.088148  6.868600e+06
# 77  549623.922389  6.868511e+06
# 78  558206.933428  6.863354e+06
# 79  550749.651872  6.856615e+06
# 80  536741.218282  6.861779e+06
#
# [81 rows x 5 columns]

# %%
OD_list = []
for index, row_origin in origin_df.iterrows():
    o_geo_x = row_origin['o_geo_x']
    o_geo_y = row_origin['o_geo_y']
       
    for index, row_destination in destination_df.iterrows():
        d_geo_x = row_destination['d_geo_x']
        d_geo_y = row_destination['d_geo_y']
        
        OD_dict = {'s_coordinates_x': o_geo_x, 's_coordinates_y': o_geo_y, 'e_coordinates_x': d_geo_x, 'e_coordinates_y': d_geo_y}
        OD_list.append(OD_dict)

# %%
OD_list

# %%
len(OD_list)

# %%
OD_list[50]
# Out:
# {'s_coordinates_x': 555390.8842695578,
#  's_coordinates_y': 6853898.051924179,
#  'e_coordinates_x': 538646.1842005353,
#  'e_coordinates_y': 6870627.3083565105}

# %% [markdown]
# # Test 1:

# %%
start_node, end_node = s_e_node_df(OD_list[100], city_sub_new_nodes)

# %%
start_node
# Out:
#                           geometry  degree   id         name     geo_x  \
# 20  POINT (539965.955 6871906.555)       2  845  Isolatorweg  4.850597
#
#         geo_y         coordinate_value                route_name_list   route  \
# 20  52.395233  (4.8505967, 52.3952329)  Metro 50: Isolatorweg => Gein  subway
#
#        ref transfer
# 20  50, 51   50, 51

# %%
end_node
# Out:
#                           geometry  degree   id              name     geo_x  \
# 54  POINT (545582.068 6868673.707)       2  728  Centraal Station  4.901047
#
#         geo_y         coordinate_value  \
# 54  52.377508  (4.9010471, 52.3775081)
#
#                               route_name_list   route             ref  \
# 54  Metro 51: Isolatorweg => Centraal Station  subway  51, 52, 53, 54
#
#           transfer
# 54  51, 52, 53, 54

# %% [markdown]
# ### Find the route which the s_e nodes are on----compare with new_edges instead of routes dataframe, should compare with routes dataframe

# %%
s_on_route_ref,e_on_route_ref = s_e_on_route_ref(start_node, end_node)

# %%
s_on_route_ref
# Out:
#   ref
# 0  50
# 1  51

# %%
e_on_route_ref
# Out:
#   ref
# 0  51
# 1  52
# 2  53
# 3  54

# %% [markdown]
# ### Make judgement of s_e_on_route_ref

# %%
s_on_route_ref, e_on_route_ref = judge_on_route(s_on_route_ref, e_on_route_ref)
# Out:
# Some of e_on_route is the same as some of s_on_route.
# The next step is to find the same routes ---- using function 's_e_same_routes'

# %% [markdown]
# ### Find those same routes

# %%
s_e_same_routes_df = s_e_same_routes(s_on_route_ref,e_on_route_ref)
s_e_same_routes_df
# Out:
# s_node and e_node are on same route/routes:   ref
# 1  51
#   ref
# 1  51

# %% [markdown]
# ### Get the same route information--- A route gdf

# %%
s_e_on_possible_route_df = pd.merge(s_e_same_routes_df, city_sub_routes, on='ref', how='left')
s_e_on_possible_route_df
# Out:
#   ref   osm_id   route                to  \
# 0  51    31249  subway       Isolatorweg
# 1  51  4515355  subway  Centraal Station
#
#                                         name                 network service  \
# 0  Metro 51: Centraal Station => Isolatorweg  Stadsvervoer Amsterdam    None
# 1  Metro 51: Isolatorweg => Centraal Station  Stadsvervoer Amsterdam    None
#
#                                             geometry
# 0  MULTILINESTRING ((4.90193 52.37689, 4.90202 52...
# 1  MULTILINESTRING ((4.83880 52.38842, 4.83897 52...

# %%
s_e_on_route_possible_gdf = gpd.GeoDataFrame(s_e_on_possible_route_df.copy()).reset_index(drop=True)

start_node_gdf = gpd.GeoDataFrame(start_node.copy())
start_node_gdf.crs = "EPSG:3857"
start_node_gdf = start_node_gdf.to_crs("EPSG:4326")
end_node_gdf = gpd.GeoDataFrame(end_node.copy())
end_node_gdf.crs = "EPSG:3857"
end_node_gdf = end_node_gdf.to_crs("EPSG:4326")

# %%
s_e_on_route_possible_gdf
# Out:
#   ref   osm_id   route                to  \
# 0  51    31249  subway       Isolatorweg
# 1  51  4515355  subway  Centraal Station
#
#                                         name                 network service  \
# 0  Metro 51: Centraal Station => Isolatorweg  Stadsvervoer Amsterdam    None
# 1  Metro 51: Isolatorweg => Centraal Station  Stadsvervoer Amsterdam    None
#
#                                             geometry
# 0  MULTILINESTRING ((4.90193 52.37689, 4.90202 52...
# 1  MULTILINESTRING ((4.83880 52.38842, 4.83897 52...

# %%
def s_e_same_routes_transfer_all(s_e_same_routes_df,three_networks_routes,start_node):
    s_e_on_possible_route_df = pd.merge(s_e_same_routes_df, three_networks_routes, on='ref', how='left')
    s_e_on_route_possible_gdf = gpd.GeoDataFrame(s_e_on_possible_route_df.copy())

    start_node_gdf = gpd.GeoDataFrame(start_node.copy())
    start_node_gdf.crs = "EPSG:3857"
    start_node_gdf = start_node_gdf.to_crs("EPSG:4326")

    s_e_on_same_route_gdf = s_e_on_route_possible_gdf[s_e_on_route_possible_gdf.geometry.buffer(0.000001).intersects(start_node_gdf.iloc[0]['geometry'])]
    s_e_on_same_route_gdf = s_e_on_same_route_gdf.reset_index(drop = True)
    return start_node_gdf,s_e_on_same_route_gdf

# %%
start_node_gdf,s_e_on_same_route_gdf = s_e_same_routes_transfer_all(s_e_same_routes_df,city_sub_routes,start_node)

# %%
s_e_on_same_route_gdf
# Out:
#   ref   osm_id   route                to  \
# 0  51  4515355  subway  Centraal Station
#
#                                         name                 network service  \
# 0  Metro 51: Isolatorweg => Centraal Station  Stadsvervoer Amsterdam    None
#
#                                             geometry
# 0  MULTILINESTRING ((4.83880 52.38842, 4.83897 52...

# %% [markdown]
# ### Get all stations between s_e nodes

# %%
def all_btw_stations_on_same_route_gdf(merged_order_route_dict, s_e_on_same_route_gdf, start_node_gdf):
    all_stations_on_same_route = merged_order_route_dict[s_e_on_same_route_gdf.name[0]]
   
    all_stations_on_same_route_gdf = gpd.GeoDataFrame(all_stations_on_same_route.copy())
    all_stations_on_same_route_gdf.crs = "EPSG:3857"
    end_node_gdf = gpd.GeoDataFrame(end_node.copy())
    end_node_gdf.crs = "EPSG:3857"
    end_node_gdf = end_node_gdf.to_crs("EPSG:4326")

    start_station_index = shapely.distance(start_node_gdf.geometry.values,all_stations_on_same_route_gdf.geometry.values).argmin()
    end_station_index = shapely.distance(end_node_gdf.geometry.values,all_stations_on_same_route_gdf.geometry.values).argmin()
    all_btw_stations_on_same_route_gdf = all_stations_on_same_route_gdf.iloc[start_station_index:end_station_index+1]

    return all_btw_stations_on_same_route_gdf

# %%
all_btw_stations_on_same_route_gdf = all_btw_stations_on_same_route_gdf(city_sub_order_route_dict, s_e_on_same_route_gdf, start_node_gdf)
all_btw_stations_on_same_route_gdf
# Out:
#     id                 name              geometry     geo_x      geo_y  \
# 0   12          Isolatorweg  POINT (4.851 52.395)  4.850597  52.395233
# 1   14   Station Sloterdijk  POINT (4.839 52.389)  4.838763  52.389036
# 2    2         De Vlugtlaan  POINT (4.838 52.379)  4.838056  52.379461
# 3   13  Jan van Galenstraat  POINT (4.835 52.373)  4.835183  52.372584
# 4    3           Postjesweg  POINT (4.834 52.365)  4.833861  52.364599
# 5   11             Lelylaan  POINT (4.834 52.358)  4.834253   52.35806
# 6    6      Heemstedestraat  POINT (4.834 52.352)  4.834225  52.352325
# 7    4    Henk Sneevlietweg  POINT (4.834 52.346)  4.834395  52.346385
# 8    9      Amstelveenseweg  POINT (4.858 52.338)  4.857592  52.338339
# 9    1                 Zuid  POINT (4.874 52.339)  4.873978  52.339035
# 10  15          Station RAI  POINT (4.889 52.338)   4.88942  52.337606
# 11  10           Overamstel  POINT (4.918 52.332)  4.917703   52.33166
# 12   8           Spaklerweg  POINT (4.921 52.340)  4.920853  52.340246
# 13   7        Amstelstation  POINT (4.917 52.347)  4.917477  52.346648
# 14   0         Wibautstraat  POINT (4.912 52.355)  4.912049  52.354595
# 15  18         Weesperplein  POINT (4.908 52.361)  4.907918  52.361326
# 16  17        Waterlooplein  POINT (4.904 52.367)  4.903753   52.36669
# 17  16           Nieuwmarkt  POINT (4.901 52.371)  4.901085  52.371353
# 18   5     Centraal Station  POINT (4.901 52.378)  4.901047  52.377508
#
#                               route_name_list ref   route  \
# 0   Metro 51: Isolatorweg => Centraal Station  51  subway
# 1   Metro 51: Isolatorweg => Centraal Station  51  subway
# 2   Metro 51: Isolatorweg => Centraal Station  51  subway
# 3   Metro 51: Isolatorweg => Centraal Station  51  subway
# 4   Metro 51: Isolatorweg => Centraal Station  51  subway
# 5   Metro 51: Isolatorweg => Centraal Station  51  subway
# 6   Metro 51: Isolatorweg => Centraal Station  51  subway
# 7   Metro 51: Isolatorweg => Centraal Station  51  subway
# 8   Metro 51: Isolatorweg => Centraal Station  51  subway
# 9   Metro 51: Isolatorweg => Centraal Station  51  subway
# 10  Metro 51: Isolatorweg => Centraal Station  51  subway
# 11  Metro 51: Isolatorweg => Centraal Station  51  subway
# 12  Metro 51: Isolatorweg => Centraal Station  51  subway
# 13  Metro 51: Isolatorweg => Centraal Station  51  subway
# 14  Metro 51: Isolatorweg => Centraal Station  51  subway
# 15  Metro 51: Isolatorweg => Centraal Station  51  subway
# 16  Metro 51: Isolatorweg => Centraal Station  51  subway
# 17  Metro 51: Isolatorweg => Centraal Station  51  subway
# 18  Metro 51: Isolatorweg => Centraal Station  51  subway
#
#            coordinate_value
# 0   (4.8505967, 52.3952329)
# 1   (4.8387632, 52.3890363)
# 2   (4.8380564, 52.3794609)
# 3   (4.8351828, 52.3725841)
# 4   (4.8338612, 52.3645995)
# 5   (4.8342535, 52.3580602)
# 6   (4.8342252, 52.3523254)
# 7     (4.834395, 52.346385)
# 8   (4.8575924, 52.3383393)
# 9   (4.8739781, 52.3390351)
# 10  (4.8894203, 52.3376062)
# 11  (4.9177027, 52.3316595)
# 12  (4.9208526, 52.3402457)
# 13  (4.9174767, 52.3466483)
# 14  (4.9120486, 52.3545947)
# 15  (4.9079182, 52.3613263)
# 16  (4.9037527, 52.3666905)
# 17   (4.9010846, 52.371353)
# 18  (4.9010471, 52.3775081)

# %% [markdown]
# ### Get all nodes and id_pairs of nodes between s_e nodes

# %%
def btw_all_ids_pairs_transfer_all(all_btw_stations_on_same_route_gdf, three_networks_nodes_transfer_all):
    s_e_between_nodes = three_networks_nodes_transfer_all.merge(all_btw_stations_on_same_route_gdf, on = 'coordinate_value', suffixes=('', '_drop'))

    btw_all_id_pairs_list = []
    s_e_btw_nodes_transfer_all = three_networks_nodes_transfer_all.merge(all_btw_stations_on_same_route_gdf, on = 'coordinate_value', suffixes=('', '_drop'))

   

    id_pairs_way1 = pd.DataFrame(columns=['s_id', 'e_id'])

  
    for i in range(len(s_e_btw_nodes_transfer_all)-1):
           
        id_pairs_way1.loc[i, 's_id'] = s_e_btw_nodes_transfer_all.loc[i, 'id']
        id_pairs_way1.loc[i, 'e_id'] = s_e_btw_nodes_transfer_all.loc[i+1, 'id']
        

    btw_all_id_pairs_list.append(id_pairs_way1)

    return btw_all_id_pairs_list

# %%
btw_all_id_pairs_list = btw_all_ids_pairs_transfer_all(all_btw_stations_on_same_route_gdf,city_sub_new_nodes)
btw_all_id_pairs_list
# Out:
# [   s_id e_id
#  0   845  849
#  1   849  806
#  2   806  847
#  3   847  147
#  4   147  842
#  5   842  106
#  6   106  807
#  7   807  834
#  8   834   83
#  9    83  858
#  10  858  836
#  11  836  832
#  12  832  820
#  13  820  139
#  14  139  138
#  15  138  137
#  16  137  866
#  17  866  728]

# %% [markdown]
# ### Calculate shortest path and plot

# %%
btw_all_id_pairs_list_unique = drop_df_in_list(btw_all_id_pairs_list)
# Out:
# All dataframes in the list are the same

# %%
btw_all_id_pairs_list_unique
# Out:
# [   s_id e_id
#  0   845  849
#  1   849  806
#  2   806  847
#  3   847  147
#  4   147  842
#  5   842  106
#  6   106  807
#  7   807  834
#  8   834   83
#  9    83  858
#  10  858  836
#  11  836  832
#  12  832  820
#  13  820  139
#  14  139  138
#  15  138  137
#  16  137  866
#  17  866  728]

# %%
G = create_ground_graph(city_sub_new_edges, city_sub_new_nodes)

# %%
shortest_path_pairs_way = all_shortest_paths(G, btw_all_id_pairs_list_unique[0], city_sub_new_edges)

# %%
shortest_path_pairs_way
# Out:
#         osm_id                                           geometry railway  \
# 4     23189039  LINESTRING (4.8409161 52.3937679, 4.8416087 52...  subway
# 131   26983251  LINESTRING (4.8389695 52.3915778, 4.8390716 52...  subway
# 132   26983252  LINESTRING (4.8389695 52.3915778, 4.8389039 52...  subway
# 145   35359327  LINESTRING (4.8505094 52.3952331, 4.8495665 52...  subway
# 424  166370272  LINESTRING (4.8465456 52.3951777, 4.8467329 52...  subway
# ..         ...                                                ...     ...
# 833  562757374  LINESTRING (4.9010846 52.371353, 4.9010385 52....  subway
# 832  562757374  LINESTRING (4.9032664 52.3738373, 4.9032513 52...  subway
# 839  562757377  LINESTRING (4.9032664 52.3738373, 4.9033805 52...  subway
# 840  562757377  LINESTRING (4.9028129 52.376366, 4.9026508 52....  subway
# 841  562757377  LINESTRING (4.9023235 52.3767533, 4.9023002 52...  subway
#
#     service   id  from_id  to_id    distance      time  weights     to_from  \
# 4      None    4        8    492  382.935219  0.015317      382    (8, 492)
# 131    None  131      122    123   66.325938  0.002653       66  (122, 123)
# 132    None  132      122    849  283.361928  0.011334      283  (122, 849)
# 145    None  145      135    499   83.886925  0.003355       83  (135, 499)
# 424    None  424      491    373   12.747231  0.000510       12  (491, 373)
# ..      ...  ...      ...    ...         ...       ...      ...         ...
# 833    None  833      866    137  609.918310  0.024397      609  (866, 137)
# 832    None  832      732    866  315.995940  0.012640      315  (732, 866)
# 839    None  839      732    659  295.186232  0.011807      295  (732, 659)
# 840    None  840      659    661   54.480037  0.002179       54  (659, 661)
# 841    None  841      661    728  121.082728  0.004843      121  (661, 728)
#
#         from_to                            route_name_list   route         ref
# 4      (492, 8)              Metro 50: Isolatorweg => Gein  subway      50, 51
# 131  (123, 122)              Metro 50: Isolatorweg => Gein  subway      50, 51
# 132  (849, 122)              Metro 50: Isolatorweg => Gein  subway      50, 51
# 145  (499, 135)              Metro 50: Isolatorweg => Gein  subway      50, 51
# 424  (373, 491)              Metro 50: Gein => Isolatorweg  subway      50, 51
# ..          ...                                        ...     ...         ...
# 833  (137, 866)  Metro 51: Isolatorweg => Centraal Station  subway  51, 53, 54
# 832  (866, 732)  Metro 51: Isolatorweg => Centraal Station  subway  51, 53, 54
# 839  (659, 732)  Metro 51: Isolatorweg => Centraal Station  subway  51, 53, 54
# 840  (661, 659)  Metro 51: Isolatorweg => Centraal Station  subway  51, 53, 54
# 841  (728, 661)  Metro 51: Isolatorweg => Centraal Station  subway  51, 53, 54
#
# [132 rows x 15 columns]

# %%
duplicate_row_count_way, shortest_path_edges_way, edges_way = edges_with_count_weight(shortest_path_pairs_way, city_sub_edges)

# %%
shortest_path_edges_way
# Out:
#         osm_id                                           geometry railway  \
# 0     23189039  LINESTRING (4.8409161 52.3937679, 4.8416087 52...  subway
# 1     26983251  LINESTRING (4.8389695 52.3915778, 4.8390716 52...  subway
# 2     26983252  LINESTRING (4.8389695 52.3915778, 4.8389039 52...  subway
# 3     35359327  LINESTRING (4.8505094 52.3952331, 4.8495665 52...  subway
# 4    166370272  LINESTRING (4.8465456 52.3951777, 4.8467329 52...  subway
# ..         ...                                                ...     ...
# 127  562757374  LINESTRING (4.9010846 52.371353, 4.9010385 52....  subway
# 128  562757374  LINESTRING (4.9032664 52.3738373, 4.9032513 52...  subway
# 129  562757377  LINESTRING (4.9032664 52.3738373, 4.9033805 52...  subway
# 130  562757377  LINESTRING (4.9028129 52.376366, 4.9026508 52....  subway
# 131  562757377  LINESTRING (4.9023235 52.3767533, 4.9023002 52...  subway
#
#     service   id  from_id  to_id    distance      time  weights     to_from  \
# 0      None    4        8    492  382.935219  0.015317      382    (8, 492)
# 1      None  131      122    123   66.325938  0.002653       66  (122, 123)
# 2      None  132      122    849  283.361928  0.011334      283  (122, 849)
# 3      None  145      135    499   83.886925  0.003355       83  (135, 499)
# 4      None  424      491    373   12.747231  0.000510       12  (491, 373)
# ..      ...  ...      ...    ...         ...       ...      ...         ...
# 127    None  833      866    137  609.918310  0.024397      609  (866, 137)
# 128    None  832      732    866  315.995940  0.012640      315  (732, 866)
# 129    None  839      732    659  295.186232  0.011807      295  (732, 659)
# 130    None  840      659    661   54.480037  0.002179       54  (659, 661)
# 131    None  841      661    728  121.082728  0.004843      121  (661, 728)
#
#         from_to                            route_name_list   route  \
# 0      (492, 8)              Metro 50: Isolatorweg => Gein  subway
# 1    (123, 122)              Metro 50: Isolatorweg => Gein  subway
# 2    (849, 122)              Metro 50: Isolatorweg => Gein  subway
# 3    (499, 135)              Metro 50: Isolatorweg => Gein  subway
# 4    (373, 491)              Metro 50: Gein => Isolatorweg  subway
# ..          ...                                        ...     ...
# 127  (137, 866)  Metro 51: Isolatorweg => Centraal Station  subway
# 128  (866, 732)  Metro 51: Isolatorweg => Centraal Station  subway
# 129  (659, 732)  Metro 51: Isolatorweg => Centraal Station  subway
# 130  (661, 659)  Metro 51: Isolatorweg => Centraal Station  subway
# 131  (728, 661)  Metro 51: Isolatorweg => Centraal Station  subway
#
#             ref  count_weight
# 0        50, 51           1.0
# 1        50, 51           1.0
# 2        50, 51           1.0
# 3        50, 51           1.0
# 4        50, 51           1.0
# ..          ...           ...
# 127  51, 53, 54           1.0
# 128  51, 53, 54           1.0
# 129  51, 53, 54           1.0
# 130  51, 53, 54           1.0
# 131  51, 53, 54           1.0
#
# [132 rows x 16 columns]

# %%
shortest_path_edges_way.time.sum()
# Out:
# 0.7448451715128557

# %%
fig, ax = plt.subplots(1, 1, figsize=(30, 20))

gpd.GeoDataFrame(city_sub_new_edges.copy()).plot(ax=ax, color='gray', alpha=0.2)

gpd.GeoDataFrame(shortest_path_edges_way.copy()).plot(ax=ax, zorder=1, linewidth=(shortest_path_edges_way.count_weight), color='orange')
# Out:
# <Axes: >

# %% [markdown]
# # Tram-Amsterdam

# %% [markdown]
# ## Generate tram networks

# %%
city_tram_stations, edges, nodes, city_tram_routes = prepare_tram(osm_path)
# Out:
# endpoints: 100%|████████████████████████████████████████████████████████████████| 1562/1562 [00:00<00:00, 54321.98it/s]
# endpoints: 100%|████████████████████████████████████████████████████████████████| 2204/2204 [00:00<00:00, 49327.90it/s]
# topology: 100%|██████████████████████████████████████████████████████████████████| 2204/2204 [00:00<00:00, 8226.67it/s]
# Calculate_degree possibly unhappy

# %%
edges
# Out:
#           osm_id                                           geometry railway  \
# 0        7045610  LINESTRING (4.9324018 52.3610615, 4.932387 52....    tram
# 1        7045616  LINESTRING (4.934085 52.3609657, 4.9340765 52....    tram
# 2        7045675  LINESTRING (4.9337809 52.3611734, 4.9339017 52...    tram
# 3        7045689  LINESTRING (4.9394 52.361617, 4.9385742 52.361...    tram
# 4        7045994  LINESTRING (4.9157261 52.365067, 4.9157046 52....    tram
# ...          ...                                                ...     ...
# 2199  1185084715  LINESTRING (4.8520736 52.3479443, 4.8521852 52...    tram
# 2200  1185084716  LINESTRING (4.852325 52.3480075, 4.852489 52.3...    tram
# 2201  1185084717  LINESTRING (4.8516012 52.3470208, 4.8519064 52...    tram
# 2202  1185084718  LINESTRING (4.8522982 52.348033, 4.8524709 52....    tram
# 2203  1185084719  LINESTRING (4.851576 52.3470746, 4.8518677 52....    tram
#
#      service    id  from_id  to_id    distance      time  weights  \
# 0       None     0        0      1   28.561299  0.002040       28
# 1       None     1        2      3  146.082551  0.010434      146
# 2       None     2        4      5  390.987463  0.027928      390
# 3       None     3        6      7  345.247175  0.024661      345
# 4       None     4        8   1730   35.152166  0.002511       35
# ...      ...   ...      ...    ...         ...       ...      ...
# 2199    None  2199     1496    594   11.280287  0.000806       11
# 2200    None  2200      562   1072   12.010525  0.000858       12
# 2201    None  2201     1497    561   81.765515  0.005840       81
# 2202    None  2202      566   1079   12.587379  0.000899       12
# 2203    None  2203      552    565   78.206965  0.005586       78
#
#           to_from      from_to
# 0          (0, 1)       (1, 0)
# 1          (2, 3)       (3, 2)
# 2          (4, 5)       (5, 4)
# 3          (6, 7)       (7, 6)
# 4       (8, 1730)    (1730, 8)
# ...           ...          ...
# 2199  (1496, 594)  (594, 1496)
# 2200  (562, 1072)  (1072, 562)
# 2201  (1497, 561)  (561, 1497)
# 2202  (566, 1079)  (1079, 566)
# 2203   (552, 565)   (565, 552)
#
# [2204 rows x 12 columns]

# %%
nodes
# Out:
#                           geometry  degree    id
# 0     POINT (4.9324018 52.3610615)       3     0
# 1      POINT (4.9321097 52.361227)       3     1
# 2      POINT (4.934085 52.3609657)       3     2
# 3      POINT (4.933017 52.3603624)       3     3
# 4     POINT (4.9337809 52.3611734)       3     4
# ...                            ...     ...   ...
# 1915  POINT (4.9009826 52.3777045)       0  1915
# 1916   POINT (4.890644 52.3719008)       2  1916
# 1917  POINT (4.9899502 52.3580579)       2  1917
# 1918   POINT (4.9272548 52.357015)       0  1918
# 1919  POINT (4.9268761 52.3574304)       0  1919
#
# [1920 rows x 3 columns]

# %%
city_tram_routes
# Out:
#         osm_id route                                   to  \
# 17       31398  tram           Amsterdam, De Boelelaan/VU
# 18       31530  tram       Amsterdam, Oudenaardeplantsoen
# 19       31794  tram                Amsterdam, Drentepark
# 22       32579  tram    Amsterdam, Osdorp Dijkgraafsplein
# 23       32615  tram                    Amsterdam, IJburg
# 24       32867  tram       Amsterdam, Lambertus Zijlplein
# 390    4494870  tram          Amsterdam, Centraal Station
# 391    4497721  tram          Amsterdam, Centraal Station
# 392    4512710  tram           Amsterdam Centraal Station
# 393    4513899  tram          Amsterdam, Centraal Station
# 394    4514441  tram          Amsterdam, Centraal Station
# 395    4514562  tram          Amsterdam, Centraal Station
# 495    6323706  tram                            Bovenkerk
# 496    6323707  tram                Haarlemmermeerstation
# 662    8487480  tram                Amsterdam, Sloterpark
# 663    8493152  tram                Amsterdam, Azartplein
# 664    8493327  tram                 Amsterdam, Flevopark
# 665    8494828  tram            Amsterdam, Van Hallstraat
# 666    8495110  tram                Amsterdam, Sloterdijk
# 667    8495459  tram                        Diemen, Sniep
# 668    8500223  tram  Amsterdam, Eerste Marnixdwarsstraat
# 669    8500345  tram                Amstelveen, Stadshart
# 670    8500553  tram        Amsterdam, Muiderpoortstation
# 676    8507592  tram            Amsterdam, Osdorp De Aker
# 677    8507736  tram          Amsterdam, Centraal Station
# 678    8507786  tram                 Amsterdam, Flevopark
# 679    8507941  tram          Amsterdam, Centraal Station
# 680    8510079  tram             Amsterdam, Amstelstation
# 1057  12010105  tram                 Amstelveen, Westwijk
# 1058  12010106  tram              Amsterdam, Station Zuid
#
#                                                    name  ref  \
# 17    Tram 24: Amsterdam Centraal Station => Amsterd...   24
# 18    Tram 2: Amsterdam Centraal Station => Amsterda...    2
# 19    Tram 4: Amsterdam Centraal Station => Amsterda...    4
# 22    Tram 17: Amsterdam Centraal Station => Amsterd...   17
# 23    Tram 26: Amsterdam Centraal Station => Amsterd...   26
# 24    Tram 13: Amsterdam Centraal Station => Amsterd...   13
# 390   Tram 4: Amsterdam Station RAI => Amsterdam Cen...    4
# 391   Tram 2: Amsterdam Nieuw Sloten => Amsterdam Ce...    2
# 392   Tram 13: Amsterdam Geuzenveld => Amsterdam Cen...   13
# 393   Tram 24: Amsterdam VUmc => Amsterdam Centraal ...   24
# 394   Tram 17: Amsterdam Osdorp Dijkgraafsplein => A...   17
# 395   Tram 26: Amsterdam IJburg => Amsterdam Centraa...   26
# 495                Electrische Museumtramlijn Amsterdam  EMA
# 496                Electrische Museumtramlijn Amsterdam  EMA
# 662   Tram 7: Amsterdam Azartplein => Amsterdam Slot...    7
# 663   Tram 7: Amsterdam Slotermeer => Amsterdam Azar...    7
# 664   Tram 3: Amsterdam Westergasfabriek => Amsterda...    3
# 665   Tram 3: Amsterdam Flevopark => Amsterdam Weste...    3
# 666       Tram 19: Diemen Sniep => Amsterdam Sloterdijk   19
# 667       Tram 19: Amsterdam Sloterdijk => Diemen Sniep   19
# 668   Tram 5: Amstelveen Stadshart => Amsterdam Eers...    5
# 669   Tram 5: Amsterdam Eerste Marnixdwarsstraat => ...    5
# 670   Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...    1
# 676   Tram 1: Amsterdam Muiderpoortstation =>Amsterd...    1
# 677   Tram 14: Amsterdam Flevopark => Amsterdam Cent...   14
# 678   Tram 14: Amsterdam Centraal Station => Amsterd...   14
# 679   Tram 12: Amsterdam Amstelstation => Amsterdam ...   12
# 680   Tram 12: Amsterdam Centraal Station => Amsterd...   12
# 1057  Tram 25: Amsterdam Station Zuid => Amstelveen ...   25
# 1058  Tram 25: Amstelveen Westwijk => Amsterdam Stat...   25
#
#                      network service  \
# 17    Stadsvervoer Amsterdam    None
# 18    Stadsvervoer Amsterdam    None
# 19    Stadsvervoer Amsterdam    None
# 22    Stadsvervoer Amsterdam    None
# 23    Stadsvervoer Amsterdam    None
# 24    Stadsvervoer Amsterdam    None
# 390   Stadsvervoer Amsterdam    None
# 391   Stadsvervoer Amsterdam    None
# 392   Stadsvervoer Amsterdam    None
# 393   Stadsvervoer Amsterdam    None
# 394   Stadsvervoer Amsterdam    None
# 395   Stadsvervoer Amsterdam    None
# 495                      EMA    None
# 496                      EMA    None
# 662   Stadsvervoer Amsterdam    None
# 663   Stadsvervoer Amsterdam    None
# 664   Stadsvervoer Amsterdam    None
# 665   Stadsvervoer Amsterdam    None
# 666   Stadsvervoer Amsterdam    None
# 667   Stadsvervoer Amsterdam    None
# 668   Stadsvervoer Amsterdam    None
# 669   Stadsvervoer Amsterdam    None
# 670   Stadsvervoer Amsterdam    None
# 676   Stadsvervoer Amsterdam    None
# 677   Stadsvervoer Amsterdam    None
# 678   Stadsvervoer Amsterdam    None
# 679   Stadsvervoer Amsterdam    None
# 680   Stadsvervoer Amsterdam    None
# 1057  Stadsvervoer Amsterdam    None
# 1058  Stadsvervoer Amsterdam    None
#
#                                                geometry
# 17    MULTILINESTRING ((4.89406 52.37387, 4.89361 52...
# 18    MULTILINESTRING ((4.81102 52.34641, 4.81118 52...
# 19    MULTILINESTRING ((4.89406 52.37387, 4.89361 52...
# 22    MULTILINESTRING ((4.89915 52.37828, 4.89919 52...
# 23    MULTILINESTRING ((4.90035 52.37793, 4.90035 52...
# 24    MULTILINESTRING ((4.89922 52.37830, 4.89926 52...
# 390   MULTILINESTRING ((4.88956 52.33608, 4.88962 52...
# 391   MULTILINESTRING ((4.80985 52.34614, 4.81032 52...
# 392   MULTILINESTRING ((4.80291 52.37726, 4.80320 52...
# 393   MULTILINESTRING ((4.86582 52.33525, 4.86638 52...
# 394   MULTILINESTRING ((4.78649 52.35545, 4.78658 52...
# 395   MULTILINESTRING ((5.00315 52.35096, 5.00329 52...
# 495   MULTILINESTRING ((4.85628 52.34931, 4.85621 52...
# 496   MULTILINESTRING ((4.85047 52.30419, 4.85048 52...
# 662   MULTILINESTRING ((4.93732 52.37661, 4.93733 52...
# 663   MULTILINESTRING ((4.92417 52.36656, 4.92492 52...
# 664   MULTILINESTRING ((4.86985 52.38426, 4.86988 52...
# 665   MULTILINESTRING ((4.95106 52.36525, 4.95096 52...
# 666   MULTILINESTRING ((4.97019 52.33632, 4.96967 52...
# 667   MULTILINESTRING ((4.97019 52.33632, 4.96967 52...
# 668   MULTILINESTRING ((4.86656 52.30142, 4.86662 52...
# 669   MULTILINESTRING ((4.88041 52.35868, 4.88054 52...
# 670   MULTILINESTRING ((4.77476 52.35373, 4.77655 52...
# 676   MULTILINESTRING ((4.93261 52.36080, 4.93252 52...
# 677   MULTILINESTRING ((4.95186 52.36530, 4.95171 52...
# 678   MULTILINESTRING ((4.89406 52.37387, 4.89361 52...
# 679   MULTILINESTRING ((4.91789 52.34745, 4.91800 52...
# 680   MULTILINESTRING ((4.89929 52.37832, 4.89936 52...
# 1057  MULTILINESTRING ((4.87347 52.34084, 4.87347 52...
# 1058  MULTILINESTRING ((4.83051 52.27427, 4.83055 52...

# %%
len(city_tram_routes)
# Out:
# 30

# %%
city_tram_routes = city_tram_routes.loc[city_tram_routes.ref != 'EMA']

# %%
city_tram_routes, check_name = check_tram_routes(city_tram_stations, city_tram_routes)

# %%
replacement_dict = {
    ',': '',
    'Diemen': '',
    'Amsterdam': '',
    'Sloterdijk': 'Station Sloterdijk',
    'Osdorp Dijkgraafsplein': 'Dijkgraafplein',
    'Osdorp De Aker': 'Matterhorn'
}

city_tram_stations, city_tram_routes, check_name = recheck_tram_routes(replacement_dict, city_tram_stations, city_tram_routes)

# %%
replacement_dict = {
    'Amstelveen Westwijk': 'Westwijk'
}

city_tram_stations, city_tram_routes, check_name = recheck_tram_routes(replacement_dict, city_tram_stations, city_tram_routes)

# %%
city_tram_order_route_dict, city_tram_shortest_path_pairs, city_tram_shortest_path_edges, tram_edges = tram(city_tram_stations, edges, nodes, city_tram_routes, city='Amsterdam')

# %%
tram_edges
# Out:
#           osm_id                                           geometry railway  \
# 0        7045610  LINESTRING (4.9324018 52.3610615, 4.932387 52....    tram
# 1        7045616  LINESTRING (4.934085 52.3609657, 4.9340765 52....    tram
# 2        7045675  LINESTRING (4.9337809 52.3611734, 4.9339017 52...    tram
# 3        7045689  LINESTRING (4.9394 52.361617, 4.9385742 52.361...    tram
# 4        7045994  LINESTRING (4.9157261 52.365067, 4.9157046 52....    tram
# ...          ...                                                ...     ...
# 2199  1185084715  LINESTRING (4.8520736 52.3479443, 4.8521852 52...    tram
# 2200  1185084716  LINESTRING (4.852325 52.3480075, 4.852489 52.3...    tram
# 2201  1185084717  LINESTRING (4.8516012 52.3470208, 4.8519064 52...    tram
# 2202  1185084718  LINESTRING (4.8522982 52.348033, 4.8524709 52....    tram
# 2203  1185084719  LINESTRING (4.851576 52.3470746, 4.8518677 52....    tram
#
#      service    id  from_id  to_id    distance      time  weights  \
# 0       None     0        0      1   28.561299  0.002040       28
# 1       None     1        2      3  146.082551  0.010434      146
# 2       None     2        4      5  390.987463  0.027928      390
# 3       None     3        6      7  345.247175  0.024661      345
# 4       None     4        8   1730   35.152166  0.002511       35
# ...      ...   ...      ...    ...         ...       ...      ...
# 2199    None  2199     1496    594   11.280287  0.000806       11
# 2200    None  2200      562   1072   12.010525  0.000858       12
# 2201    None  2201     1497    561   81.765515  0.005840       81
# 2202    None  2202      566   1079   12.587379  0.000899       12
# 2203    None  2203      552    565   78.206965  0.005586       78
#
#           to_from      from_to
# 0          (0, 1)       (1, 0)
# 1          (2, 3)       (3, 2)
# 2          (4, 5)       (5, 4)
# 3          (6, 7)       (7, 6)
# 4       (8, 1730)    (1730, 8)
# ...           ...          ...
# 2199  (1496, 594)  (594, 1496)
# 2200  (562, 1072)  (1072, 562)
# 2201  (1497, 561)  (561, 1497)
# 2202  (566, 1079)  (1079, 566)
# 2203   (552, 565)   (565, 552)
#
# [2204 rows x 12 columns]

# %% [markdown]
# ## Add columns to nodes

# %%
city_tram_order_route_dict = add_ref_to_orderroutes_or_shortestpath_dict(city_tram_order_route_dict, city_tram_routes)

# %%
city_tram_new_nodes = add_columns_to_nodes(city_tram_order_route_dict, nodes)

# %%
city_tram_new_nodes
# Out:
#                      geometry  degree    id                       name  \
# 0    POINT (4.93261 52.36080)       2  1341         Muiderpoortstation
# 1    POINT (4.92894 52.36093)       2  1503               Dapperstraat
# 2    POINT (4.92570 52.36012)       2  1606             Linnaeusstraat
# 3    POINT (4.91674 52.35907)       2  1612                  Beukenweg
# 4    POINT (4.91359 52.36235)       2  1598  Korte 's-Gravesandestraat
# ..                        ...     ...   ...                        ...
# 413  POINT (4.92630 52.36814)       2  1559      Eerste Coehoornstraat
# 414  POINT (4.92960 52.37020)       2  1808    Eerste Leeghwaterstraat
# 415  POINT (4.93483 52.37301)       2  1515               Rietlandpark
# 416  POINT (4.93817 52.37346)       2  1751        C. van Eesterenlaan
# 417  POINT (4.93735 52.37682)       2   414                 Azartplein
#
#         geo_x      geo_y         coordinate_value  \
# 0    4.932613  52.360796  (4.9326128, 52.3607965)
# 1    4.928942  52.360931  (4.9289422, 52.3609314)
# 2    4.925703  52.360116  (4.9257029, 52.3601162)
# 3    4.916742  52.359073  (4.9167422, 52.3590732)
# 4    4.913592  52.362348  (4.9135923, 52.3623479)
# ..        ...        ...                      ...
# 413  4.926300  52.368143  (4.9263002, 52.3681426)
# 414  4.929600  52.370198  (4.9295997, 52.3701978)
# 415  4.934833  52.373011  (4.9348327, 52.3730107)
# 416  4.938170  52.373460  (4.9381702, 52.3734596)
# 417  4.937347  52.376818  (4.9373469, 52.3768181)
#
#                                        route_name_list route       ref  \
# 0    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram      1, 3
# 1    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram      1, 3
# 2    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram      1, 3
# 3    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram      1, 3
# 4    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram  1, 19, 7
# ..                                                 ...   ...       ...
# 413  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram         7
# 414  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram         7
# 415  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram     26, 7
# 416  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram         7
# 417  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram         7
#
#      transfer
# 0        1, 3
# 1        1, 3
# 2        1, 3
# 3        1, 3
# 4    1, 19, 7
# ..        ...
# 413      None
# 414      None
# 415     26, 7
# 416      None
# 417      None
#
# [418 rows x 11 columns]

# %% [markdown]
# ### retrive all transfer stations on each route

# %%
city_tram_transfer_stations_df = all_transfer_stations_df(city_tram_new_nodes)

# %%
city_tram_transfer_stations_df
# Out:
#                      geometry  degree    id                       name  \
# 0    POINT (4.93261 52.36080)       2  1341         Muiderpoortstation
# 1    POINT (4.92894 52.36093)       2  1503               Dapperstraat
# 2    POINT (4.92570 52.36012)       2  1606             Linnaeusstraat
# 3    POINT (4.91674 52.35907)       2  1612                  Beukenweg
# 4    POINT (4.91359 52.36235)       2  1598  Korte 's-Gravesandestraat
# ..                        ...     ...   ...                        ...
# 393  POINT (4.84859 52.37333)       2  1642        Jan van Galenstraat
# 408  POINT (4.84872 52.37298)       2  1802        Jan van Galenstraat
# 409  POINT (4.85007 52.37041)       2  1888              Mercatorplein
# 411  POINT (4.91857 52.36337)       2  1803             Alexanderplein
# 415  POINT (4.93483 52.37301)       2  1515               Rietlandpark
#
#         geo_x      geo_y         coordinate_value  \
# 0    4.932613  52.360796  (4.9326128, 52.3607965)
# 1    4.928942  52.360931  (4.9289422, 52.3609314)
# 2    4.925703  52.360116  (4.9257029, 52.3601162)
# 3    4.916742  52.359073  (4.9167422, 52.3590732)
# 4    4.913592  52.362348  (4.9135923, 52.3623479)
# ..        ...        ...                      ...
# 393  4.848589  52.373332  (4.8485891, 52.3733319)
# 408  4.848724  52.372983  (4.8487242, 52.3729826)
# 409  4.850068  52.370406  (4.8500681, 52.3704058)
# 411  4.918568  52.363371  (4.9185684, 52.3633708)
# 415  4.934833  52.373011  (4.9348327, 52.3730107)
#
#                                        route_name_list route        ref  \
# 0    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram       1, 3
# 1    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram       1, 3
# 2    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram       1, 3
# 3    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram       1, 3
# 4    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram   1, 19, 7
# ..                                                 ...   ...        ...
# 393  Tram 7: Amsterdam Azartplein => Amsterdam Slot...  tram  13, 19, 7
# 408  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram  13, 19, 7
# 409  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram      13, 7
# 411  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram  14, 19, 7
# 415  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram      26, 7
#
#       transfer
# 0         1, 3
# 1         1, 3
# 2         1, 3
# 3         1, 3
# 4     1, 19, 7
# ..         ...
# 393  13, 19, 7
# 408  13, 19, 7
# 409      13, 7
# 411  14, 19, 7
# 415      26, 7
#
# [183 rows x 11 columns]

# %%
len(city_tram_transfer_stations_df)
# Out:
# 183

# %% [markdown]
# ## Add columns to edges

# %%
city_tram_shortest_path_edges = add_ref_to_orderroutes_or_shortestpath_dict(city_tram_shortest_path_edges, city_tram_routes)

# %%
city_tram_new_edges = add_columns_to_edges(city_tram_shortest_path_edges,edges)

# %%
column_to_drop = 'count_weight'
city_tram_new_edges = city_tram_new_edges.drop(columns=column_to_drop)

# %%
city_tram_new_edges
# Out:
#           osm_id                                           geometry railway  \
# 0        7045610  LINESTRING (4.9324018 52.3610615, 4.932387 52....    tram
# 1        7045616  LINESTRING (4.934085 52.3609657, 4.9340765 52....    tram
# 2        7045675  LINESTRING (4.9337809 52.3611734, 4.9339017 52...    tram
# 3        7045689  LINESTRING (4.9394 52.361617, 4.9385742 52.361...    tram
# 4        7045994  LINESTRING (4.9157261 52.365067, 4.9157046 52....    tram
# ...          ...                                                ...     ...
# 2199  1185084715  LINESTRING (4.8520736 52.3479443, 4.8521852 52...    tram
# 2200  1185084716  LINESTRING (4.852325 52.3480075, 4.852489 52.3...    tram
# 2201  1185084717  LINESTRING (4.8516012 52.3470208, 4.8519064 52...    tram
# 2202  1185084718  LINESTRING (4.8522982 52.348033, 4.8524709 52....    tram
# 2203  1185084719  LINESTRING (4.851576 52.3470746, 4.8518677 52....    tram
#
#      service    id  from_id  to_id    distance      time  weights  \
# 0       None     0        0      1   28.561299  0.002040       28
# 1       None     1        2      3  146.082551  0.010434      146
# 2       None     2        4      5  390.987463  0.027928      390
# 3       None     3        6      7  345.247175  0.024661      345
# 4       None     4        8   1730   35.152166  0.002511       35
# ...      ...   ...      ...    ...         ...       ...      ...
# 2199    None  2199     1496    594   11.280287  0.000806       11
# 2200    None  2200      562   1072   12.010525  0.000858       12
# 2201    None  2201     1497    561   81.765515  0.005840       81
# 2202    None  2202      566   1079   12.587379  0.000899       12
# 2203    None  2203      552    565   78.206965  0.005586       78
#
#           to_from      from_to  \
# 0          (0, 1)       (1, 0)
# 1          (2, 3)       (3, 2)
# 2          (4, 5)       (5, 4)
# 3          (6, 7)       (7, 6)
# 4       (8, 1730)    (1730, 8)
# ...           ...          ...
# 2199  (1496, 594)  (594, 1496)
# 2200  (562, 1072)  (1072, 562)
# 2201  (1497, 561)  (561, 1497)
# 2202  (566, 1079)  (1079, 566)
# 2203   (552, 565)   (565, 552)
#
#                                         route_name_list route  ref
# 0     Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram    1
# 1                                                   NaN   NaN  NaN
# 2     Tram 3: Amsterdam Westergasfabriek => Amsterda...  tram    3
# 3     Tram 3: Amsterdam Flevopark => Amsterdam Weste...  tram    3
# 4     Tram 14: Amsterdam Flevopark => Amsterdam Cent...  tram   14
# ...                                                 ...   ...  ...
# 2199                                                NaN   NaN  NaN
# 2200                                                NaN   NaN  NaN
# 2201                                                NaN   NaN  NaN
# 2202                                                NaN   NaN  NaN
# 2203                                                NaN   NaN  NaN
#
# [2204 rows x 15 columns]

# %% [markdown]
# # Bus-Amsterdam

# %% [markdown]
# ## Generate bus networks

# %%
city_bus_stations, edges, nodes, city_bus_routes = prepare_bus(osm_path)
# Out:
# endpoints: 100%|██████████████████████████████████████████████████████████████| 50662/50662 [00:00<00:00, 54184.25it/s]
# endpoints: 100%|██████████████████████████████████████████████████████████████| 71634/71634 [00:01<00:00, 66985.95it/s]
# topology: 100%|████████████████████████████████████████████████████████████████| 71634/71634 [00:08<00:00, 8429.87it/s]

# %%
edges
# Out:
#            osm_id                                           geometry  service  \
# 0         4436684  LINESTRING (4.9683596 52.3558775, 4.9683345 52...    steps
# 1         4495957  LINESTRING (4.8601784 52.357593, 4.8601399 52....    steps
# 2         4496429  LINESTRING (4.8743983 52.358788, 4.8744747 52....  service
# 3         4727308  LINESTRING (4.9563878 52.377293, 4.9564629 52....     path
# 4         4727308  LINESTRING (4.9564856 52.376881, 4.9564944 52....     path
# ...           ...                                                ...      ...
# 71623  1185077512  LINESTRING (4.795149 52.3318873, 4.7953163 52....  service
# 71624  1185077519  LINESTRING (4.7974835 52.3325307, 4.7972201 52...  service
# 71625  1185077520  LINESTRING (4.7967795 52.3323057, 4.7972519 52...  service
# 71626  1185077524  LINESTRING (4.7997017 52.3324389, 4.7997688 52...     path
# 71627  1185077528  LINESTRING (4.7988313 52.3335157, 4.7987286 52...  service
#
#           id  from_id  to_id   distance      time  weights         to_from  \
# 0          0        0      1   4.049164  0.000324        4          (0, 1)
# 1          1        2      3   7.754968  0.000620        7          (2, 3)
# 2          2        4      5  68.807947  0.005505       68          (4, 5)
# 3          3        6  65237  46.383298  0.003711       46      (6, 65237)
# 4          4    65237      7   2.090290  0.000167        2      (65237, 7)
# ...      ...      ...    ...        ...       ...      ...             ...
# 71623  71623    65586  65587  29.884042  0.002391       29  (65586, 65587)
# 71624  71624    65588  65589  19.267219  0.001541       19  (65588, 65589)
# 71625  71625    65590  65591  34.723141  0.002778       34  (65590, 65591)
# 71626  71626    65592  65593  65.462451  0.005237       65  (65592, 65593)
# 71627  71627    65594  65595  41.888083  0.003351       41  (65594, 65595)
#
#               from_to railway
# 0              (1, 0)     bus
# 1              (3, 2)     bus
# 2              (5, 4)     bus
# 3          (65237, 6)     bus
# 4          (7, 65237)     bus
# ...               ...     ...
# 71623  (65587, 65586)     bus
# 71624  (65589, 65588)     bus
# 71625  (65591, 65590)     bus
# 71626  (65593, 65592)     bus
# 71627  (65595, 65594)     bus
#
# [71628 rows x 12 columns]

# %%
nodes
# Out:
#                            geometry  degree     id
# 0      POINT (4.9683596 52.3558775)       1      0
# 1      POINT (4.9683118 52.3558559)       1      1
# 2       POINT (4.8601784 52.357593)       1      2
# 3      POINT (4.8601399 52.3576586)       1      3
# 4       POINT (4.8743983 52.358788)       1      4
# ...                             ...     ...    ...
# 68437  POINT (4.8808204 52.3586774)       0  68437
# 68438  POINT (4.8688259 52.3392455)       2  68438
# 68439  POINT (4.8690257 52.3316423)       2  68439
# 68440  POINT (4.8705297 52.3165252)       2  68440
# 68441  POINT (4.8909317 52.4173556)       2  68441
#
# [68442 rows x 3 columns]

# %%
city_bus_routes
# Out:
#         osm_id route                                to  \
# 31       73789   bus      Amsterdam Muiderpoortstation
# 37      146350   bus           Schiphol, Airport/Plaza
# 44      156123   bus                   Marken Minneweg
# 52      161790   bus  Nieuw Vennep, P+R Getsewoud Zuid
# 91      169215   bus                  Haarlem, Station
# ...        ...   ...                               ...
# 1446  13630218   bus          Amsterdam, Station Noord
# 1447  13631642   bus         Assendelft, Festina Lente
# 1448  13633193   bus                  Zaandam, Station
# 1470  14979096   bus  Amsterdam, Station Bijlmer ArenA
# 1471  14979097   bus      Almere Haven, Station Buiten
#
#                                                    name  ref  \
# 31    Bus 40: Amsterdam Amstelstation => Amsterdam M...   40
# 37    Bus 365: Leiden Centraal Station => Schiphol A...  365
# 44    Bus 315: Amsterdam Station Noord => Marken Min...  315
# 52    Bus 397: Amsterdam Busstation Elandsgracht → N...  397
# 91    Bus 300: Amsterdam Bijlmer ArenA → Haarlem Sta...  300
# ...                                                 ...  ...
# 1446  Bus 292: Zaandam De Vlinder => Amsterdam Stati...  292
# 1447  Bus 63: Zaandam Station => Assendelft Festina ...   63
# 1448  Bus 63: Assendelft Festina Lente => Zaandam St...   63
# 1470  Bus 330: Almere Station Buiten => Amsterdam St...  330
# 1471  Bus 330: Amsterdam Station Bijlmer ArenA => Al...  330
#
#                      network service  \
# 31    Stadsvervoer Amsterdam    None
# 37        Zuid-Holland Noord    None
# 44                 Waterland    None
# 52     Amstelland-Meerlanden    None
# 91     Amstelland-Meerlanden    None
# ...                      ...     ...
# 1446              Zaanstreek    None
# 1447              Zaanstreek    None
# 1448              Zaanstreek    None
# 1470       Busvervoer Almere    None
# 1471       Busvervoer Almere    None
#
#                                                geometry
# 31    MULTILINESTRING ((4.91869 52.34617, 4.91868 52...
# 37    MULTILINESTRING ((4.76218 52.30830, 4.76200 52...
# 44    MULTILINESTRING ((4.93321 52.40187, 4.93311 52...
# 52    MULTILINESTRING ((4.87678 52.36968, 4.87687 52...
# 91    MULTILINESTRING ((4.94705 52.31143, 4.94711 52...
# ...                                                 ...
# 1446  MULTILINESTRING ((4.85659 52.42963, 4.85664 52...
# 1447  MULTILINESTRING ((4.81643 52.43588, 4.81651 52...
# 1448  MULTILINESTRING ((4.81436 52.43590, 4.81452 52...
# 1470  MULTILINESTRING ((5.05775 52.32570, 5.05723 52...
# 1471  MULTILINESTRING ((4.94759 52.31119, 4.94762 52...
#
# [319 rows x 8 columns]

# %%
len(city_bus_routes)
# Out:
# 319

# %%
city_bus_routes = city_bus_routes.loc[city_bus_routes.network == 'Stadsvervoer Amsterdam']
city_bus_routes = city_bus_routes.loc[city_bus_routes.service != 'night']

# %%
city_bus_routes, check_name = check_bus_routes(city_bus_stations, city_bus_routes)

# %%
replacement_dict = {
    'Amsterdam, ': '',
    'Amsterdam': '',
    'Weesp Station': 'Station',
    'Osdorp De Aker': 'Matterhorn',
    'Schiphol, Airport/Plaza': 'Schiphol, Airport',
    'De Boelelaan': 'De Boelelaan/De Klencke'
}
replacement_dict1 = {
    'Amsterdam, ': '',
    'Amsterdam': '',
}

city_bus_stations['name'] = city_bus_stations['name'].replace(replacement_dict1, regex=True).str.strip()

city_bus_stations, city_bus_routes, check_name = recheck_bus_routes(replacement_dict, city_bus_stations, city_bus_routes)

# %%
city_bus_order_route_dict, city_bus_shortest_path_pairs, city_bus_shortest_path_edges, bus_edges = bus(city_bus_stations, edges, nodes, city_bus_routes, city='Amsterdam')

# %%
city_bus_order_route_dict
# Out:
# {'Bus 15: Amsterdam Station Zuid => Amsterdam Station Sloterdijk':     id                   name                      geometry     geo_x  \
#  0    6           Station Zuid  POINT (4.8720355 52.3408188)  4.872035
#  1    3    Prinses Irenestraat  POINT (4.8682898 52.3428941)   4.86829
#  2   10           Olympiaplein   POINT (4.865862 52.3462864)  4.865862
#  3    8             Olympiaweg  POINT (4.8583469 52.3452468)  4.858347
#  4   28  Haarlemmermeerstation  POINT (4.8576315 52.3492179)  4.857632
#  5   22             Zeilstraat  POINT (4.8566667 52.3512098)  4.856667
#  6   21        Amstelveenseweg  POINT (4.8560722 52.3513667)  4.856072
#  7    1         Hoofddorpplein  POINT (4.8503895 52.3520264)   4.85039
#  8   20   Haarlemmermeerstraat  POINT (4.8503138 52.3554125)  4.850314
#  9   23          Surinameplein  POINT (4.8521842 52.3580689)  4.852184
#  10  26        Corantijnstraat  POINT (4.8532685 52.3617315)  4.853269
#  11  24             Postjesweg    POINT (4.853152 52.364773)  4.853152
#  12  12      W. Schoutenstraat  POINT (4.8523856 52.3673915)  4.852386
#  13   0          Mercatorplein  POINT (4.8499526 52.3706797)  4.849953
#  14  15    Jan van Galenstraat  POINT (4.8485665 52.3733267)  4.848566
#  15  14          Erasmusgracht  POINT (4.8469526 52.3763271)  4.846953
#  16  19     Bos en Lommerplein  POINT (4.8449299 52.3777646)   4.84493
#  17   4     Station Sloterdijk  POINT (4.8388077 52.3877091)  4.838808
#
#          geo_y
#  0   52.340819
#  1   52.342894
#  2   52.346286
#  3   52.345247
#  4   52.349218
#  5    52.35121
#  6   52.351367
#  7   52.352026
#  8   52.355412
#  9   52.358069
#  10  52.361731
#  11  52.364773
#  12  52.367391
#  13   52.37068
#  14  52.373327
#  15  52.376327
#  16  52.377765
#  17  52.387709  ,
#  'Bus 15: Amsterdam Station Sloterdijk => Amsterdam Station Zuid':     id                   name                      geometry     geo_x  \
#  0    5     Station Sloterdijk  POINT (4.8388077 52.3877091)  4.838808
#  1   20     Bos en Lommerplein  POINT (4.8464834 52.3772052)  4.846483
#  2   17          Erasmusgracht  POINT (4.8469526 52.3763271)  4.846953
#  3   19    Jan van Galenstraat  POINT (4.8487471 52.3729851)  4.848747
#  4   14          Mercatorplein  POINT (4.8500926 52.3704116)  4.850093
#  5   16      W. Schoutenstraat   POINT (4.8525714 52.366991)  4.852571
#  6   28             Postjesweg  POINT (4.8531765 52.3638554)  4.853177
#  7   30        Corantijnstraat  POINT (4.8532711 52.3615936)  4.853271
#  8    6          Surinameplein  POINT (4.8522845 52.3581748)  4.852284
#  9    3   Haarlemmermeerstraat   POINT (4.8503283 52.355174)  4.850328
#  10   2         Hoofddorpplein  POINT (4.8503895 52.3520264)   4.85039
#  11  25        Amstelveenseweg  POINT (4.8560722 52.3513667)  4.856072
#  12  26             Zeilstraat  POINT (4.8566667 52.3512098)  4.856667
#  13  31  Haarlemmermeerstation  POINT (4.8573618 52.3488918)  4.857362
#  14  10             Olympiaweg  POINT (4.8586293 52.3452866)  4.858629
#  15  12           Olympiaplein  POINT (4.8666383 52.3463918)  4.866638
#  16   4    Prinses Irenestraat  POINT (4.8682441 52.3421193)  4.868244
#  17   9           Station Zuid  POINT (4.8727824 52.3407386)  4.872782
#
#          geo_y
#  0   52.387709
#  1   52.377205
#  2   52.376327
#  3   52.372985
#  4   52.370412
#  5   52.366991
#  6   52.363855
#  7   52.361594
#  8   52.358175
#  9   52.355174
#  10  52.352026
#  11  52.351367
#  12   52.35121
#  13  52.348892
#  14  52.345287
#  15  52.346392
#  16  52.342119
#  17  52.340739  ,
#  'Bus 18: Amsterdam Slotervaart => Amsterdam Centraal Station':     id                         name                      geometry     geo_x  \
#  0    0                   Louweshoek  POINT (4.8231898 52.3462931)   4.82319
#  1   40                    Louwesweg   POINT (4.825072 52.3467202)  4.825072
#  2   43           Johan Huizingalaan  POINT (4.8274702 52.3492178)   4.82747
#  3   38                    Sierplein  POINT (4.8273532 52.3551327)  4.827353
#  4   14            Cornelis Lelylaan  POINT (4.8276261 52.3579398)  4.827626
#  5    9         Justus Lipsiusstraat  POINT (4.8272114 52.3615163)  4.827211
#  6   11             Robert Fruinlaan  POINT (4.8300671 52.3640144)  4.830067
#  7   31             Jan Tooropstraat  POINT (4.8357251 52.3640713)  4.835725
#  8   33            Derkinderenstraat  POINT (4.8395939 52.3641096)  4.839594
#  9    2               Nachtwachtlaan  POINT (4.8433625 52.3641637)  4.843362
#  10  48                   Postjesweg    POINT (4.853152 52.364773)  4.853152
#  11  46            W. Schoutenstraat  POINT (4.8523856 52.3673915)  4.852386
#  12  45                Mercatorplein  POINT (4.8514813 52.3702456)  4.851481
#  13  52             Marco Polostraat  POINT (4.8555007 52.3709463)  4.855501
#  14  16           Jan Evertsenstraat  POINT (4.8593919 52.3720492)  4.859392
#  15  54          Jan van Galenstraat  POINT (4.8602804 52.3748883)   4.86028
#  16  10                  Markthallen  POINT (4.8668821 52.3757035)  4.866882
#  17  29  Gillis van Ledenberchstraat  POINT (4.8708584 52.3751208)  4.870858
#  18   6    Frederik Hendrikplantsoen   POINT (4.8753059 52.379004)  4.875306
#  19   7           Kostverlorenstraat  POINT (4.8717234 52.3796847)  4.871723
#  20  17           Van Beuningenplein  POINT (4.8711423 52.3813613)  4.871142
#  21  18           Van der Hoopstraat  POINT (4.8703982 52.3833567)  4.870398
#  22  36     Van Limburg Stirumstraat   POINT (4.875274 52.3854642)  4.875274
#  23  39              Haarlemmerplein  POINT (4.8836597 52.3851357)   4.88366
#  24  27          Buiten Oranjestraat  POINT (4.8880371 52.3831468)  4.888037
#  25  28        Buiten Brouwersstraat  POINT (4.8915473 52.3815327)  4.891547
#  26  26             Centraal Station  POINT (4.8996024 52.3802901)  4.899602
#
#          geo_y
#  0   52.346293
#  1    52.34672
#  2   52.349218
#  3   52.355133
#  4    52.35794
#  5   52.361516
#  6   52.364014
#  7   52.364071
#  8    52.36411
#  9   52.364164
#  10  52.364773
#  11  52.367391
#  12  52.370246
#  13  52.370946
#  14  52.372049
#  15  52.374888
#  16  52.375704
#  17  52.375121
#  18  52.379004
#  19  52.379685
#  20  52.381361
#  21  52.383357
#  22  52.385464
#  23  52.385136
#  24  52.383147
#  25  52.381533
#  26   52.38029  ,
#  'Bus 18: Amsterdam Centraal Station => Amsterdam Slotervaart':     id                         name                      geometry     geo_x  \
#  0    8             Centraal Station  POINT (4.8991236 52.3801466)  4.899124
#  1   12        Buiten Brouwersstraat  POINT (4.8912917 52.3816447)  4.891292
#  2   13          Buiten Oranjestraat  POINT (4.8878285 52.3832817)  4.887829
#  3   31              Haarlemmerplein  POINT (4.8834561 52.3848683)  4.883456
#  4    6    Frederik Hendrikplantsoen   POINT (4.874102 52.3787511)  4.874102
#  5   29     Van Limburg Stirumstraat  POINT (4.8747388 52.3854544)  4.874739
#  6   28           Van der Hoopstraat  POINT (4.8703571 52.3832599)  4.870357
#  7   26           Van Beuningenplein  POINT (4.8711139 52.3812208)  4.871114
#  8   27           Kostverlorenstraat   POINT (4.8717048 52.379535)  4.871705
#  9   21  Gillis van Ledenberchstraat  POINT (4.8705438 52.3752057)  4.870544
#  10  10                  Markthallen   POINT (4.866602 52.3757366)  4.866602
#  11  47          Jan van Galenstraat  POINT (4.8586666 52.3743099)  4.858667
#  12  15           Jan Evertsenstraat  POINT (4.8593919 52.3720492)  4.859392
#  13  45             Marco Polostraat   POINT (4.855096 52.3708761)  4.855096
#  14  39                Mercatorplein  POINT (4.8514813 52.3702456)  4.851481
#  15  41            W. Schoutenstraat   POINT (4.8525714 52.366991)  4.852571
#  16  42                   Postjesweg    POINT (4.853152 52.364773)  4.853152
#  17   7                     Hoofdweg  POINT (4.8524952 52.3643025)  4.852495
#  18   4               Nachtwachtlaan  POINT (4.8431013 52.3641646)  4.843101
#  19  25            Derkinderenstraat   POINT (4.839315 52.3641068)  4.839315
#  20  23             Jan Tooropstraat  POINT (4.8353443 52.3640666)  4.835344
#  21   2             Robert Fruinlaan  POINT (4.8291209 52.3640082)  4.829121
#  22   9         Justus Lipsiusstraat  POINT (4.8270967 52.3607918)  4.827097
#  23   1            Cornelis Lelylaan  POINT (4.8268513 52.3576299)  4.826851
#  24   5                    Sierplein  POINT (4.8273557 52.3548704)  4.827356
#  25  36           Johan Huizingalaan  POINT (4.8274736 52.3491043)  4.827474
#  26  35                    Louwesweg  POINT (4.8242542 52.3466689)  4.824254
#  27   0                   Louweshoek  POINT (4.8231898 52.3462931)   4.82319
#
#          geo_y
#  0   52.380147
#  1   52.381645
#  2   52.383282
#  3   52.384868
#  4   52.378751
#  5   52.385454
#  6    52.38326
#  7   52.381221
#  8   52.379535
#  9   52.375206
#  10  52.375737
#  11   52.37431
#  12  52.372049
#  13  52.370876
#  14  52.370246
#  15  52.366991
#  16  52.364773
#  17  52.364303
#  18  52.364165
#  19  52.364107
#  20  52.364067
#  21  52.364008
#  22  52.360792
#  23   52.35763
#  24   52.35487
#  25  52.349104
#  26  52.346669
#  27  52.346293  ,
#  'Bus 21: Amsterdam Geuzenveld => Amsterdam Centraal Station':     id                       name                      geometry     geo_x  \
#  0    0   De Savornin Lohmanstraat  POINT (4.8007267 52.3754569)  4.800727
#  1   19         Michel de Klerkhof    POINT (4.797686 52.376336)  4.797686
#  2   18       Sam van Houtenstraat  POINT (4.7979455 52.3796692)  4.797945
#  3    6             Aalbersestraat  POINT (4.7988976 52.3823436)  4.798898
#  4    9       Jacob Cabeliaustraat   POINT (4.8041858 52.382434)  4.804186
#  5    8        Dr. H. Colijnstraat  POINT (4.8057553 52.3824573)  4.805755
#  6   23     Antony Moddermanstraat  POINT (4.8145966 52.3833501)  4.814597
#  7   34              Plein '40-'45   POINT (4.8225314 52.381242)  4.822531
#  8   32   Burgemeester Eliasstraat  POINT (4.8275093 52.3804641)  4.827509
#  9   35    Burgemeester Fockstraat  POINT (4.8332484 52.3795645)  4.833248
#  10  30  Burgemeester de Vlugtlaan   POINT (4.838306 52.3787739)  4.838306
#  11  37         Bos en Lommerplein  POINT (4.8470139 52.3781334)  4.847014
#  12  40              Egidiusstraat  POINT (4.8514957 52.3790411)  4.851496
#  13   7           Bos en Lommerweg  POINT (4.8552199 52.3810375)   4.85522
#  14  44              Solebaystraat  POINT (4.8560523 52.3850963)  4.856052
#  15  43                  Vredenhof  POINT (4.8638628 52.3852539)  4.863863
#  16  47             Van Hallstraat   POINT (4.868721 52.3853033)  4.868721
#  17  27   Van Limburg Stirumstraat   POINT (4.875274 52.3854642)  4.875274
#  18  29            Haarlemmerplein  POINT (4.8836597 52.3851357)   4.88366
#  19  24        Buiten Oranjestraat  POINT (4.8880371 52.3831468)  4.888037
#  20  25      Buiten Brouwersstraat  POINT (4.8915473 52.3815327)  4.891547
#  21  17           Centraal Station  POINT (4.8996024 52.3802901)  4.899602
#
#          geo_y
#  0   52.375457
#  1   52.376336
#  2   52.379669
#  3   52.382344
#  4   52.382434
#  5   52.382457
#  6    52.38335
#  7   52.381242
#  8   52.380464
#  9   52.379565
#  10  52.378774
#  11  52.378133
#  12  52.379041
#  13  52.381037
#  14  52.385096
#  15  52.385254
#  16  52.385303
#  17  52.385464
#  18  52.385136
#  19  52.383147
#  20  52.381533
#  21   52.38029  ,
#  'Bus 21: Amsterdam Centraal Station => Amsterdam Geuzenveld':     id                       name                      geometry     geo_x  \
#  0    1           Centraal Station  POINT (4.8991236 52.3801466)  4.899124
#  1    2      Buiten Brouwersstraat  POINT (4.8912917 52.3816447)  4.891292
#  2    3        Buiten Oranjestraat  POINT (4.8878285 52.3832817)  4.887829
#  3   21            Haarlemmerplein  POINT (4.8834561 52.3848683)  4.883456
#  4   19   Van Limburg Stirumstraat  POINT (4.8747388 52.3854544)  4.874739
#  5   35             Van Hallstraat  POINT (4.8675174 52.3853169)  4.867517
#  6   39                  Vredenhof   POINT (4.862224 52.3852115)  4.862224
#  7   38              Solebaystraat  POINT (4.8554756 52.3843152)  4.855476
#  8   32           Bos en Lommerweg  POINT (4.8537807 52.3801819)  4.853781
#  9   34              Egidiusstraat   POINT (4.850926 52.3789239)  4.850926
#  10  31         Bos en Lommerplein  POINT (4.8449299 52.3777646)   4.84493
#  11  24  Burgemeester de Vlugtlaan  POINT (4.8371983 52.3789475)  4.837198
#  12  29    Burgemeester Fockstraat  POINT (4.8312662 52.3798768)  4.831266
#  13  26   Burgemeester Eliasstraat  POINT (4.8258007 52.3807324)  4.825801
#  14   0              Plein '40-'45  POINT (4.8204295 52.3816162)   4.82043
#  15  15     Antony Moddermanstraat  POINT (4.8133913 52.3833335)  4.813391
#  16   6        Dr. H. Colijnstraat  POINT (4.8057553 52.3824573)  4.805755
#  17   7       Jacob Cabeliaustraat   POINT (4.8041858 52.382434)  4.804186
#  18   4             Aalbersestraat  POINT (4.7978176 52.3820714)  4.797818
#  19  13       Sam van Houtenstraat  POINT (4.7979801 52.3787705)   4.79798
#  20  11         Michel de Klerkhof    POINT (4.797686 52.376336)  4.797686
#  21  14               Nolensstraat  POINT (4.8009791 52.3752305)  4.800979
#
#          geo_y
#  0   52.380147
#  1   52.381645
#  2   52.383282
#  3   52.384868
#  4   52.385454
#  5   52.385317
#  6   52.385211
#  7   52.384315
#  8   52.380182
#  9   52.378924
#  10  52.377765
#  11  52.378948
#  12  52.379877
#  13  52.380732
#  14  52.381616
#  15  52.383333
#  16  52.382457
#  17  52.382434
#  18  52.382071
#  19  52.378771
#  20  52.376336
#  21  52.375231  ,
#  'Bus 22: Amsterdam Station Sloterdijk => Amsterdam Muiderpoortstation':     id                   name                      geometry     geo_x  \
#  0   15     Station Sloterdijk  POINT (4.8387698 52.3880096)   4.83877
#  1    3          La Guardiaweg  POINT (4.8403476 52.3915236)  4.840348
#  2   24               Kabelweg  POINT (4.8486876 52.3917417)  4.848688
#  3   14             Contactweg  POINT (4.8567562 52.3920094)  4.856756
#  4   13       Spaarndammerdijk   POINT (4.8620399 52.392447)   4.86204
#  5   39             Zaanstraat    POINT (4.86985 52.3928793)   4.86985
#  6   40     Spaarndammerstraat  POINT (4.8771658 52.3923825)  4.877166
#  7   17       Assendelftstraat  POINT (4.8798373 52.3888866)  4.879837
#  8   19            Nassauplein  POINT (4.8814896 52.3852578)   4.88149
#  9   38        Haarlemmerplein  POINT (4.8836597 52.3851357)   4.88366
#  10  33    Buiten Oranjestraat  POINT (4.8880371 52.3831468)  4.888037
#  11  34  Buiten Brouwersstraat  POINT (4.8915473 52.3815327)  4.891547
#  12  21       Centraal Station  POINT (4.9025698 52.3792093)   4.90257
#  13   2      Prins Hendrikkade   POINT (4.9065518 52.373463)  4.906552
#  14   6           Kadijksplein  POINT (4.9134932 52.3708094)  4.913493
#  15  10      Kattenburgerplein  POINT (4.9163389 52.3706236)  4.916339
#  16   4     Wittenburgergracht  POINT (4.9207898 52.3691024)   4.92079
#  17   0     Oostenburgergracht  POINT (4.9248011 52.3677345)  4.924801
#  18   7              Het Funen   POINT (4.931555 52.3674762)  4.931555
#  19  32                Veelaan  POINT (4.9394896 52.3676768)   4.93949
#  20  31          Zeeburgerdijk   POINT (4.939513 52.3654344)  4.939513
#  21  16              Javaplein  POINT (4.9395347 52.3640185)  4.939535
#  22  41         Molukkenstraat  POINT (4.9388488 52.3615252)  4.938849
#  23  43     Muiderpoortstation  POINT (4.9328692 52.3613043)  4.932869
#
#          geo_y
#  0    52.38801
#  1   52.391524
#  2   52.391742
#  3   52.392009
#  4   52.392447
#  5   52.392879
#  6   52.392382
#  7   52.388887
#  8   52.385258
#  9   52.385136
#  10  52.383147
#  11  52.381533
#  12  52.379209
#  13  52.373463
#  14  52.370809
#  15  52.370624
#  16  52.369102
#  17  52.367734
#  18  52.367476
#  19  52.367677
#  20  52.365434
#  21  52.364019
#  22  52.361525
#  23  52.361304  ,
#  'Bus 22: Amsterdam Muiderpoortstation => Amsterdam Station Sloterdijk':     id                   name                      geometry     geo_x  \
#  0   33                Veelaan  POINT (4.9394896 52.3676768)   4.93949
#  1   32          Zeeburgerdijk   POINT (4.939513 52.3654344)  4.939513
#  2   18              Javaplein  POINT (4.9395347 52.3640185)  4.939535
#  3   40         Molukkenstraat  POINT (4.9388488 52.3615252)  4.938849
#  4   42     Muiderpoortstation  POINT (4.9337209 52.3610843)  4.933721
#  5   10              Het Funen  POINT (4.9309177 52.3674666)  4.930918
#  6   13     Oostenburgergracht  POINT (4.9243625 52.3678773)  4.924362
#  7    7     Wittenburgergracht  POINT (4.9196296 52.3694986)   4.91963
#  8   12      Kattenburgerplein   POINT (4.915926 52.3707527)  4.915926
#  9    3           Kadijksplein   POINT (4.913366 52.3709246)  4.913366
#  10  36              IJ tunnel  POINT (4.9094406 52.3722719)  4.909441
#  11   2      Prins Hendrikkade  POINT (4.9023285 52.3767988)  4.902329
#  12  23       Centraal Station  POINT (4.8991236 52.3801466)  4.899124
#  13  24  Buiten Brouwersstraat  POINT (4.8912917 52.3816447)  4.891292
#  14  25    Buiten Oranjestraat  POINT (4.8878285 52.3832817)  4.887829
#  15  37        Haarlemmerplein  POINT (4.8834561 52.3848683)  4.883456
#  16  22            Nassauplein  POINT (4.8814716 52.3853917)  4.881472
#  17  20       Assendelftstraat  POINT (4.8794708 52.3893574)  4.879471
#  18  14     Spaarndammerstraat   POINT (4.877647 52.3920895)  4.877647
#  19  39             Zaanstraat  POINT (4.8701947 52.3929109)  4.870195
#  20  15       Spaarndammerdijk  POINT (4.8603787 52.3925617)  4.860379
#  21  16             Contactweg  POINT (4.8543711 52.3921091)  4.854371
#  22  26               Kabelweg  POINT (4.8482571 52.3920169)  4.848257
#  23   5          La Guardiaweg  POINT (4.8400239 52.3918607)  4.840024
#  24  17     Station Sloterdijk  POINT (4.8387698 52.3880096)   4.83877
#
#          geo_y
#  0   52.367677
#  1   52.365434
#  2   52.364019
#  3   52.361525
#  4   52.361084
#  5   52.367467
#  6   52.367877
#  7   52.369499
#  8   52.370753
#  9   52.370925
#  10  52.372272
#  11  52.376799
#  12  52.380147
#  13  52.381645
#  14  52.383282
#  15  52.384868
#  16  52.385392
#  17  52.389357
#  18  52.392089
#  19  52.392911
#  20  52.392562
#  21  52.392109
#  22  52.392017
#  23  52.391861
#  24   52.38801  ,
#  'Bus 231: Amsterdam Abberdaan => Amsterdam Station Sloterdijk':     id                name                      geometry     geo_x      geo_y
#  0    5           Abberdaan  POINT (4.7809214 52.3918165)  4.780921  52.391816
#  1    9          Pleimuiden  POINT (4.7850098 52.3918246)   4.78501  52.391825
#  2    8            Bolstoen   POINT (4.7886091 52.391827)  4.788609  52.391827
#  3    7           Jarmuiden  POINT (4.7905903 52.3909185)   4.79059  52.390918
#  4    2            Bornhout  POINT (4.7945486 52.3962536)  4.794549  52.396254
#  5   10        Westpoortweg  POINT (4.7952386 52.3976228)  4.795239  52.397623
#  6    1           Hornhaven    POINT (4.80881 52.3947044)   4.80881  52.394704
#  7    3             Oderweg  POINT (4.8215721 52.3901284)  4.821572  52.390128
#  8   13          Kapoeasweg    POINT (4.8279492 52.39014)  4.827949   52.39014
#  9    0       Kastrupstraat   POINT (4.8334122 52.390143)  4.833412  52.390143
#  10   4  Station Sloterdijk  POINT (4.8388353 52.3874811)  4.838835  52.387481,
#  'Bus 231: Amsterdam Station Sloterdijk => Amsterdam Abberdaan':    id                name                      geometry     geo_x      geo_y
#  0  13  Station Sloterdijk  POINT (4.8362683 52.3893183)  4.836268  52.389318
#  1   6       Kastrupstraat  POINT (4.8331183 52.3901425)  4.833118  52.390143
#  2  11          Kapoeasweg   POINT (4.8269381 52.390139)  4.826938  52.390139
#  3  10             Oderweg  POINT (4.8200763 52.3902005)  4.820076    52.3902
#  4   9           Hornhaven  POINT (4.8074785 52.3949806)  4.807479  52.394981
#  5   2        Westpoortweg  POINT (4.7943425 52.3969716)  4.794342  52.396972
#  6   8            Bornhout  POINT (4.7932844 52.3956958)  4.793284  52.395696
#  7   1             Herwijk  POINT (4.7873308 52.3956862)  4.787331  52.395686
#  8   7         Scharenburg  POINT (4.7796793 52.3956813)  4.779679  52.395681
#  9   5           Abberdaan  POINT (4.7809214 52.3918165)  4.780921  52.391816,
#  'Bus 240: Amsterdam Muiderpoortstation => Amsterdam Amstelstation':     id                  name                      geometry     geo_x  \
#  0   25    Muiderpoortstation  POINT (4.9337209 52.3610843)  4.933721
#  1   24        Molukkenstraat    POINT (4.939261 52.361582)  4.939261
#  2   19         Valentijnkade  POINT (4.9407792 52.3588673)  4.940779
#  3    6   C. Mac Gillavrylaan  POINT (4.9446705 52.3576513)   4.94467
#  4    5    Science Park Terra   POINT (4.957594 52.3540272)  4.957594
#  5   11     Science Park Aqua  POINT (4.9540888 52.3560016)  4.954089
#  6   15      Science Park Aer  POINT (4.9527173 52.3551787)  4.952717
#  7   21          Science Park  POINT (4.9507177 52.3545954)  4.950718
#  8    8  Station Science Park  POINT (4.9477777 52.3523366)  4.947778
#  9    4       Linnaeusparkweg  POINT (4.9416577 52.3487013)  4.941658
#  10  12             Kruislaan  POINT (4.9389198 52.3470215)   4.93892
#  11   0     Pekelharingstraat   POINT (4.9363067 52.345433)  4.936307
#  12  14           Lorentzlaan  POINT (4.9313498 52.3463235)   4.93135
#  13  10         Maxwellstraat   POINT (4.9286576 52.347239)  4.928658
#  14   9          Fizeaustraat   POINT (4.9243303 52.345937)   4.92433
#  15  22         Amstelstation  POINT (4.9190225 52.3462721)  4.919022
#
#          geo_y
#  0   52.361084
#  1   52.361582
#  2   52.358867
#  3   52.357651
#  4   52.354027
#  5   52.356002
#  6   52.355179
#  7   52.354595
#  8   52.352337
#  9   52.348701
#  10  52.347021
#  11  52.345433
#  12  52.346323
#  13  52.347239
#  14  52.345937
#  15  52.346272  ,
#  'Bus 240: Amsterdam Amstelstation => Amsterdam Muiderpoortstation':     id                  name                      geometry     geo_x  \
#  0   23         Amstelstation  POINT (4.9186931 52.3461675)  4.918693
#  1    2          Fizeaustraat  POINT (4.9246384 52.3459384)  4.924638
#  2    9         Maxwellstraat   POINT (4.9286576 52.347239)  4.928658
#  3    1           Lorentzlaan  POINT (4.9319663 52.3459101)  4.931966
#  4    3     Pekelharingstraat  POINT (4.9364934 52.3455479)  4.936493
#  5   14             Kruislaan  POINT (4.9396689 52.3474808)  4.939669
#  6   12       Linnaeusparkweg   POINT (4.942695 52.3492498)  4.942695
#  7    4    Science Park Terra   POINT (4.957594 52.3540272)  4.957594
#  8   10     Science Park Aqua  POINT (4.9540888 52.3560016)  4.954089
#  9   11      Science Park Aer  POINT (4.9521127 52.3547911)  4.952113
#  10  22          Science Park  POINT (4.9507177 52.3545954)  4.950718
#  11   7  Station Science Park  POINT (4.9479814 52.3523774)  4.947981
#  12   6   C. Mac Gillavrylaan  POINT (4.9442456 52.3576753)  4.944246
#  13  21         Valentijnkade   POINT (4.940737 52.3589863)  4.940737
#  14  24        Molukkenstraat  POINT (4.9388488 52.3615252)  4.938849
#  15  26    Muiderpoortstation  POINT (4.9328692 52.3613043)  4.932869
#
#          geo_y
#  0   52.346167
#  1   52.345938
#  2   52.347239
#  3    52.34591
#  4   52.345548
#  5   52.347481
#  6    52.34925
#  7   52.354027
#  8   52.356002
#  9   52.354791
#  10  52.354595
#  11  52.352377
#  12  52.357675
#  13  52.358986
#  14  52.361525
#  15  52.361304  ,
#  'Bus 245: Amsterdam Molenwijk => Schiphol Zuid':     id                         name                      geometry     geo_x  \
#  0    3                Oostzanerdijk  POINT (4.8814222 52.4202605)  4.881422
#  1   45                 Lange Vonder  POINT (4.8964306 52.4219261)  4.896431
#  2   88  Pieter A van Heyningestraat  POINT (4.8997514 52.4220813)  4.899751
#  3    9                Vorticellaweg  POINT (4.9080085 52.4197673)  4.908009
#  4   47                  Kadoelenpad  POINT (4.9111874 52.4133568)  4.911187
#  5   74          Banne Buikslootlaan  POINT (4.9178781 52.4079484)  4.917878
#  6   32                 Oosterlengte  POINT (4.9223735 52.4058331)  4.922373
#  7   21           G.J. Scheurleerweg  POINT (4.9290462 52.4037927)  4.929046
#  8   64                Station Noord  POINT (4.9321528 52.4026618)  4.932153
#  9   23          Buikslotermeerplein  POINT (4.9396376 52.3994953)  4.939638
#  10  24                J. Drijverweg   POINT (4.9445796 52.399403)   4.94458
#  11   2               Beemsterstraat  POINT (4.9521646 52.3971457)  4.952165
#  12  19         Dijkmanshuizenstraat  POINT (4.9548208 52.3955624)  4.954821
#  13  46               Volendammerweg  POINT (4.9570777 52.3925001)  4.957078
#  14  36              Hilversumstraat  POINT (4.9591812 52.3896887)  4.959181
#  15   1                    Volkstuin  POINT (4.9682812 52.3871698)  4.968281
#  16  20                     Liergouw  POINT (4.9705641 52.3829186)  4.970564
#  17  31                 Zuiderzeeweg   POINT (4.962287 52.3713671)  4.962287
#  18  82                 Insulindeweg  POINT (4.9476591 52.3647503)  4.947659
#  19  80               Soembawastraat  POINT (4.9433815 52.3621563)  4.943382
#  20  75               Molukkenstraat  POINT (4.9388488 52.3615252)  4.938849
#  21  79           Muiderpoortstation  POINT (4.9328692 52.3613043)  4.932869
#  22  85                 Dapperstraat  POINT (4.9289531 52.3609165)  4.928953
#  23  87               Linnaeusstraat   POINT (4.924905 52.3599316)  4.924905
#  24  38                  Beukenplein  POINT (4.9181204 52.3570535)   4.91812
#  25  40                  Krugerplein   POINT (4.9208273 52.352987)  4.920827
#  26   6             James Wattstraat  POINT (4.9232838 52.3511829)  4.923284
#  27  30                Maxwellstraat   POINT (4.9286576 52.347239)  4.928658
#  28  29                 Fizeaustraat   POINT (4.9243303 52.345937)   4.92433
#  29  25                Amstelstation  POINT (4.9193827 52.3468042)  4.919383
#  30  66                   Amsteldijk  POINT (4.9110032 52.3470988)  4.911003
#  31  73                Victorieplein  POINT (4.9056787 52.3463485)  4.905679
#  32  67                   Waalstraat  POINT (4.9005987 52.3444516)  4.900599
#  33  68                   Maasstraat  POINT (4.8963085 52.3428958)  4.896308
#  34  71                 Dintelstraat  POINT (4.8930026 52.3419109)  4.893003
#  35  18               Anderlechtlaan  POINT (4.8138897 52.3353049)   4.81389
#  36  17               Oude Haagseweg  POINT (4.8097928 52.3334159)  4.809793
#  37  22                 Koekoekslaan  POINT (4.8026256 52.3292258)  4.802626
#  38  44                  Cateringweg  POINT (4.7996812 52.3230573)  4.799681
#  39  50     Knooppunt Schiphol Noord  POINT (4.7927196 52.3221443)   4.79272
#  40  48                  Elzenhof/P5  POINT (4.7855413 52.3237806)  4.785541
#  41  49           P40 Parkeerterrein  POINT (4.7748546 52.3217504)  4.774855
#  42  90            Schiphol, Airport  POINT (4.7596179 52.3095457)  4.759618
#  43  28             P12/Vrachtgebouw  POINT (4.7538941 52.3045031)  4.753894
#  44  11               Schipholgebouw  POINT (4.7495022 52.3028155)  4.749502
#  45  12      Schiphol Zuid, Uiverweg   POINT (4.743576 52.3001981)  4.743576
#  46  27   Schiphol Zuid, Pelikaanweg   POINT (4.7447597 52.297974)   4.74476
#  47  14     Schiphol Zuid, Toekanweg   POINT (4.737814 52.2952583)  4.737814
#
#          geo_y
#  0    52.42026
#  1   52.421926
#  2   52.422081
#  3   52.419767
#  4   52.413357
#  5   52.407948
#  6   52.405833
#  7   52.403793
#  8   52.402662
#  9   52.399495
#  10  52.399403
#  11  52.397146
#  12  52.395562
#  13    52.3925
#  14  52.389689
#  15   52.38717
#  16  52.382919
#  17  52.371367
#  18   52.36475
#  19  52.362156
#  20  52.361525
#  21  52.361304
#  22  52.360917
#  23  52.359932
#  24  52.357053
#  25  52.352987
#  26  52.351183
#  27  52.347239
#  28  52.345937
#  29  52.346804
#  30  52.347099
#  31  52.346348
#  32  52.344452
#  33  52.342896
#  34  52.341911
#  35  52.335305
#  36  52.333416
#  37  52.329226
#  38  52.323057
#  39  52.322144
#  40  52.323781
#  41   52.32175
#  42  52.309546
#  43  52.304503
#  44  52.302816
#  45  52.300198
#  46  52.297974
#  47  52.295258  ,
#  'Bus 246: Amsterdam Oostelijke Eilanden => Schiphol Zuid':     id                         name                      geometry     geo_x  \
#  0   58                   Borneolaan  POINT (4.9392596 52.3711842)   4.93926
#  1   59          C. van Eesterenlaan  POINT (4.9388462 52.3735497)  4.938846
#  2   57                   Azartplein  POINT (4.9373175 52.3768151)  4.937317
#  3   17                 Majanggracht  POINT (4.9296448 52.3789786)  4.929645
#  4   19                 Tosaristraat   POINT (4.923057 52.3794834)  4.923057
#  5   52             Jan Schaeferbrug  POINT (4.9217586 52.3765349)  4.921759
#  6   16           Kattenburgerstraat   POINT (4.9184891 52.372718)  4.918489
#  7    1                 Kadijksplein   POINT (4.913366 52.3709246)  4.913366
#  8   29                Waterlooplein  POINT (4.9045597 52.3687054)   4.90456
#  9   28                 Weesperplein  POINT (4.9077118 52.3614715)  4.907712
#  10  54                Van Woustraat  POINT (4.9008536 52.3547009)  4.900854
#  11  53   Tweede van der Helststraat  POINT (4.8949324 52.3533244)  4.894932
#  12  51         Cornelis Troostplein  POINT (4.8915571 52.3502994)  4.891557
#  13  64         Van Hilligaertstraat  POINT (4.8914953 52.3498389)  4.891495
#  14  24                Scheldestraat  POINT (4.8896383 52.3473897)  4.889638
#  15  23                   Apollolaan   POINT (4.881967 52.3481494)  4.881967
#  16  21              Beethovenstraat   POINT (4.8782207 52.346969)  4.878221
#  17  50                   Stadionweg  POINT (4.8768476 52.3466757)  4.876848
#  18  49          Prinses Irenestraat  POINT (4.8768045 52.3426144)  4.876805
#  19  25      Willem van Weldammelaan  POINT (4.8761948 52.3350039)  4.876195
#  20  63  De Boelelaan / Parnassusweg  POINT (4.8697829 52.3350684)  4.869783
#  21   3            De Boelelaan / VU  POINT (4.8662755 52.3350556)  4.866276
#  22  33             VUmc Hoofdingang  POINT (4.8600616 52.3351796)  4.860062
#  23  32              Amstelveenseweg  POINT (4.8587227 52.3391618)  4.858723
#  24  11               Anderlechtlaan  POINT (4.8138897 52.3353049)   4.81389
#  25  10               Oude Haagseweg  POINT (4.8097928 52.3334159)  4.809793
#  26  12                 Koekoekslaan  POINT (4.8026256 52.3292258)  4.802626
#  27  27                  Cateringweg  POINT (4.7996812 52.3230573)  4.799681
#  28  35     Knooppunt Schiphol Noord  POINT (4.7927196 52.3221443)   4.79272
#  29  30                  Elzenhof/P5  POINT (4.7855413 52.3237806)  4.785541
#  30  31           P40 Parkeerterrein  POINT (4.7748546 52.3217504)  4.774855
#  31  60            Schiphol, Airport  POINT (4.7596179 52.3095457)  4.759618
#  32  15             P12/Vrachtgebouw  POINT (4.7538941 52.3045031)  4.753894
#  33   4               Schipholgebouw  POINT (4.7495022 52.3028155)  4.749502
#  34   5      Schiphol Zuid, Uiverweg   POINT (4.743576 52.3001981)  4.743576
#  35  14   Schiphol Zuid, Pelikaanweg   POINT (4.7447597 52.297974)   4.74476
#  36   7     Schiphol Zuid, Toekanweg   POINT (4.737814 52.2952583)  4.737814
#
#          geo_y
#  0   52.371184
#  1    52.37355
#  2   52.376815
#  3   52.378979
#  4   52.379483
#  5   52.376535
#  6   52.372718
#  7   52.370925
#  8   52.368705
#  9   52.361472
#  10  52.354701
#  11  52.353324
#  12  52.350299
#  13  52.349839
#  14   52.34739
#  15  52.348149
#  16  52.346969
#  17  52.346676
#  18  52.342614
#  19  52.335004
#  20  52.335068
#  21  52.335056
#  22   52.33518
#  23  52.339162
#  24  52.335305
#  25  52.333416
#  26  52.329226
#  27  52.323057
#  28  52.322144
#  29  52.323781
#  30   52.32175
#  31  52.309546
#  32  52.304503
#  33  52.302816
#  34  52.300198
#  35  52.297974
#  36  52.295258  ,
#  'Bus 247: Amsterdam Bos en Lommer => Schiphol Zuid':     id                        name                      geometry     geo_x  \
#  0   51          Bos en Lommerplein  POINT (4.8470139 52.3781334)  4.847014
#  1   53               Egidiusstraat  POINT (4.8514957 52.3790411)  4.851496
#  2   15            Bos en Lommerweg  POINT (4.8552199 52.3810375)   4.85522
#  3   24  Charlotte de Bourbonstraat  POINT (4.8598032 52.3810118)  4.859803
#  4   26               De Rijpgracht  POINT (4.8628121 52.3771875)  4.862812
#  5   61         Jan van Galenstraat  POINT (4.8586666 52.3743099)  4.858667
#  6   14          Jan Evertsenstraat  POINT (4.8593919 52.3720492)  4.859392
#  7   59            Marco Polostraat   POINT (4.855096 52.3708761)  4.855096
#  8   48               Mercatorplein  POINT (4.8514813 52.3702456)  4.851481
#  9   50           W. Schoutenstraat   POINT (4.8525714 52.366991)  4.852571
#  10  56                  Postjesweg  POINT (4.8531765 52.3638554)  4.853177
#  11  58             Corantijnstraat  POINT (4.8532711 52.3615936)  4.853271
#  12  18               Surinameplein  POINT (4.8522845 52.3581748)  4.852284
#  13  12            Station Lelylaan  POINT (4.8346148 52.3566737)  4.834615
#  14   2                   Sierplein  POINT (4.8273557 52.3548704)  4.827356
#  15  45          Johan Huizingalaan  POINT (4.8274736 52.3491043)  4.827474
#  16  44                   Louwesweg  POINT (4.8242542 52.3466689)  4.824254
#  17  22               Antwerpenbaan  POINT (4.8159759 52.3458066)  4.815976
#  18  66                 Belgiëplein   POINT (4.8114068 52.344479)  4.811407
#  19  10              Anderlechtlaan  POINT (4.8138897 52.3353049)   4.81389
#  20   9              Oude Haagseweg  POINT (4.8097928 52.3334159)  4.809793
#  21  11                Koekoekslaan  POINT (4.8026256 52.3292258)  4.802626
#  22  21                 Cateringweg  POINT (4.7996812 52.3230573)  4.799681
#  23  29    Knooppunt Schiphol Noord  POINT (4.7927196 52.3221443)   4.79272
#  24  27                 Elzenhof/P5  POINT (4.7855413 52.3237806)  4.785541
#  25  28          P40 Parkeerterrein  POINT (4.7748546 52.3217504)  4.774855
#  26  63           Schiphol, Airport  POINT (4.7596179 52.3095457)  4.759618
#  27  17            P12/Vrachtgebouw  POINT (4.7538941 52.3045031)  4.753894
#  28   3              Schipholgebouw  POINT (4.7495022 52.3028155)  4.749502
#  29   4     Schiphol Zuid, Uiverweg   POINT (4.743576 52.3001981)  4.743576
#  30  16  Schiphol Zuid, Pelikaanweg   POINT (4.7447597 52.297974)   4.74476
#  31   6    Schiphol Zuid, Toekanweg   POINT (4.737814 52.2952583)  4.737814
#
#          geo_y
#  0   52.378133
#  1   52.379041
#  2   52.381037
#  3   52.381012
#  4   52.377187
#  5    52.37431
#  6   52.372049
#  7   52.370876
#  8   52.370246
#  9   52.366991
#  10  52.363855
#  11  52.361594
#  12  52.358175
#  13  52.356674
#  14   52.35487
#  15  52.349104
#  16  52.346669
#  17  52.345807
#  18  52.344479
#  19  52.335305
#  20  52.333416
#  21  52.329226
#  22  52.323057
#  23  52.322144
#  24  52.323781
#  25   52.32175
#  26  52.309546
#  27  52.304503
#  28  52.302816
#  29  52.300198
#  30  52.297974
#  31  52.295258  ,
#  'Bus 267: Amsterdam Riekerpolder => Amsterdam Sloten':   id                 name                      geometry     geo_x      geo_y
#  0  2                  IBM  POINT (4.8276171 52.3407116)  4.827617  52.340712
#  1  3  John M. Keynesplein   POINT (4.8252211 52.340147)  4.825221  52.340147
#  2  1       Anderlechtlaan  POINT (4.8138897 52.3353049)   4.81389  52.335305,
#  'Bus 267: Amsterdam Sloten => Amsterdam Riekerpolder':   id                 name                      geometry     geo_x      geo_y
#  0  0       Anderlechtlaan  POINT (4.8143821 52.3355324)  4.814382  52.335532
#  1  2      Adam Smithplein  POINT (4.8216284 52.3396829)  4.821628  52.339683
#  2  1  John M. Keynesplein   POINT (4.8252211 52.340147)  4.825221  52.340147,
#  'Bus 34: Amsterdam Olof Palmeplein => Amsterdam Noorderpark':     id                 name                      geometry     geo_x      geo_y
#  0    9        J. Drijverweg  POINT (4.9442866 52.3995789)  4.944287  52.399579
#  1   14       Th. Weeversweg  POINT (4.9444813 52.3982351)  4.944481  52.398235
#  2    8      Olof Palmeplein   POINT (4.9401433 52.396837)  4.940143  52.396837
#  3   11  Buikslotermeerplein   POINT (4.9388739 52.399888)  4.938874  52.399888
#  4   24        Station Noord  POINT (4.9334201 52.4020325)   4.93342  52.402032
#  5   10   G.J. Scheurleerweg  POINT (4.9292038 52.4038579)  4.929204  52.403858
#  6   13         Oosterlengte  POINT (4.9219523 52.4061481)  4.921952  52.406148
#  7    2            Grootzeil  POINT (4.9240585 52.4086791)  4.924059  52.408679
#  8    4              Masthof   POINT (4.9255139 52.412212)  4.925514  52.412212
#  9    6              Staghof  POINT (4.9225015 52.4136523)  4.922502  52.413652
#  10  19            Tussendek  POINT (4.9193743 52.4125784)  4.919374  52.412578
#  11  18              Voordek  POINT (4.9168622 52.4104798)  4.916862   52.41048
#  12  16    Statenjachtstraat   POINT (4.9136626 52.407858)  4.913663  52.407858
#  13  15          Tjalkstraat  POINT (4.9101517 52.4049386)  4.910152  52.404939
#  14   7              Barkpad  POINT (4.9114689 52.4026388)  4.911469  52.402639
#  15  23  Pinksterbloemstraat   POINT (4.912135 52.3986147)  4.912135  52.398615
#  16  22      Sneeuwbalstraat   POINT (4.914018 52.3963068)  4.914018  52.396307
#  17  26             Mosplein  POINT (4.9134391 52.3928028)  4.913439  52.392803
#  18  25          Noorderpark  POINT (4.9192839 52.3892137)  4.919284  52.389214,
#  'Bus 34: Amsterdam Noorderpark => Amsterdam Olof Palmeplein':     id                 name                      geometry     geo_x      geo_y
#  0   25          Noorderpark  POINT (4.9193382 52.3892587)  4.919338  52.389259
#  1    0             Mosplein  POINT (4.9138434 52.3931662)  4.913843  52.393166
#  2   10      Sneeuwbalstraat  POINT (4.9140858 52.3963978)  4.914086  52.396398
#  3    2  Pinksterbloemstraat  POINT (4.9120506 52.3987653)  4.912051  52.398765
#  4   11              Barkpad  POINT (4.9116492 52.4025689)  4.911649  52.402569
#  5    3          Tjalkstraat  POINT (4.9111059 52.4057317)  4.911106  52.405732
#  6   19    Statenjachtstraat  POINT (4.9137818 52.4079562)  4.913782  52.407956
#  7    6              Voordek  POINT (4.9173642 52.4109825)  4.917364  52.410983
#  8    8            Tussendek  POINT (4.9199187 52.4131703)  4.919919   52.41317
#  9   22              Staghof  POINT (4.9230313 52.4134213)  4.923031  52.413421
#  10   7              Masthof   POINT (4.9255139 52.412212)  4.925514  52.412212
#  11   4            Grootzeil  POINT (4.9231588 52.4081431)  4.923159  52.408143
#  12  16         Oosterlengte  POINT (4.9223735 52.4058331)  4.922373  52.405833
#  13  13   G.J. Scheurleerweg  POINT (4.9290462 52.4037927)  4.929046  52.403793
#  14  24        Station Noord  POINT (4.9321528 52.4026618)  4.932153  52.402662
#  15  15        J. Drijverweg   POINT (4.9445796 52.399403)   4.94458  52.399403
#  16   1       Th. Weeversweg  POINT (4.9444002 52.3982512)    4.9444  52.398251
#  17  14  Buikslotermeerplein  POINT (4.9396376 52.3994953)  4.939638  52.399495
#  18  12      Olof Palmeplein   POINT (4.9401433 52.396837)  4.940143  52.396837,
#  'Bus 35: Amsterdam Olof Palmeplein => Amsterdam Molenwijk':     id                  name                      geometry     geo_x  \
#  0   31           Bovenkruier  POINT (4.8840331 52.4202952)  4.884033
#  1    7         Oostzanerdijk  POINT (4.8814222 52.4202605)  4.881422
#  2   20           Meteorenweg  POINT (4.8813371 52.4147897)  4.881337
#  3   18         Kometensingel   POINT (4.882798 52.4166577)  4.882798
#  4   33              Petmolen  POINT (4.8860883 52.4172572)  4.886088
#  5   22            Maanstraat   POINT (4.8868823 52.412275)  4.886882
#  6   13        Waterlandplein  POINT (4.9529344 52.3926033)  4.952934
#  7   39             Purmerweg    POINT (4.9484849 52.38999)  4.948485
#  8   40           Purmerplein   POINT (4.9458609 52.390762)  4.945861
#  9   36     De Egmondenstraat   POINT (4.9479597 52.394097)   4.94796
#  10  12       Ilperveldstraat  POINT (4.9446658 52.3950661)  4.944666
#  11  15       Olof Palmeplein   POINT (4.9398889 52.396708)  4.939889
#  12   1     Wervershoofstraat  POINT (4.9395424 52.3927329)  4.939542
#  13   3      Nieuwe Purmerweg  POINT (4.9341491 52.3944314)  4.934149
#  14  27      Rode Kruisstraat  POINT (4.9286081 52.3945567)  4.928608
#  15   9             Waddenweg  POINT (4.9269871 52.3925984)  4.926987
#  16   0           Merelstraat   POINT (4.924977 52.3888591)  4.924977
#  17  42  Johan van Hasseltweg  POINT (4.9229473 52.3879722)  4.922947
#  18  44           Noorderpark  POINT (4.9193382 52.3892587)  4.919338
#  19   2              Mosplein  POINT (4.9138434 52.3931662)  4.913843
#  20   8       Sneeuwbalstraat  POINT (4.9140858 52.3963978)  4.914086
#  21   4   Pinksterbloemstraat  POINT (4.9120506 52.3987653)  4.912051
#  22   5            Slijperweg  POINT (4.9075453 52.3992989)  4.907545
#  23  29              Floraweg  POINT (4.9061053 52.3989628)  4.906105
#  24  17               Ataturk  POINT (4.8979313 52.4032248)  4.897931
#  25  26     Nageljongenstraat  POINT (4.8987953 52.4082941)  4.898795
#  26  25          Pomonastraat  POINT (4.8954612 52.4088511)  4.895461
#  27  24        Meteorensingel  POINT (4.8911292 52.4103821)  4.891129
#  28  34          Standermolen  POINT (4.8932629 52.4163356)  4.893263
#  29  14             Molenwijk  POINT (4.8936702 52.4180657)   4.89367
#
#          geo_y
#  0   52.420295
#  1    52.42026
#  2    52.41479
#  3   52.416658
#  4   52.417257
#  5   52.412275
#  6   52.392603
#  7    52.38999
#  8   52.390762
#  9   52.394097
#  10  52.395066
#  11  52.396708
#  12  52.392733
#  13  52.394431
#  14  52.394557
#  15  52.392598
#  16  52.388859
#  17  52.387972
#  18  52.389259
#  19  52.393166
#  20  52.396398
#  21  52.398765
#  22  52.399299
#  23  52.398963
#  24  52.403225
#  25  52.408294
#  26  52.408851
#  27  52.410382
#  28  52.416336
#  29  52.418066  ,
#  'Bus 35: Amsterdam Molenwijk => Amsterdam Olof Palmeplein':     id                  name                      geometry     geo_x  \
#  0    8        Waterlandplein  POINT (4.9529344 52.3926033)  4.952934
#  1   36           Purmerplein  POINT (4.9456722 52.3904803)  4.945672
#  2   35             Purmerweg    POINT (4.9484849 52.38999)  4.948485
#  3   32     De Egmondenstraat   POINT (4.9479597 52.394097)   4.94796
#  4    7       Ilperveldstraat  POINT (4.9446658 52.3950661)  4.944666
#  5    9             Molenwijk  POINT (4.8936702 52.4180657)   4.89367
#  6   29          Standermolen  POINT (4.8920556 52.4161524)  4.892056
#  7   25           Bovenkruier  POINT (4.8840331 52.4202952)  4.884033
#  8    2         Oostzanerdijk   POINT (4.8810599 52.420369)   4.88106
#  9   41           Meteorenweg   POINT (4.8811901 52.414791)   4.88119
#  10  13         Kometensingel   POINT (4.882798 52.4166577)  4.882798
#  11  27              Petmolen  POINT (4.8860883 52.4172572)  4.886088
#  12  16            Maanstraat   POINT (4.8868823 52.412275)  4.886882
#  13  17        Meteorensingel  POINT (4.8915364 52.4101872)  4.891536
#  14  19          Pomonastraat  POINT (4.8954612 52.4088511)  4.895461
#  15  20     Nageljongenstraat  POINT (4.8987953 52.4082941)  4.898795
#  16  11               Ataturk  POINT (4.8977906 52.4032814)  4.897791
#  17  23              Floraweg  POINT (4.9061053 52.3989628)  4.906105
#  18  12            Slijperweg   POINT (4.9076213 52.399194)  4.907621
#  19  31   Pinksterbloemstraat   POINT (4.912135 52.3986147)  4.912135
#  20  30       Sneeuwbalstraat   POINT (4.914018 52.3963068)  4.914018
#  21  42              Mosplein  POINT (4.9134391 52.3928028)  4.913439
#  22  40           Noorderpark  POINT (4.9192839 52.3892137)  4.919284
#  23   6  Johan van Hasseltweg  POINT (4.9232265 52.3877779)  4.923227
#  24   4           Merelstraat  POINT (4.9250366 52.3891109)  4.925037
#  25   3             Waddenweg  POINT (4.9269871 52.3925984)  4.926987
#  26  22      Rode Kruisstraat  POINT (4.9287531 52.3948693)  4.928753
#  27  38      Nieuwe Purmerweg  POINT (4.9345874 52.3941958)  4.934587
#  28   1     Wervershoofstraat  POINT (4.9395424 52.3927329)  4.939542
#  29   5       Olof Palmeplein   POINT (4.9401433 52.396837)  4.940143
#
#          geo_y
#  0   52.392603
#  1    52.39048
#  2    52.38999
#  3   52.394097
#  4   52.395066
#  5   52.418066
#  6   52.416152
#  7   52.420295
#  8   52.420369
#  9   52.414791
#  10  52.416658
#  11  52.417257
#  12  52.412275
#  13  52.410187
#  14  52.408851
#  15  52.408294
#  16  52.403281
#  17  52.398963
#  18  52.399194
#  19  52.398615
#  20  52.396307
#  21  52.392803
#  22  52.389214
#  23  52.387778
#  24  52.389111
#  25  52.392598
#  26  52.394869
#  27  52.394196
#  28  52.392733
#  29  52.396837  ,
#  'Bus 36: Amsterdam Station Noord => Amsterdam Station Sloterdijk':     id                 name                      geometry     geo_x      geo_y
#  0   30        Station Noord  POINT (4.9333136 52.4019497)  4.933314   52.40195
#  1    8   G.J. Scheurleerweg  POINT (4.9292038 52.4038579)  4.929204  52.403858
#  2   13         Oosterlengte  POINT (4.9219523 52.4061481)  4.921952  52.406148
#  3   18  Boven IJ Ziekenhuis  POINT (4.9198712 52.4053609)  4.919871  52.405361
#  4   17     Fluitschipstraat  POINT (4.9160624 52.4036271)  4.916062  52.403627
#  5    6              Barkpad  POINT (4.9114689 52.4026388)  4.911469  52.402639
#  6    0           Slijperweg  POINT (4.9075453 52.3992989)  4.907545  52.399299
#  7   19             Floraweg  POINT (4.9061053 52.3989628)  4.906105  52.398963
#  8   12              Ataturk  POINT (4.8979313 52.4032248)  4.897931  52.403225
#  9   15    Nageljongenstraat  POINT (4.8987953 52.4082941)  4.898795  52.408294
#  10  14         Pomonastraat  POINT (4.8954612 52.4088511)  4.895461  52.408851
#  11  20          Ananasplein  POINT (4.8960199 52.4106504)   4.89602   52.41065
#  12  21        Druivenstraat  POINT (4.8980605 52.4122741)   4.89806  52.412274
#  13   3             Appelweg  POINT (4.8953771 52.4157677)  4.895377  52.415768
#  14   9            Molenwijk  POINT (4.8936702 52.4180657)   4.89367  52.418066
#  15  29         Standermolen  POINT (4.8920556 52.4161524)  4.892056  52.416152
#  16  26             Petmolen  POINT (4.8856111 52.4179234)  4.885611  52.417923
#  17  25          Bovenkruier  POINT (4.8840331 52.4202952)  4.884033  52.420295
#  18   5        Oostzanerdijk   POINT (4.8810599 52.420369)   4.88106  52.420369
#  19   7        La Guardiaweg  POINT (4.8400239 52.3918607)  4.840024  52.391861
#  20  10   Station Sloterdijk   POINT (4.8387805 52.387923)  4.838781  52.387923,
#  'Bus 36: Amsterdam Station Sloterdijk => Amsterdam Station Noord':     id                 name                      geometry     geo_x      geo_y
#  0    8   Station Sloterdijk   POINT (4.8387805 52.387923)  4.838781  52.387923
#  1    5        La Guardiaweg  POINT (4.8403476 52.3915236)  4.840348  52.391524
#  2    3        Oostzanerdijk  POINT (4.8814222 52.4202605)  4.881422   52.42026
#  3   23          Bovenkruier  POINT (4.8841256 52.4201594)  4.884126  52.420159
#  4   26             Petmolen  POINT (4.8860883 52.4172572)  4.886088  52.417257
#  5    7            Molenwijk  POINT (4.8936702 52.4180657)   4.89367  52.418066
#  6   27         Standermolen  POINT (4.8932629 52.4163356)  4.893263  52.416336
#  7   22             Appelweg   POINT (4.895508 52.4156882)  4.895508  52.415688
#  8   20        Druivenstraat  POINT (4.8980605 52.4122741)   4.89806  52.412274
# ...
#  0   35          Amstelstation  POINT (4.9189201 52.3462172)   4.91892
#  1   48             Amsteldijk  POINT (4.9110032 52.3470988)  4.911003
#  2   54          Victorieplein  POINT (4.9056787 52.3463485)  4.905679
#  3   18             Waalstraat  POINT (4.9010625 52.3446215)  4.901063
#  4   30  President Kennedylaan  POINT (4.9018289 52.3409042)  4.901829
#  5   11             Maasstraat  POINT (4.8964643 52.3406764)  4.896464
#  6   51            Europaplein   POINT (4.892229 52.3402304)  4.892229
#  7   50            Station RAI  POINT (4.8905695 52.3368943)  4.890569
#  8   19        Europaboulevard  POINT (4.8898062 52.3340017)  4.889806
#  9   25             Amstelpark  POINT (4.8897887 52.3317414)  4.889789
#  10  26          Nieuw Herlaer  POINT (4.8898911 52.3259706)  4.889891
#  11  27      Van Heenvlietlaan  POINT (4.8820321 52.3248864)  4.882032
#  12  29         Kastelenstraat  POINT (4.8794836 52.3266222)  4.879484
#  13   8   Gelderlandplein Oost  POINT (4.8795101 52.3309276)   4.87951
#  14  12               Hogewerf  POINT (4.8793973 52.3341353)  4.879397
#  15  38           Station Zuid  POINT (4.8720355 52.3408188)  4.872035
#  16   1      De Boelelaan / VU   POINT (4.8662746 52.335116)  4.866275
#  17   2       VUmc Hoofdingang  POINT (4.8600598 52.3352138)   4.86006
#  18  45             IJsbaanpad   POINT (4.857721 52.3416032)  4.857721
#  19  43      Olympisch Stadion  POINT (4.8568598 52.3440308)   4.85686
#  20  58  Haarlemmermeerstation  POINT (4.8576315 52.3492179)  4.857632
#  21  57             Zeilstraat  POINT (4.8566667 52.3512098)  4.856667
#  22  56        Amstelveenseweg  POINT (4.8560722 52.3513667)  4.856072
#  23   7         Hoofddorpplein  POINT (4.8494579 52.3506282)  4.849458
#  24  55          Aalsmeerplein  POINT (4.8466088 52.3470123)  4.846609
#  25  21        Naaldwijkstraat  POINT (4.8424149 52.3468628)  4.842415
#  26  22        Maassluisstraat  POINT (4.8384643 52.3469848)  4.838464
#  27  23   Ottho Heldringstraat   POINT (4.8331334 52.346963)  4.833133
#  28  13      Aletta Jacobslaan  POINT (4.8285185 52.3468914)  4.828519
#  29  40     Johan Huizingalaan  POINT (4.8274702 52.3492178)   4.82747
#  30  36              Sierplein  POINT (4.8273532 52.3551327)  4.827353
#  31  16       Station Lelylaan  POINT (4.8345018 52.3566769)  4.834502
#
#          geo_y
#  0   52.346217
#  1   52.347099
#  2   52.346348
#  3   52.344622
#  4   52.340904
#  5   52.340676
#  6    52.34023
#  7   52.336894
#  8   52.334002
#  9   52.331741
#  10  52.325971
#  11  52.324886
#  12  52.326622
#  13  52.330928
#  14  52.334135
#  15  52.340819
#  16  52.335116
#  17  52.335214
#  18  52.341603
#  19  52.344031
#  20  52.349218
#  21   52.35121
#  22  52.351367
#  23  52.350628
#  24  52.347012
#  25  52.346863
#  26  52.346985
#  27  52.346963
#  28  52.346891
#  29  52.349218
#  30  52.355133
#  31  52.356677  ,
#  'Bus 63: Osdorp De Aker => Amsterdam Station Lelylaan':     id                       name                      geometry     geo_x  \
#  0    0                 Matterhorn  POINT (4.7745693 52.3543998)  4.774569
#  1   18               Griendstraat  POINT (4.7793748 52.3583711)  4.779375
#  2   19             Zuidermolenweg  POINT (4.7811205 52.3599209)  4.781121
#  3   20            Jan Rebelstraat  POINT (4.7842364 52.3619802)  4.784236
#  4   21            Baden Powellweg  POINT (4.7877497 52.3623131)   4.78775
#  5    8            Saaftingestraat  POINT (4.7915161 52.3603913)  4.791516
#  6    9          Reimerswaalstraat  POINT (4.7956961 52.3612211)  4.795696
#  7   11                   Bullepad  POINT (4.7995362 52.3620072)  4.799536
#  8   13                   Geer Ban  POINT (4.8041006 52.3629227)  4.804101
#  9    7               Osdorper ban  POINT (4.8059511 52.3626428)  4.805951
#  10   6           Osdorpplein Oost  POINT (4.8080851 52.3586388)  4.808085
#  11   2           C.K. Eloutstraat   POINT (4.8117822 52.354462)  4.811782
#  12  14         Piet Wiedijkstraat   POINT (4.815327 52.3551704)  4.815327
#  13  16  Van Mourik Broekmanstraat  POINT (4.8214442 52.3565764)  4.821444
#  14  17          Hemsterhuisstraat  POINT (4.8218035 52.3591318)  4.821803
#  15   1          Cornelis Lelylaan  POINT (4.8268513 52.3576299)  4.826851
#  16   4           Station Lelylaan  POINT (4.8343566 52.3566723)  4.834357
#
#          geo_y
#  0     52.3544
#  1   52.358371
#  2   52.359921
#  3    52.36198
#  4   52.362313
#  5   52.360391
#  6   52.361221
#  7   52.362007
#  8   52.362923
#  9   52.362643
#  10  52.358639
#  11  52.354462
#  12   52.35517
#  13  52.356576
#  14  52.359132
#  15   52.35763
#  16  52.356672  ,
#  'Bus 63: Amsterdam Station Lelylaan => Osdorp De Aker':     id                       name                      geometry     geo_x  \
#  0    3           Station Lelylaan  POINT (4.8343566 52.3566723)  4.834357
#  1    4          Cornelis Lelylaan  POINT (4.8276261 52.3579398)  4.827626
#  2   23          Hemsterhuisstraat   POINT (4.8217278 52.359131)  4.821728
#  3   15  Van Mourik Broekmanstraat  POINT (4.8214492 52.3564454)  4.821449
#  4   14         Piet Wiedijkstraat   POINT (4.815327 52.3551704)  4.815327
#  5    2           C.K. Eloutstraat  POINT (4.8115002 52.3544056)    4.8115
#  6    5           Osdorpplein Oost  POINT (4.8077186 52.3593186)  4.807719
#  7   24               Osdorper ban  POINT (4.8046011 52.3630571)  4.804601
#  8   12                   Geer Ban  POINT (4.8036666 52.3628347)  4.803667
#  9   11                   Bullepad  POINT (4.7995362 52.3620072)  4.799536
#  10  10          Reimerswaalstraat  POINT (4.7943043 52.3609537)  4.794304
#  11  22            Saaftingestraat  POINT (4.7897228 52.3600373)  4.789723
#  12  21            Baden Powellweg  POINT (4.7877962 52.3624428)  4.787796
#  13  20            Jan Rebelstraat  POINT (4.7831043 52.3615321)  4.783104
#  14  18               Griendstraat  POINT (4.7793748 52.3583711)  4.779375
#  15  19                 Matterhorn  POINT (4.7751426 52.3549835)  4.775143
#
#          geo_y
#  0   52.356672
#  1    52.35794
#  2   52.359131
#  3   52.356445
#  4    52.35517
#  5   52.354406
#  6   52.359319
#  7   52.363057
#  8   52.362835
#  9   52.362007
#  10  52.360954
#  11  52.360037
#  12  52.362443
#  13  52.361532
#  14  52.358371
#  15  52.354984  ,
#  'Bus 65: Amsterdam KNSM Eiland => Amsterdam Station Zuid':     id                 name                      geometry     geo_x      geo_y
#  0   30            KNSM-laan  POINT (4.9459361 52.3771048)  4.945936  52.377105
#  1   29          Levantplein  POINT (4.9424082 52.3771086)  4.942408  52.377109
#  2   45           Azartplein  POINT (4.9373557 52.3766138)  4.937356  52.376614
#  3   47  C. van Eesterenlaan  POINT (4.9388462 52.3735497)  4.938846   52.37355
#  4    6           Borneolaan  POINT (4.9383916 52.3713357)  4.938392  52.371336
#  5   28              Veelaan  POINT (4.9394896 52.3676768)   4.93949  52.367677
#  6   27        Zeeburgerdijk   POINT (4.939513 52.3654344)  4.939513  52.365434
#  7    9            Javaplein  POINT (4.9395347 52.3640185)  4.939535  52.364019
#  8   14        Valentijnkade  POINT (4.9407792 52.3588673)  4.940779  52.358867
#  9   25        Archimedesweg  POINT (4.9396674 52.3557118)  4.939667  52.355712
#  10  23             Radioweg  POINT (4.9394469 52.3534031)  4.939447  52.353403
#  11  22            Middenweg  POINT (4.9339137 52.3501391)  4.933914  52.350139
#  12  13        Maxwellstraat   POINT (4.9286576 52.347239)  4.928658  52.347239
#  13  12         Fizeaustraat   POINT (4.9243303 52.345937)   4.92433  52.345937
#  14  10        Amstelstation  POINT (4.9193827 52.3468042)  4.919383  52.346804
#  15   2           Amsteldijk   POINT (4.9109862 52.347133)  4.910986  52.347133
#  16   3        Victorieplein  POINT (4.9056648 52.3463845)  4.905665  52.346384
#  17  38           Waalstraat  POINT (4.9005987 52.3444516)  4.900599  52.344452
#  18  39           Maasstraat  POINT (4.8963085 52.3428958)  4.896308  52.342896
#  19  42         Dintelstraat  POINT (4.8930026 52.3419109)  4.893003  52.341911
#  20  31         Scheldeplein  POINT (4.8908081 52.3444479)  4.890808  52.344448
#  21  20        Scheldestraat  POINT (4.8896383 52.3473897)  4.889638   52.34739
#  22  19           Apollolaan   POINT (4.881967 52.3481494)  4.881967  52.348149
#  23  17      Beethovenstraat   POINT (4.8782207 52.346969)  4.878221  52.346969
#  24  35           Stadionweg  POINT (4.8768476 52.3466757)  4.876848  52.346676
#  25   0  Prinses Irenestraat  POINT (4.8767388 52.3426122)  4.876739  52.342612
#  26   7         Station Zuid  POINT (4.8736017 52.3408906)  4.873602  52.340891,
#  'Bus 65: Amsterdam Station Zuid => Amsterdam KNSM Eiland':     id                 name                      geometry     geo_x      geo_y
#  0   46           Azartplein  POINT (4.9373557 52.3766138)  4.937356  52.376614
#  1   33         Station Zuid   POINT (4.873716 52.3407537)  4.873716  52.340754
#  2    0  Prinses Irenestraat  POINT (4.8768182 52.3431077)  4.876818  52.343108
#  3    1           Stadionweg  POINT (4.8769021 52.3466735)  4.876902  52.346674
#  4   18           Apollolaan  POINT (4.8822279 52.3482857)  4.882228  52.348286
#  5   20        Scheldestraat   POINT (4.889616 52.3470291)  4.889616  52.347029
#  6   31         Scheldeplein  POINT (4.8909465 52.3436421)  4.890947  52.343642
#  7   42         Dintelstraat  POINT (4.8933247 52.3419034)  4.893325  52.341903
#  8   41           Maasstraat  POINT (4.8968547 52.3430956)  4.896855  52.343096
#  9   11           Waalstraat  POINT (4.9010625 52.3446215)  4.901063  52.344622
#  10   4        Victorieplein  POINT (4.9063597 52.3464044)   4.90636  52.346404
#  11   3           Amsteldijk  POINT (4.9111659 52.3470823)  4.911166  52.347082
#  12  32        Amstelstation  POINT (4.9194545 52.3466842)  4.919454  52.346684
#  13   5         Fizeaustraat  POINT (4.9246384 52.3459384)  4.924638  52.345938
#  14  17        Maxwellstraat  POINT (4.9301749 52.3480727)  4.930175  52.348073
#  15  21            Middenweg  POINT (4.9344611 52.3504337)  4.934461  52.350434
#  16  24             Radioweg   POINT (4.939831 52.3536187)  4.939831  52.353619
#  17  25        Archimedesweg  POINT (4.9396674 52.3557118)  4.939667  52.355712
#  18  15        Valentijnkade   POINT (4.940737 52.3589863)  4.940737  52.358986
#  19  26            Javaplein  POINT (4.9395334 52.3641038)  4.939533  52.364104
#  20   7        Zeeburgerdijk   POINT (4.9395115 52.365531)  4.939512  52.365531
#  21   6              Veelaan  POINT (4.9394683 52.3684403)  4.939468   52.36844
#  22  16           Borneolaan     POINT (4.9386 52.3708048)    4.9386  52.370805
#  23  48  C. van Eesterenlaan  POINT (4.9388462 52.3735497)  4.938846   52.37355
#  24  29          Levantplein   POINT (4.9427778 52.377078)  4.942778  52.377078
#  25  30            KNSM-laan  POINT (4.9459361 52.3771048)  4.945936  52.377105,
#  'Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ArenA':     id                     name                      geometry     geo_x  \
#  0   21     Pieter Martensstraat  POINT (5.0144582 52.3483266)  5.014458
#  1   24         Vennepluimstraat  POINT (4.9912925 52.3571984)  4.991293
#  2   23           Diemerparklaan  POINT (4.9957586 52.3548394)  4.995759
#  3   10            Lumièrestraat  POINT (5.0002141 52.3524736)  5.000214
#  4   22  Pieter Oosterhuisstraat  POINT (5.0075027 52.3518653)  5.007503
#  5   20      Diemen, Diemerknoop  POINT (5.0030154 52.3354164)  5.003015
#  6    7              Stammerkamp  POINT (4.9829371 52.3333748)  4.982937
#  7   18      Diemen, Stammerkamp  POINT (4.9829301 52.3333284)   4.98293
#  8    1               Vinkenbrug  POINT (4.9788636 52.3337164)  4.978864
#  9   19       Diemen, Vinkenburg  POINT (4.9788496 52.3336556)   4.97885
#  10   0           Provincialeweg  POINT (4.9718582 52.3276691)  4.971858
#  11  26   Diemen, Provincialeweg  POINT (4.9719251 52.3276346)  4.971925
#  12  27             Geldershoofd  POINT (4.9709355 52.3250219)  4.970936
#  13  29       Station Ganzenhoef  POINT (4.9729525 52.3224051)  4.972952
#  14   9        Annie Romeinplein  POINT (4.9700257 52.3214479)  4.970026
#  15   6               Tulastraat  POINT (4.9653709 52.3199551)  4.965371
#  16   4                  Florijn  POINT (4.9586722 52.3176176)  4.958672
#  17   5        Anton de Komplein  POINT (4.9541152 52.3160401)  4.954115
#  18  12             Bijlmerplein  POINT (4.9490731 52.3142965)  4.949073
#  19   2            Foppingadreef  POINT (4.9493119 52.3130617)  4.949312
#  20  11    Station Bijlmer ArenA  POINT (4.9474375 52.3113653)  4.947438
#
#          geo_y
#  0   52.348327
#  1   52.357198
#  2   52.354839
#  3   52.352474
#  4   52.351865
#  5   52.335416
#  6   52.333375
#  7   52.333328
#  8   52.333716
#  9   52.333656
#  10  52.327669
#  11  52.327635
#  12  52.325022
#  13  52.322405
#  14  52.321448
#  15  52.319955
#  16  52.317618
#  17   52.31604
#  18  52.314296
#  19  52.313062
#  20  52.311365  ,
#  'Bus 66: Amsterdam Bijlmer ArenA => Amsterdam IJburg':     id                     name                      geometry     geo_x  \
#  0    3    Station Bijlmer ArenA  POINT (4.9474683 52.3113329)  4.947468
#  1   21            Foppingadreef  POINT (4.9498074 52.3127334)  4.949807
#  2    9             Bijlmerplein  POINT (4.9494963 52.3143341)  4.949496
#  3    2        Anton de Komplein  POINT (4.9558884 52.3164584)  4.955888
#  4   10                  Florijn  POINT (4.9596498 52.3177953)   4.95965
#  5    0               Tulastraat    POINT (4.96581 52.3198302)   4.96581
#  6    4        Annie Romeinplein  POINT (4.9715166 52.3216851)  4.971517
#  7   13       Station Ganzenhoef   POINT (4.9732278 52.323056)  4.973228
#  8   23             Geldershoofd  POINT (4.9707228 52.3252556)  4.970723
#  9    5   Diemen, Provincialeweg  POINT (4.9726754 52.3279964)  4.972675
#  10  15       Diemen, Vinkenburg  POINT (4.9783717 52.3336649)  4.978372
#  11   1              Stammerkamp  POINT (4.9833779 52.3331678)  4.983378
#  12  14      Diemen, Stammerkamp  POINT (4.9833777 52.3332213)  4.983378
#  13  16      Diemen, Diemerknoop  POINT (5.0027574 52.3353668)  5.002757
#  14  17     Pieter Martensstraat   POINT (5.0142692 52.348784)  5.014269
#  15  18  Pieter Oosterhuisstraat  POINT (5.0072883 52.3520178)  5.007288
#  16   7            Lumièrestraat  POINT (4.9991732 52.3532416)  4.999173
#  17  19           Diemerparklaan   POINT (4.9947414 52.355608)  4.994741
#  18  20         Vennepluimstraat  POINT (4.9912925 52.3571984)  4.991293
#
#          geo_y
#  0   52.311333
#  1   52.312733
#  2   52.314334
#  3   52.316458
#  4   52.317795
#  5    52.31983
#  6   52.321685
#  7   52.323056
#  8   52.325256
#  9   52.327996
#  10  52.333665
#  11  52.333168
#  12  52.333221
#  13  52.335367
#  14  52.348784
#  15  52.352018
#  16  52.353242
#  17  52.355608
#  18  52.357198  ,
#  'Bus 68: Amsterdam Riekerpolder => Amsterdam Henk Sneevlietweg':   id                 name                      geometry     geo_x      geo_y
#  0  4      Adam Smithplein  POINT (4.8216284 52.3396829)  4.821628  52.339683
#  1  2  John M. Keynesplein    POINT (4.824444 52.340413)  4.824444  52.340413
#  2  3                  IBM   POINT (4.827888 52.3410803)  4.827888   52.34108
#  3  0           Parkeerdek  POINT (4.8286682 52.3425954)  4.828668  52.342595
#  4  1    Henk Sneevlietweg  POINT (4.8330587 52.3457424)  4.833059  52.345742,
#  'Bus 68: Amsterdam Henk Sneevlietweg => Amsterdam Riekerpolder':   id                 name                      geometry     geo_x      geo_y
#  0  4      Adam Smithplein  POINT (4.8216284 52.3396829)  4.821628  52.339683
#  1  1    Henk Sneevlietweg  POINT (4.8330587 52.3457424)  4.833059  52.345742
#  2  0           Parkeerdek  POINT (4.8286682 52.3425954)  4.828668  52.342595
#  3  2                  IBM  POINT (4.8276171 52.3407116)  4.827617  52.340712
#  4  3  John M. Keynesplein   POINT (4.8252211 52.340147)  4.825221  52.340147}

# %%
df15_1 = city_bus_shortest_path_edges['Bus 15: Amsterdam Station Zuid => Amsterdam Station Sloterdijk']
df15_2 = city_bus_shortest_path_edges['Bus 15: Amsterdam Station Sloterdijk => Amsterdam Station Zuid']

df52_1 = city_sub_shortest_path_edges['Metro 52: Noord => Zuid'] 
df52_2 = city_sub_shortest_path_edges['Metro 52: Zuid => Noord']

df53_1 = city_sub_shortest_path_edges['Metro 53: Centraal Station => Gaasperplas']
df53_2 = city_sub_shortest_path_edges['Metro 53: Gaasperplas => Centraal Station']

df54_1 = city_sub_shortest_path_edges['Metro 54: Centraal Station => Gein']
df54_2 = city_sub_shortest_path_edges['Metro 54: Gein => Centraal Station']

# %% [markdown]
# ## Add columns to nodes

# %%
city_bus_order_route_dict = add_ref_to_orderroutes_or_shortestpath_dict(city_bus_order_route_dict, city_bus_routes)

# %%
city_bus_new_nodes = add_columns_to_nodes(city_bus_order_route_dict, nodes)

# %%
city_bus_new_nodes
# Out:
#                      geometry  degree     id                   name     geo_x  \
# 0    POINT (4.87204 52.34082)       2  14779           Station Zuid  4.872035
# 1    POINT (4.86829 52.34289)       2  67476    Prinses Irenestraat  4.868290
# 2    POINT (4.86586 52.34629)       2  68204           Olympiaplein  4.865862
# 3    POINT (4.85835 52.34525)       2  68196             Olympiaweg  4.858347
# 4    POINT (4.85763 52.34922)       2  68341  Haarlemmermeerstation  4.857632
# ..                        ...     ...    ...                    ...       ...
# 752  POINT (4.99474 52.35561)       2  67471         Diemerparklaan  4.994741
# 753  POINT (4.82444 52.34041)       3  15699    John M. Keynesplein  4.824444
# 754  POINT (4.82789 52.34108)       2  11244                    IBM  4.827888
# 755  POINT (4.82867 52.34260)       3  26843             Parkeerdek  4.828668
# 756  POINT (4.83306 52.34574)       2  31909      Henk Sneevlietweg  4.833059
#
#          geo_y         coordinate_value  \
# 0    52.340819  (4.8720355, 52.3408188)
# 1    52.342894  (4.8682898, 52.3428941)
# 2    52.346286   (4.865862, 52.3462864)
# 3    52.345247  (4.8583469, 52.3452468)
# 4    52.349218  (4.8576315, 52.3492179)
# ..         ...                      ...
# 752  52.355608   (4.9947414, 52.355608)
# 753  52.340413    (4.824444, 52.340413)
# 754  52.341080   (4.827888, 52.3410803)
# 755  52.342595  (4.8286682, 52.3425954)
# 756  52.345742  (4.8330587, 52.3457424)
#
#                                        route_name_list route          ref  \
# 0    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus   15, 62, 65
# 1    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus  15, 246, 65
# 2    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus           15
# 3    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus           15
# 4    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus       15, 62
# ..                                                 ...   ...          ...
# 752  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...   bus           66
# 753  Bus 68: Amsterdam Riekerpolder => Amsterdam He...   bus      267, 68
# 754  Bus 68: Amsterdam Riekerpolder => Amsterdam He...   bus      267, 68
# 755  Bus 68: Amsterdam Riekerpolder => Amsterdam He...   bus           68
# 756  Bus 68: Amsterdam Riekerpolder => Amsterdam He...   bus           68
#
#         transfer
# 0     15, 62, 65
# 1    15, 246, 65
# 2           None
# 3           None
# 4         15, 62
# ..           ...
# 752         None
# 753      267, 68
# 754      267, 68
# 755         None
# 756         None
#
# [757 rows x 11 columns]

# %% [markdown]
# ### retrive all transfer stations on each route

# %%
city_bus_transfer_stations_df = all_transfer_stations_df(city_bus_new_nodes)

# %%
city_bus_transfer_stations_df
# Out:
#                      geometry  degree     id                   name     geo_x  \
# 0    POINT (4.87204 52.34082)       2  14779           Station Zuid  4.872035
# 1    POINT (4.86829 52.34289)       2  67476    Prinses Irenestraat  4.868290
# 4    POINT (4.85763 52.34922)       2  68341  Haarlemmermeerstation  4.857632
# 5    POINT (4.85667 52.35121)       2  68268             Zeilstraat  4.856667
# 6    POINT (4.85607 52.35137)       2  68266        Amstelveenseweg  4.856072
# ..                        ...     ...    ...                    ...       ...
# 740  POINT (4.96581 52.31983)       0  66747             Tulastraat  4.965810
# 741  POINT (4.97152 52.32169)       0  67123      Annie Romeinplein  4.971517
# 742  POINT (4.97323 52.32306)       2  67461     Station Ganzenhoef  4.973228
# 753  POINT (4.82444 52.34041)       3  15699    John M. Keynesplein  4.824444
# 754  POINT (4.82789 52.34108)       2  11244                    IBM  4.827888
#
#          geo_y         coordinate_value  \
# 0    52.340819  (4.8720355, 52.3408188)
# 1    52.342894  (4.8682898, 52.3428941)
# 4    52.349218  (4.8576315, 52.3492179)
# 5    52.351210  (4.8566667, 52.3512098)
# 6    52.351367  (4.8560722, 52.3513667)
# ..         ...                      ...
# 740  52.319830    (4.96581, 52.3198302)
# 741  52.321685  (4.9715166, 52.3216851)
# 742  52.323056   (4.9732278, 52.323056)
# 753  52.340413    (4.824444, 52.340413)
# 754  52.341080   (4.827888, 52.3410803)
#
#                                        route_name_list route          ref  \
# 0    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus   15, 62, 65
# 1    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus  15, 246, 65
# 4    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus       15, 62
# 5    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus       15, 62
# 6    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus  15, 246, 62
# ..                                                 ...   ...          ...
# 740  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...   bus   41, 47, 66
# 741  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...   bus       41, 66
# 742  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...   bus       41, 66
# 753  Bus 68: Amsterdam Riekerpolder => Amsterdam He...   bus      267, 68
# 754  Bus 68: Amsterdam Riekerpolder => Amsterdam He...   bus      267, 68
#
#         transfer
# 0     15, 62, 65
# 1    15, 246, 65
# 4         15, 62
# 5         15, 62
# 6    15, 246, 62
# ..           ...
# 740   41, 47, 66
# 741       41, 66
# 742       41, 66
# 753      267, 68
# 754      267, 68
#
# [351 rows x 11 columns]

# %% [markdown]
# ## Add columns to edges

# %%
city_bus_shortest_path_edges = add_ref_to_orderroutes_or_shortestpath_dict(city_bus_shortest_path_edges, city_bus_routes)

# %%
city_bus_new_edges = add_columns_to_edges(city_bus_shortest_path_edges,edges)

# %%
column_to_drop = 'count_weight'
city_bus_new_edges = city_bus_new_edges.drop(columns=column_to_drop)

# %%
city_bus_new_edges
# Out:
#            osm_id                                           geometry railway  \
# 0         4436684  LINESTRING (4.9683596 52.3558775, 4.9683345 52...     bus
# 1         4495957  LINESTRING (4.8601784 52.357593, 4.8601399 52....     bus
# 2         4496429  LINESTRING (4.8743983 52.358788, 4.8744747 52....     bus
# 3         4727308  LINESTRING (4.9563878 52.377293, 4.9564629 52....     bus
# 4         4727308  LINESTRING (4.9564856 52.376881, 4.9564944 52....     bus
# ...           ...                                                ...     ...
# 71623  1185077512  LINESTRING (4.795149 52.3318873, 4.7953163 52....     bus
# 71624  1185077519  LINESTRING (4.7974835 52.3325307, 4.7972201 52...     bus
# 71625  1185077520  LINESTRING (4.7967795 52.3323057, 4.7972519 52...     bus
# 71626  1185077524  LINESTRING (4.7997017 52.3324389, 4.7997688 52...     bus
# 71627  1185077528  LINESTRING (4.7988313 52.3335157, 4.7987286 52...     bus
#
#        service     id  from_id  to_id   distance      time  weights  \
# 0        steps      0        0      1   4.049164  0.000324        4
# 1        steps      1        2      3   7.754968  0.000620        7
# 2      service      2        4      5  68.807947  0.005505       68
# 3         path      3        6  65237  46.383298  0.003711       46
# 4         path      4    65237      7   2.090290  0.000167        2
# ...        ...    ...      ...    ...        ...       ...      ...
# 71623  service  71623    65586  65587  29.884042  0.002391       29
# 71624  service  71624    65588  65589  19.267219  0.001541       19
# 71625  service  71625    65590  65591  34.723141  0.002778       34
# 71626     path  71626    65592  65593  65.462451  0.005237       65
# 71627  service  71627    65594  65595  41.888083  0.003351       41
#
#               to_from         from_to route_name_list route  ref
# 0              (0, 1)          (1, 0)             NaN   NaN  NaN
# 1              (2, 3)          (3, 2)             NaN   NaN  NaN
# 2              (4, 5)          (5, 4)             NaN   NaN  NaN
# 3          (6, 65237)      (65237, 6)             NaN   NaN  NaN
# 4          (65237, 7)      (7, 65237)             NaN   NaN  NaN
# ...               ...             ...             ...   ...  ...
# 71623  (65586, 65587)  (65587, 65586)             NaN   NaN  NaN
# 71624  (65588, 65589)  (65589, 65588)             NaN   NaN  NaN
# 71625  (65590, 65591)  (65591, 65590)             NaN   NaN  NaN
# 71626  (65592, 65593)  (65593, 65592)             NaN   NaN  NaN
# 71627  (65594, 65595)  (65595, 65594)             NaN   NaN  NaN
#
# [71628 rows x 15 columns]

# %% [markdown]
# # Multi networks

# %% [markdown]
# ### Merge three networks

# %%
three_networks_edges = pd.concat([city_sub_new_edges,city_tram_new_edges,city_bus_new_edges])
# three_networks_nodes = pd.concat([sub_new_nodes_transfer_all,city_tram_new_nodes_transfer_all,city_bus_new_nodes_transfer_all]) 
three_networks_nodes = pd.concat([city_sub_new_nodes,city_tram_new_nodes,city_bus_new_nodes]) 
three_networks_routes = pd.concat([city_sub_routes,city_tram_routes,city_bus_routes])

# %%
three_networks_edges
# Out:
#            osm_id                                           geometry railway  \
# 0        23157994  LINESTRING (4.9236699 52.3361909, 4.9236979 52...  subway
# 1        23158053  LINESTRING (4.9642294 52.2945339, 4.9644259 52...  subway
# 2        23158054  LINESTRING (4.9622901 52.2955678, 4.9624673 52...  subway
# 3        23189033  LINESTRING (4.8467318 52.3952137, 4.8471439 52...  subway
# 4        23189039  LINESTRING (4.8409161 52.3937679, 4.8416087 52...  subway
# ...           ...                                                ...     ...
# 71623  1185077512  LINESTRING (4.795149 52.3318873, 4.7953163 52....     bus
# 71624  1185077519  LINESTRING (4.7974835 52.3325307, 4.7972201 52...     bus
# 71625  1185077520  LINESTRING (4.7967795 52.3323057, 4.7972519 52...     bus
# 71626  1185077524  LINESTRING (4.7997017 52.3324389, 4.7997688 52...     bus
# 71627  1185077528  LINESTRING (4.7988313 52.3335157, 4.7987286 52...     bus
#
#        service     id  from_id  to_id    distance      time  weights  \
# 0         None      0        0      1  258.660599  0.010346      258
# 1         None      1        2      3  215.433271  0.008617      215
# 2         None      2        4      5  121.794737  0.004872      121
# 3         None      3        6      7   28.046592  0.001122       28
# 4         None      4        8    492  382.935219  0.015317      382
# ...        ...    ...      ...    ...         ...       ...      ...
# 71623  service  71623    65586  65587   29.884042  0.002391       29
# 71624  service  71624    65588  65589   19.267219  0.001541       19
# 71625  service  71625    65590  65591   34.723141  0.002778       34
# 71626     path  71626    65592  65593   65.462451  0.005237       65
# 71627  service  71627    65594  65595   41.888083  0.003351       41
#
#               to_from         from_to  \
# 0              (0, 1)          (1, 0)
# 1              (2, 3)          (3, 2)
# 2              (4, 5)          (5, 4)
# 3              (6, 7)          (7, 6)
# 4            (8, 492)        (492, 8)
# ...               ...             ...
# 71623  (65586, 65587)  (65587, 65586)
# 71624  (65588, 65589)  (65589, 65588)
# 71625  (65590, 65591)  (65591, 65590)
# 71626  (65592, 65593)  (65593, 65592)
# 71627  (65594, 65595)  (65595, 65594)
#
#                                  route_name_list   route     ref
# 0      Metro 51: Isolatorweg => Centraal Station  subway      51
# 1                  Metro 50: Isolatorweg => Gein  subway  50, 54
# 2                  Metro 50: Isolatorweg => Gein  subway  50, 54
# 3                                            NaN     NaN     NaN
# 4                  Metro 50: Isolatorweg => Gein  subway  50, 51
# ...                                          ...     ...     ...
# 71623                                        NaN     NaN     NaN
# 71624                                        NaN     NaN     NaN
# 71625                                        NaN     NaN     NaN
# 71626                                        NaN     NaN     NaN
# 71627                                        NaN     NaN     NaN
#
# [74794 rows x 15 columns]

# %%
three_networks_nodes
# Out:
#                      geometry  degree     id                 name     geo_x  \
# 0    POINT (4.98916 52.29641)       2    328                 Gein  4.989161
# 1    POINT (4.97400 52.29564)       2    855           Reigersbos  4.974000
# 2    POINT (4.96013 52.29813)       2    854          Holendrecht  4.960126
# 3    POINT (4.95213 52.30687)       2    810            Bullewijk  4.952129
# 4    POINT (4.94762 52.31181)       2    809        Bijlmer ArenA  4.947618
# ..                        ...     ...    ...                  ...       ...
# 752  POINT (4.99474 52.35561)       2  67471       Diemerparklaan  4.994741
# 753  POINT (4.82444 52.34041)       3  15699  John M. Keynesplein  4.824444
# 754  POINT (4.82789 52.34108)       2  11244                  IBM  4.827888
# 755  POINT (4.82867 52.34260)       3  26843           Parkeerdek  4.828668
# 756  POINT (4.83306 52.34574)       2  31909    Henk Sneevlietweg  4.833059
#
#          geo_y         coordinate_value  \
# 0    52.296407  (4.9891612, 52.2964067)
# 1    52.295637  (4.9740002, 52.2956365)
# 2    52.298132  (4.9601264, 52.2981319)
# 3    52.306869   (4.9521292, 52.306869)
# 4    52.311806   (4.9476178, 52.311806)
# ..         ...                      ...
# 752  52.355608   (4.9947414, 52.355608)
# 753  52.340413    (4.824444, 52.340413)
# 754  52.341080   (4.827888, 52.3410803)
# 755  52.342595  (4.8286682, 52.3425954)
# 756  52.345742  (4.8330587, 52.3457424)
#
#                                        route_name_list   route      ref  \
# 0                        Metro 50: Gein => Isolatorweg  subway   50, 54
# 1                        Metro 50: Gein => Isolatorweg  subway   50, 54
# 2                        Metro 50: Gein => Isolatorweg  subway   50, 54
# 3                        Metro 50: Gein => Isolatorweg  subway   50, 54
# 4                        Metro 50: Gein => Isolatorweg  subway   50, 54
# ..                                                 ...     ...      ...
# 752  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...     bus       66
# 753  Bus 68: Amsterdam Riekerpolder => Amsterdam He...     bus  267, 68
# 754  Bus 68: Amsterdam Riekerpolder => Amsterdam He...     bus  267, 68
# 755  Bus 68: Amsterdam Riekerpolder => Amsterdam He...     bus       68
# 756  Bus 68: Amsterdam Riekerpolder => Amsterdam He...     bus       68
#
#     transfer
# 0     50, 54
# 1     50, 54
# 2     50, 54
# 3     50, 54
# 4     50, 54
# ..       ...
# 752     None
# 753  267, 68
# 754  267, 68
# 755     None
# 756     None
#
# [1261 rows x 11 columns]

# %%
type(three_networks_nodes.geometry[0])
# Out:
# geopandas.geoseries.GeoSeries

# %%
three_networks_routes
# Out:
#       osm_id   route                   to  \
# 0      18683  subway          Isolatorweg
# 1    4515354  subway                 Gein
# 2      31249  subway          Isolatorweg
# 3    4515355  subway     Centraal Station
# 4    8466667  subway                 Zuid
# ..       ...     ...                  ...
# 58    365791     bus     Vennepluimstraat
# 59  11720818     bus    Henk Sneevlietweg
# 60  11720819     bus  John M. Keynesplein
# 61   6096663     bus    Henk Sneevlietweg
# 62   5860193     bus  John M. Keynesplein
#
#                                                  name ref  \
# 0                       Metro 50: Gein => Isolatorweg  50
# 1                       Metro 50: Isolatorweg => Gein  50
# 2           Metro 51: Centraal Station => Isolatorweg  51
# 3           Metro 51: Isolatorweg => Centraal Station  51
# 4                             Metro 52: Noord => Zuid  52
# ..                                                ...  ..
# 58  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66
# 59  Bus 68: Amsterdam Riekerpolder => Amsterdam He...  68
# 60  Bus 68: Amsterdam Henk Sneevlietweg => Amsterd...  68
# 61  Bus 68: Amsterdam Riekerpolder => Amsterdam He...  68
# 62  Bus 68: Amsterdam Henk Sneevlietweg => Amsterd...  68
#
#                    network service  \
# 0   Stadsvervoer Amsterdam    None
# 1   Stadsvervoer Amsterdam    None
# 2   Stadsvervoer Amsterdam    None
# 3   Stadsvervoer Amsterdam    None
# 4   Stadsvervoer Amsterdam    None
# ..                     ...     ...
# 58  Stadsvervoer Amsterdam    None
# 59  Stadsvervoer Amsterdam    None
# 60  Stadsvervoer Amsterdam    None
# 61  Stadsvervoer Amsterdam    None
# 62  Stadsvervoer Amsterdam    None
#
#                                              geometry
# 0   MULTILINESTRING ((4.98996 52.29640, 4.98959 52...
# 1   MULTILINESTRING ((4.83880 52.38842, 4.83897 52...
# 2   MULTILINESTRING ((4.90193 52.37689, 4.90202 52...
# 3   MULTILINESTRING ((4.83880 52.38842, 4.83897 52...
# 4   MULTILINESTRING ((4.93265 52.40228, 4.93269 52...
# ..                                                ...
# 58  MULTILINESTRING ((4.94749 52.31135, 4.94747 52...
# 59  MULTILINESTRING ((4.82522 52.34015, 4.82543 52...
# 60  MULTILINESTRING ((4.83306 52.34574, 4.83285 52...
# 61  MULTILINESTRING ((4.82444 52.34041, 4.82445 52...
# 62  MULTILINESTRING ((4.83306 52.34574, 4.83285 52...
#
# [101 rows x 8 columns]

# %%
merged_order_route_dict = {key: value for d in [city_sub_order_route_dict, city_tram_order_route_dict, city_bus_order_route_dict] for key, value in d.items()}

# %%
merged_order_route_dict
# Out:
# {'Metro 50: Gein => Isolatorweg':     id                 name                      geometry     geo_x  \
#  0    5                 Gein  POINT (4.9891612 52.2964067)  4.989161
#  1   18           Reigersbos  POINT (4.9740002 52.2956365)     4.974
#  2   17          Holendrecht  POINT (4.9601264 52.2981319)  4.960126
#  3    6            Bullewijk   POINT (4.9521292 52.306869)  4.952129
#  4    4        Bijlmer ArenA   POINT (4.9476178 52.311806)  4.947618
#  5    3          Strandvliet  POINT (4.9413977 52.3186119)  4.941398
#  6   16         Duivendrecht  POINT (4.9365601 52.3236024)   4.93656
#  7    7      Van der Madeweg  POINT (4.9304544 52.3297847)  4.930454
#  8    9           Overamstel  POINT (4.9176063 52.3317688)  4.917606
#  9   19          Station RAI    POINT (4.889539 52.337689)  4.889539
#  10  10                 Zuid  POINT (4.8739633 52.3393223)  4.873963
#  11   8      Amstelveenseweg  POINT (4.8575709 52.3384751)  4.857571
#  12  11    Henk Sneevlietweg  POINT (4.8345741 52.3463868)  4.834574
#  13   2      Heemstedestraat   POINT (4.834401 52.3523291)  4.834401
#  14  12             Lelylaan  POINT (4.8344667 52.3580615)  4.834467
#  15  15           Postjesweg  POINT (4.8340343 52.3645962)  4.834034
#  16  14  Jan van Galenstraat  POINT (4.8353639 52.3725816)  4.835364
#  17  13         De Vlugtlaan   POINT (4.838233 52.3794484)  4.838233
#  18   0   Station Sloterdijk  POINT (4.8389786 52.3890375)  4.838979
#  19   1          Isolatorweg  POINT (4.8505958 52.3951031)  4.850596
#
#          geo_y                route_name_list ref   route  \
#  0   52.296407  Metro 50: Gein => Isolatorweg  50  subway
#  1   52.295637  Metro 50: Gein => Isolatorweg  50  subway
#  2   52.298132  Metro 50: Gein => Isolatorweg  50  subway
#  3   52.306869  Metro 50: Gein => Isolatorweg  50  subway
#  4   52.311806  Metro 50: Gein => Isolatorweg  50  subway
#  5   52.318612  Metro 50: Gein => Isolatorweg  50  subway
#  6   52.323602  Metro 50: Gein => Isolatorweg  50  subway
#  7   52.329785  Metro 50: Gein => Isolatorweg  50  subway
#  8   52.331769  Metro 50: Gein => Isolatorweg  50  subway
#  9   52.337689  Metro 50: Gein => Isolatorweg  50  subway
#  10  52.339322  Metro 50: Gein => Isolatorweg  50  subway
#  11  52.338475  Metro 50: Gein => Isolatorweg  50  subway
#  12  52.346387  Metro 50: Gein => Isolatorweg  50  subway
#  13  52.352329  Metro 50: Gein => Isolatorweg  50  subway
#  14  52.358061  Metro 50: Gein => Isolatorweg  50  subway
#  15  52.364596  Metro 50: Gein => Isolatorweg  50  subway
#  16  52.372582  Metro 50: Gein => Isolatorweg  50  subway
#  17  52.379448  Metro 50: Gein => Isolatorweg  50  subway
#  18  52.389038  Metro 50: Gein => Isolatorweg  50  subway
#  19  52.395103  Metro 50: Gein => Isolatorweg  50  subway
#
#             coordinate_value
#  0   (4.9891612, 52.2964067)
#  1   (4.9740002, 52.2956365)
#  2   (4.9601264, 52.2981319)
#  3    (4.9521292, 52.306869)
#  4    (4.9476178, 52.311806)
#  5   (4.9413977, 52.3186119)
#  6   (4.9365601, 52.3236024)
#  7   (4.9304544, 52.3297847)
#  8   (4.9176063, 52.3317688)
#  9     (4.889539, 52.337689)
#  10  (4.8739633, 52.3393223)
#  11  (4.8575709, 52.3384751)
#  12  (4.8345741, 52.3463868)
#  13   (4.834401, 52.3523291)
#  14  (4.8344667, 52.3580615)
#  15  (4.8340343, 52.3645962)
#  16  (4.8353639, 52.3725816)
#  17   (4.838233, 52.3794484)
#  18  (4.8389786, 52.3890375)
#  19  (4.8505958, 52.3951031)  ,
#  'Metro 50: Isolatorweg => Gein':     id                 name                      geometry     geo_x  \
#  0   11          Isolatorweg  POINT (4.8505967 52.3952329)  4.850597
#  1   13   Station Sloterdijk  POINT (4.8387632 52.3890363)  4.838763
#  2    1         De Vlugtlaan  POINT (4.8380564 52.3794609)  4.838056
#  3   12  Jan van Galenstraat  POINT (4.8351828 52.3725841)  4.835183
#  4    2           Postjesweg  POINT (4.8338612 52.3645995)  4.833861
#  5   10             Lelylaan  POINT (4.8342535 52.3580602)  4.834253
#  6    5      Heemstedestraat  POINT (4.8342252 52.3523254)  4.834225
#  7    3    Henk Sneevlietweg    POINT (4.834395 52.346385)  4.834395
#  8    8      Amstelveenseweg  POINT (4.8575924 52.3383393)  4.857592
#  9    0                 Zuid  POINT (4.8739781 52.3390351)  4.873978
#  10  19          Station RAI  POINT (4.8894203 52.3376062)   4.88942
#  11   9           Overamstel  POINT (4.9177027 52.3316595)  4.917703
#  12   7      Van der Madeweg  POINT (4.9300743 52.3296548)  4.930074
#  13  15         Duivendrecht   POINT (4.936458 52.3235649)  4.936458
#  14  18          Strandvliet  POINT (4.9414198 52.3183621)   4.94142
#  15   6        Bijlmer ArenA  POINT (4.9473959 52.3117311)  4.947396
#  16  14            Bullewijk  POINT (4.9520015 52.3067895)  4.952001
#  17  17          Holendrecht  POINT (4.9599574 52.2980894)  4.959957
#  18   4           Reigersbos  POINT (4.9743774 52.2955964)  4.974377
#  19  16                 Gein   POINT (4.989299 52.2962711)  4.989299
#
#          geo_y                route_name_list ref   route  \
#  0   52.395233  Metro 50: Isolatorweg => Gein  50  subway
#  1   52.389036  Metro 50: Isolatorweg => Gein  50  subway
#  2   52.379461  Metro 50: Isolatorweg => Gein  50  subway
#  3   52.372584  Metro 50: Isolatorweg => Gein  50  subway
#  4   52.364599  Metro 50: Isolatorweg => Gein  50  subway
#  5    52.35806  Metro 50: Isolatorweg => Gein  50  subway
#  6   52.352325  Metro 50: Isolatorweg => Gein  50  subway
#  7   52.346385  Metro 50: Isolatorweg => Gein  50  subway
#  8   52.338339  Metro 50: Isolatorweg => Gein  50  subway
#  9   52.339035  Metro 50: Isolatorweg => Gein  50  subway
#  10  52.337606  Metro 50: Isolatorweg => Gein  50  subway
#  11   52.33166  Metro 50: Isolatorweg => Gein  50  subway
#  12  52.329655  Metro 50: Isolatorweg => Gein  50  subway
#  13  52.323565  Metro 50: Isolatorweg => Gein  50  subway
#  14  52.318362  Metro 50: Isolatorweg => Gein  50  subway
#  15  52.311731  Metro 50: Isolatorweg => Gein  50  subway
#  16   52.30679  Metro 50: Isolatorweg => Gein  50  subway
#  17  52.298089  Metro 50: Isolatorweg => Gein  50  subway
#  18  52.295596  Metro 50: Isolatorweg => Gein  50  subway
#  19  52.296271  Metro 50: Isolatorweg => Gein  50  subway
#
#             coordinate_value
#  0   (4.8505967, 52.3952329)
#  1   (4.8387632, 52.3890363)
#  2   (4.8380564, 52.3794609)
#  3   (4.8351828, 52.3725841)
#  4   (4.8338612, 52.3645995)
#  5   (4.8342535, 52.3580602)
#  6   (4.8342252, 52.3523254)
#  7     (4.834395, 52.346385)
#  8   (4.8575924, 52.3383393)
#  9   (4.8739781, 52.3390351)
#  10  (4.8894203, 52.3376062)
#  11  (4.9177027, 52.3316595)
#  12  (4.9300743, 52.3296548)
#  13   (4.936458, 52.3235649)
#  14  (4.9414198, 52.3183621)
#  15  (4.9473959, 52.3117311)
#  16  (4.9520015, 52.3067895)
#  17  (4.9599574, 52.2980894)
#  18  (4.9743774, 52.2955964)
#  19   (4.989299, 52.2962711)  ,
#  'Metro 51: Centraal Station => Isolatorweg':     id                 name                      geometry     geo_x  \
#  0    4     Centraal Station  POINT (4.9008686 52.3773546)  4.900869
#  1   17           Nieuwmarkt  POINT (4.9009379 52.3714238)  4.900938
#  2   16        Waterlooplein  POINT (4.9036061 52.3666363)  4.903606
#  3   18         Weesperplein  POINT (4.9078472 52.3613094)  4.907847
#  4    3         Wibautstraat  POINT (4.9118953 52.3545601)  4.911895
#  5    5        Amstelstation  POINT (4.9174059 52.3466361)  4.917406
#  6    6           Spaklerweg  POINT (4.9208004 52.3402348)    4.9208
#  7    8           Overamstel  POINT (4.9176682 52.3316938)  4.917668
#  8   15          Station RAI    POINT (4.889539 52.337689)  4.889539
#  9    9                 Zuid  POINT (4.8739633 52.3393223)  4.873963
#  10   7      Amstelveenseweg  POINT (4.8575709 52.3384751)  4.857571
#  11  10    Henk Sneevlietweg  POINT (4.8345741 52.3463868)  4.834574
#  12   2      Heemstedestraat   POINT (4.834401 52.3523291)  4.834401
#  13  11             Lelylaan  POINT (4.8344667 52.3580615)  4.834467
#  14  14           Postjesweg  POINT (4.8340343 52.3645962)  4.834034
#  15  13  Jan van Galenstraat  POINT (4.8353639 52.3725816)  4.835364
#  16  12         De Vlugtlaan   POINT (4.838233 52.3794484)  4.838233
#  17   0   Station Sloterdijk  POINT (4.8389786 52.3890375)  4.838979
#  18   1          Isolatorweg  POINT (4.8505958 52.3951031)  4.850596
#
#          geo_y                            route_name_list ref   route  \
#  0   52.377355  Metro 51: Centraal Station => Isolatorweg  51  subway
#  1   52.371424  Metro 51: Centraal Station => Isolatorweg  51  subway
#  2   52.366636  Metro 51: Centraal Station => Isolatorweg  51  subway
#  3   52.361309  Metro 51: Centraal Station => Isolatorweg  51  subway
#  4    52.35456  Metro 51: Centraal Station => Isolatorweg  51  subway
#  5   52.346636  Metro 51: Centraal Station => Isolatorweg  51  subway
#  6   52.340235  Metro 51: Centraal Station => Isolatorweg  51  subway
#  7   52.331694  Metro 51: Centraal Station => Isolatorweg  51  subway
#  8   52.337689  Metro 51: Centraal Station => Isolatorweg  51  subway
#  9   52.339322  Metro 51: Centraal Station => Isolatorweg  51  subway
#  10  52.338475  Metro 51: Centraal Station => Isolatorweg  51  subway
#  11  52.346387  Metro 51: Centraal Station => Isolatorweg  51  subway
#  12  52.352329  Metro 51: Centraal Station => Isolatorweg  51  subway
#  13  52.358061  Metro 51: Centraal Station => Isolatorweg  51  subway
#  14  52.364596  Metro 51: Centraal Station => Isolatorweg  51  subway
#  15  52.372582  Metro 51: Centraal Station => Isolatorweg  51  subway
#  16  52.379448  Metro 51: Centraal Station => Isolatorweg  51  subway
#  17  52.389038  Metro 51: Centraal Station => Isolatorweg  51  subway
#  18  52.395103  Metro 51: Centraal Station => Isolatorweg  51  subway
#
#             coordinate_value
#  0   (4.9008686, 52.3773546)
#  1   (4.9009379, 52.3714238)
#  2   (4.9036061, 52.3666363)
#  3   (4.9078472, 52.3613094)
#  4   (4.9118953, 52.3545601)
#  5   (4.9174059, 52.3466361)
#  6   (4.9208004, 52.3402348)
#  7   (4.9176682, 52.3316938)
#  8     (4.889539, 52.337689)
#  9   (4.8739633, 52.3393223)
#  10  (4.8575709, 52.3384751)
#  11  (4.8345741, 52.3463868)
#  12   (4.834401, 52.3523291)
#  13  (4.8344667, 52.3580615)
#  14  (4.8340343, 52.3645962)
#  15  (4.8353639, 52.3725816)
#  16   (4.838233, 52.3794484)
#  17  (4.8389786, 52.3890375)
#  18  (4.8505958, 52.3951031)  ,
#  'Metro 51: Isolatorweg => Centraal Station':     id                 name                      geometry     geo_x  \
#  0   12          Isolatorweg  POINT (4.8505967 52.3952329)  4.850597
#  1   14   Station Sloterdijk  POINT (4.8387632 52.3890363)  4.838763
#  2    2         De Vlugtlaan  POINT (4.8380564 52.3794609)  4.838056
#  3   13  Jan van Galenstraat  POINT (4.8351828 52.3725841)  4.835183
#  4    3           Postjesweg  POINT (4.8338612 52.3645995)  4.833861
#  5   11             Lelylaan  POINT (4.8342535 52.3580602)  4.834253
#  6    6      Heemstedestraat  POINT (4.8342252 52.3523254)  4.834225
#  7    4    Henk Sneevlietweg    POINT (4.834395 52.346385)  4.834395
#  8    9      Amstelveenseweg  POINT (4.8575924 52.3383393)  4.857592
#  9    1                 Zuid  POINT (4.8739781 52.3390351)  4.873978
#  10  15          Station RAI  POINT (4.8894203 52.3376062)   4.88942
#  11  10           Overamstel  POINT (4.9177027 52.3316595)  4.917703
#  12   8           Spaklerweg  POINT (4.9208526 52.3402457)  4.920853
#  13   7        Amstelstation  POINT (4.9174767 52.3466483)  4.917477
#  14   0         Wibautstraat  POINT (4.9120486 52.3545947)  4.912049
#  15  18         Weesperplein  POINT (4.9079182 52.3613263)  4.907918
#  16  17        Waterlooplein  POINT (4.9037527 52.3666905)  4.903753
#  17  16           Nieuwmarkt   POINT (4.9010846 52.371353)  4.901085
#  18   5     Centraal Station  POINT (4.9010471 52.3775081)  4.901047
#
#          geo_y                            route_name_list ref   route  \
#  0   52.395233  Metro 51: Isolatorweg => Centraal Station  51  subway
#  1   52.389036  Metro 51: Isolatorweg => Centraal Station  51  subway
#  2   52.379461  Metro 51: Isolatorweg => Centraal Station  51  subway
#  3   52.372584  Metro 51: Isolatorweg => Centraal Station  51  subway
#  4   52.364599  Metro 51: Isolatorweg => Centraal Station  51  subway
#  5    52.35806  Metro 51: Isolatorweg => Centraal Station  51  subway
#  6   52.352325  Metro 51: Isolatorweg => Centraal Station  51  subway
#  7   52.346385  Metro 51: Isolatorweg => Centraal Station  51  subway
#  8   52.338339  Metro 51: Isolatorweg => Centraal Station  51  subway
#  9   52.339035  Metro 51: Isolatorweg => Centraal Station  51  subway
#  10  52.337606  Metro 51: Isolatorweg => Centraal Station  51  subway
#  11   52.33166  Metro 51: Isolatorweg => Centraal Station  51  subway
#  12  52.340246  Metro 51: Isolatorweg => Centraal Station  51  subway
#  13  52.346648  Metro 51: Isolatorweg => Centraal Station  51  subway
#  14  52.354595  Metro 51: Isolatorweg => Centraal Station  51  subway
#  15  52.361326  Metro 51: Isolatorweg => Centraal Station  51  subway
#  16   52.36669  Metro 51: Isolatorweg => Centraal Station  51  subway
#  17  52.371353  Metro 51: Isolatorweg => Centraal Station  51  subway
#  18  52.377508  Metro 51: Isolatorweg => Centraal Station  51  subway
#
#             coordinate_value
#  0   (4.8505967, 52.3952329)
#  1   (4.8387632, 52.3890363)
#  2   (4.8380564, 52.3794609)
#  3   (4.8351828, 52.3725841)
#  4   (4.8338612, 52.3645995)
#  5   (4.8342535, 52.3580602)
#  6   (4.8342252, 52.3523254)
#  7     (4.834395, 52.346385)
#  8   (4.8575924, 52.3383393)
#  9   (4.8739781, 52.3390351)
#  10  (4.8894203, 52.3376062)
#  11  (4.9177027, 52.3316595)
#  12  (4.9208526, 52.3402457)
#  13  (4.9174767, 52.3466483)
#  14  (4.9120486, 52.3545947)
#  15  (4.9079182, 52.3613263)
#  16  (4.9037527, 52.3666905)
#  17   (4.9010846, 52.371353)
#  18  (4.9010471, 52.3775081)  ,
#  'Metro 52: Noord => Zuid':   id              name                      geometry     geo_x      geo_y  \
#  0  2             Noord   POINT (4.932402 52.4021571)  4.932402  52.402157
#  1  3       Noorderpark  POINT (4.9181114 52.3886982)  4.918111  52.388698
#  2  1  Centraal Station  POINT (4.9008785 52.3792082)  4.900879  52.379208
#  3  0             Rokin  POINT (4.8925639 52.3705391)  4.892564  52.370539
#  4  6      Vijzelgracht  POINT (4.8910469 52.3606866)  4.891047  52.360687
#  5  8           De Pijp  POINT (4.8906487 52.3539577)  4.890649  52.353958
#  6  5       Europaplein  POINT (4.8915605 52.3411785)   4.89156  52.341178
#  7  4              Zuid  POINT (4.8743378 52.3392141)  4.874338  52.339214
#
#             route_name_list ref   route         coordinate_value
#  0  Metro 52: Noord => Zuid  52  subway   (4.932402, 52.4021571)
#  1  Metro 52: Noord => Zuid  52  subway  (4.9181114, 52.3886982)
#  2  Metro 52: Noord => Zuid  52  subway  (4.9008785, 52.3792082)
#  3  Metro 52: Noord => Zuid  52  subway  (4.8925639, 52.3705391)
#  4  Metro 52: Noord => Zuid  52  subway  (4.8910469, 52.3606866)
#  5  Metro 52: Noord => Zuid  52  subway  (4.8906487, 52.3539577)
#  6  Metro 52: Noord => Zuid  52  subway  (4.8915605, 52.3411785)
#  7  Metro 52: Noord => Zuid  52  subway  (4.8743378, 52.3392141)  ,
#  'Metro 52: Zuid => Noord':   id              name                      geometry     geo_x      geo_y  \
#  0  3              Zuid  POINT (4.8743378 52.3392141)  4.874338  52.339214
#  1  4       Europaplein  POINT (4.8914299 52.3419224)   4.89143  52.341922
#  2  6           De Pijp  POINT (4.8906476 52.3539585)  4.890648  52.353958
#  3  5      Vijzelgracht  POINT (4.8912207 52.3606661)  4.891221  52.360666
#  4  8             Rokin  POINT (4.8927726 52.3704434)  4.892773  52.370443
#  5  0  Centraal Station  POINT (4.9009371 52.3791884)  4.900937  52.379188
#  6  2       Noorderpark  POINT (4.9182755 52.3885941)  4.918276  52.388594
#  7  1             Noord   POINT (4.932585 52.4020575)  4.932585  52.402057
#
#             route_name_list ref   route         coordinate_value
#  0  Metro 52: Zuid => Noord  52  subway  (4.8743378, 52.3392141)
#  1  Metro 52: Zuid => Noord  52  subway  (4.8914299, 52.3419224)
#  2  Metro 52: Zuid => Noord  52  subway  (4.8906476, 52.3539585)
#  3  Metro 52: Zuid => Noord  52  subway  (4.8912207, 52.3606661)
#  4  Metro 52: Zuid => Noord  52  subway  (4.8927726, 52.3704434)
#  5  Metro 52: Zuid => Noord  52  subway  (4.9009371, 52.3791884)
#  6  Metro 52: Zuid => Noord  52  subway  (4.9182755, 52.3885941)
#  7  Metro 52: Zuid => Noord  52  subway   (4.932585, 52.4020575)  ,
#  'Metro 53: Centraal Station => Gaasperplas':     id                 name                      geometry     geo_x  \
#  0    6     Centraal Station  POINT (4.9008686 52.3773546)  4.900869
#  1   12           Nieuwmarkt  POINT (4.9009379 52.3714238)  4.900938
#  2   11        Waterlooplein  POINT (4.9036061 52.3666363)  4.903606
#  3   13         Weesperplein  POINT (4.9078472 52.3613094)  4.907847
#  4    5         Wibautstraat  POINT (4.9118953 52.3545601)  4.911895
#  5    7        Amstelstation  POINT (4.9174059 52.3466361)  4.917406
#  6   10           Spaklerweg  POINT (4.9206141 52.3401909)  4.920614
#  7    9      Van der Madeweg  POINT (4.9302391 52.3297174)  4.930239
#  8    0         Venserpolder  POINT (4.9464091 52.3267211)  4.946409
#  9    8  Station Diemen Zuid  POINT (4.9567748 52.3303113)  4.956775
#  10   1    Verrijn Stuartweg  POINT (4.9672062 52.3282901)  4.967206
#  11   2           Ganzenhoef  POINT (4.9728869 52.3236783)  4.972887
#  12   3          Kraaiennest  POINT (4.9790073 52.3169789)  4.979007
#  13   4          Gaasperplas  POINT (4.9843391 52.3111615)  4.984339
#
#          geo_y                            route_name_list ref   route  \
#  0   52.377355  Metro 53: Centraal Station => Gaasperplas  53  subway
#  1   52.371424  Metro 53: Centraal Station => Gaasperplas  53  subway
#  2   52.366636  Metro 53: Centraal Station => Gaasperplas  53  subway
#  3   52.361309  Metro 53: Centraal Station => Gaasperplas  53  subway
#  4    52.35456  Metro 53: Centraal Station => Gaasperplas  53  subway
#  5   52.346636  Metro 53: Centraal Station => Gaasperplas  53  subway
#  6   52.340191  Metro 53: Centraal Station => Gaasperplas  53  subway
#  7   52.329717  Metro 53: Centraal Station => Gaasperplas  53  subway
#  8   52.326721  Metro 53: Centraal Station => Gaasperplas  53  subway
#  9   52.330311  Metro 53: Centraal Station => Gaasperplas  53  subway
#  10   52.32829  Metro 53: Centraal Station => Gaasperplas  53  subway
#  11  52.323678  Metro 53: Centraal Station => Gaasperplas  53  subway
#  12  52.316979  Metro 53: Centraal Station => Gaasperplas  53  subway
#  13  52.311161  Metro 53: Centraal Station => Gaasperplas  53  subway
#
#             coordinate_value
#  0   (4.9008686, 52.3773546)
#  1   (4.9009379, 52.3714238)
#  2   (4.9036061, 52.3666363)
#  3   (4.9078472, 52.3613094)
#  4   (4.9118953, 52.3545601)
#  5   (4.9174059, 52.3466361)
#  6   (4.9206141, 52.3401909)
#  7   (4.9302391, 52.3297174)
#  8   (4.9464091, 52.3267211)
#  9   (4.9567748, 52.3303113)
#  10  (4.9672062, 52.3282901)
#  11  (4.9728869, 52.3236783)
#  12  (4.9790073, 52.3169789)
#  13  (4.9843391, 52.3111615)  ,
#  'Metro 53: Gaasperplas => Centraal Station':     id                 name                      geometry     geo_x  \
#  0    3          Gaasperplas  POINT (4.9842364 52.3115025)  4.984236
#  1    5          Kraaiennest  POINT (4.9791866 52.3170385)  4.979187
#  2    2           Ganzenhoef  POINT (4.9730859 52.3237237)  4.973086
#  3    7    Verrijn Stuartweg  POINT (4.9673352 52.3283668)  4.967335
#  4    6  Station Diemen Zuid  POINT (4.9566878 52.3304057)  4.956688
#  5    9         Venserpolder  POINT (4.9462773 52.3268326)  4.946277
#  6    8      Van der Madeweg  POINT (4.9302846 52.3297352)  4.930285
#  7   10           Spaklerweg  POINT (4.9210454 52.3402871)  4.921045
#  8    4        Amstelstation  POINT (4.9174767 52.3466483)  4.917477
#  9    0         Wibautstraat  POINT (4.9120486 52.3545947)  4.912049
#  10  13         Weesperplein  POINT (4.9079182 52.3613263)  4.907918
#  11  12        Waterlooplein  POINT (4.9037527 52.3666905)  4.903753
#  12  11           Nieuwmarkt   POINT (4.9010846 52.371353)  4.901085
#  13   1     Centraal Station  POINT (4.9010471 52.3775081)  4.901047
#
#          geo_y                            route_name_list ref   route  \
#  0   52.311503  Metro 53: Gaasperplas => Centraal Station  53  subway
#  1   52.317039  Metro 53: Gaasperplas => Centraal Station  53  subway
#  2   52.323724  Metro 53: Gaasperplas => Centraal Station  53  subway
#  3   52.328367  Metro 53: Gaasperplas => Centraal Station  53  subway
#  4   52.330406  Metro 53: Gaasperplas => Centraal Station  53  subway
#  5   52.326833  Metro 53: Gaasperplas => Centraal Station  53  subway
#  6   52.329735  Metro 53: Gaasperplas => Centraal Station  53  subway
#  7   52.340287  Metro 53: Gaasperplas => Centraal Station  53  subway
#  8   52.346648  Metro 53: Gaasperplas => Centraal Station  53  subway
#  9   52.354595  Metro 53: Gaasperplas => Centraal Station  53  subway
#  10  52.361326  Metro 53: Gaasperplas => Centraal Station  53  subway
#  11   52.36669  Metro 53: Gaasperplas => Centraal Station  53  subway
#  12  52.371353  Metro 53: Gaasperplas => Centraal Station  53  subway
#  13  52.377508  Metro 53: Gaasperplas => Centraal Station  53  subway
#
#             coordinate_value
#  0   (4.9842364, 52.3115025)
#  1   (4.9791866, 52.3170385)
#  2   (4.9730859, 52.3237237)
#  3   (4.9673352, 52.3283668)
#  4   (4.9566878, 52.3304057)
#  5   (4.9462773, 52.3268326)
#  6   (4.9302846, 52.3297352)
#  7   (4.9210454, 52.3402871)
#  8   (4.9174767, 52.3466483)
#  9   (4.9120486, 52.3545947)
#  10  (4.9079182, 52.3613263)
#  11  (4.9037527, 52.3666905)
#  12   (4.9010846, 52.371353)
#  13  (4.9010471, 52.3775081)  ,
#  'Metro 54: Centraal Station => Gein':     id              name                      geometry     geo_x      geo_y  \
#  0    2  Centraal Station  POINT (4.9008686 52.3773546)  4.900869  52.377355
#  1   13        Nieuwmarkt  POINT (4.9009379 52.3714238)  4.900938  52.371424
#  2   12     Waterlooplein  POINT (4.9036061 52.3666363)  4.903606  52.366636
#  3   14      Weesperplein  POINT (4.9078472 52.3613094)  4.907847  52.361309
#  4    1      Wibautstraat  POINT (4.9118953 52.3545601)  4.911895   52.35456
#  5    4     Amstelstation  POINT (4.9174059 52.3466361)  4.917406  52.346636
#  6    6        Spaklerweg  POINT (4.9206141 52.3401909)  4.920614  52.340191
#  7    5   Van der Madeweg  POINT (4.9300743 52.3296548)  4.930074  52.329655
#  8    8      Duivendrecht   POINT (4.936458 52.3235649)  4.936458  52.323565
#  9   11       Strandvliet  POINT (4.9414198 52.3183621)   4.94142  52.318362
#  10   3     Bijlmer ArenA  POINT (4.9473959 52.3117311)  4.947396  52.311731
#  11   7         Bullewijk  POINT (4.9520015 52.3067895)  4.952001   52.30679
#  12  10       Holendrecht  POINT (4.9599574 52.2980894)  4.959957  52.298089
#  13   0        Reigersbos  POINT (4.9743774 52.2955964)  4.974377  52.295596
#  14   9              Gein   POINT (4.989299 52.2962711)  4.989299  52.296271
#
#                         route_name_list ref   route         coordinate_value
#  0   Metro 54: Centraal Station => Gein  54  subway  (4.9008686, 52.3773546)
#  1   Metro 54: Centraal Station => Gein  54  subway  (4.9009379, 52.3714238)
#  2   Metro 54: Centraal Station => Gein  54  subway  (4.9036061, 52.3666363)
#  3   Metro 54: Centraal Station => Gein  54  subway  (4.9078472, 52.3613094)
#  4   Metro 54: Centraal Station => Gein  54  subway  (4.9118953, 52.3545601)
#  5   Metro 54: Centraal Station => Gein  54  subway  (4.9174059, 52.3466361)
#  6   Metro 54: Centraal Station => Gein  54  subway  (4.9206141, 52.3401909)
#  7   Metro 54: Centraal Station => Gein  54  subway  (4.9300743, 52.3296548)
#  8   Metro 54: Centraal Station => Gein  54  subway   (4.936458, 52.3235649)
#  9   Metro 54: Centraal Station => Gein  54  subway  (4.9414198, 52.3183621)
#  10  Metro 54: Centraal Station => Gein  54  subway  (4.9473959, 52.3117311)
#  11  Metro 54: Centraal Station => Gein  54  subway  (4.9520015, 52.3067895)
#  12  Metro 54: Centraal Station => Gein  54  subway  (4.9599574, 52.2980894)
#  13  Metro 54: Centraal Station => Gein  54  subway  (4.9743774, 52.2955964)
#  14  Metro 54: Centraal Station => Gein  54  subway   (4.989299, 52.2962711)  ,
#  'Metro 54: Gein => Centraal Station':     id              name                      geometry     geo_x      geo_y  \
#  0    4              Gein  POINT (4.9891612 52.2964067)  4.989161  52.296407
#  1   11        Reigersbos  POINT (4.9740002 52.2956365)     4.974  52.295637
#  2   10       Holendrecht  POINT (4.9601264 52.2981319)  4.960126  52.298132
#  3    5         Bullewijk   POINT (4.9521292 52.306869)  4.952129  52.306869
#  4    3     Bijlmer ArenA   POINT (4.9476178 52.311806)  4.947618  52.311806
#  5    2       Strandvliet  POINT (4.9413977 52.3186119)  4.941398  52.318612
#  6    9      Duivendrecht  POINT (4.9365601 52.3236024)   4.93656  52.323602
#  7    7   Van der Madeweg  POINT (4.9304544 52.3297847)  4.930454  52.329785
#  8    8        Spaklerweg  POINT (4.9210454 52.3402871)  4.921045  52.340287
#  9    6     Amstelstation  POINT (4.9174767 52.3466483)  4.917477  52.346648
#  10   0      Wibautstraat  POINT (4.9120486 52.3545947)  4.912049  52.354595
#  11  14      Weesperplein  POINT (4.9079182 52.3613263)  4.907918  52.361326
#  12  13     Waterlooplein  POINT (4.9037527 52.3666905)  4.903753   52.36669
#  13  12        Nieuwmarkt   POINT (4.9010846 52.371353)  4.901085  52.371353
#  14   1  Centraal Station  POINT (4.9010471 52.3775081)  4.901047  52.377508
#
#                         route_name_list ref   route         coordinate_value
#  0   Metro 54: Gein => Centraal Station  54  subway  (4.9891612, 52.2964067)
#  1   Metro 54: Gein => Centraal Station  54  subway  (4.9740002, 52.2956365)
#  2   Metro 54: Gein => Centraal Station  54  subway  (4.9601264, 52.2981319)
#  3   Metro 54: Gein => Centraal Station  54  subway   (4.9521292, 52.306869)
#  4   Metro 54: Gein => Centraal Station  54  subway   (4.9476178, 52.311806)
#  5   Metro 54: Gein => Centraal Station  54  subway  (4.9413977, 52.3186119)
#  6   Metro 54: Gein => Centraal Station  54  subway  (4.9365601, 52.3236024)
#  7   Metro 54: Gein => Centraal Station  54  subway  (4.9304544, 52.3297847)
#  8   Metro 54: Gein => Centraal Station  54  subway  (4.9210454, 52.3402871)
#  9   Metro 54: Gein => Centraal Station  54  subway  (4.9174767, 52.3466483)
#  10  Metro 54: Gein => Centraal Station  54  subway  (4.9120486, 52.3545947)
#  11  Metro 54: Gein => Centraal Station  54  subway  (4.9079182, 52.3613263)
#  12  Metro 54: Gein => Centraal Station  54  subway  (4.9037527, 52.3666905)
#  13  Metro 54: Gein => Centraal Station  54  subway   (4.9010846, 52.371353)
#  14  Metro 54: Gein => Centraal Station  54  subway  (4.9010471, 52.3775081)  ,
#  'Tram 1: Amsterdam Muiderpoortstation =>Amsterdam Osdorp De Aker':     id                              name                      geometry  \
#  0   21                Muiderpoortstation  POINT (4.9326128 52.3607965)
#  1    0                      Dapperstraat  POINT (4.9289422 52.3609314)
#  2    6                    Linnaeusstraat  POINT (4.9257029 52.3601162)
#  3    7                         Beukenweg  POINT (4.9167422 52.3590732)
#  4    4         Korte 's-Gravesandestraat  POINT (4.9135923 52.3623479)
#  5    3                      Weesperplein  POINT (4.9071213 52.3610021)
#  6   22                    Frederiksplein  POINT (4.8978483 52.3594109)
#  7    5                      Vijzelgracht  POINT (4.8921024 52.3595051)
#  8    1                       Rijksmuseum   POINT (4.887104 52.3609734)
#  9   23                       Leidseplein  POINT (4.8810698 52.3632085)
#  10  13  Eerste Constantijn Huygensstraat  POINT (4.8747145 52.3626163)
#  11  24            Jan Pieter Heijestraat   POINT (4.8657924 52.360364)
#  12  10              Rhijnvis Feithstraat  POINT (4.8603541 52.3590503)
#  13   2                     Surinameplein  POINT (4.8509943 52.3580728)
#  14  12                 Derkinderenstraat  POINT (4.8397482 52.3579573)
#  15  20                  Station Lelylaan  POINT (4.8337835 52.3579004)
#  16  16                Johan Huizingalaan  POINT (4.8258953 52.3578123)
#  17  19                     Meer en Vaart    POINT (4.8099119 52.35637)
#  18  17                Louis Davidsstraat  POINT (4.8084929 52.3538423)
#  19  11                          Hoekenes  POINT (4.8018381 52.3524376)
#  20  14                   Baden Powellweg  POINT (4.7944986 52.3509515)
#  21  15                          Ecuplein  POINT (4.7881565 52.3496994)
#  22   9                       Inaristraat  POINT (4.7836582 52.3501979)
#  23   8                           Pilatus   POINT (4.7770976 52.352828)
#  24  18                        Matterhorn  POINT (4.7745043 52.3538687)
#
#         geo_x      geo_y                                    route_name_list  \
#  0   4.932613  52.360796  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  1   4.928942  52.360931  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  2   4.925703  52.360116  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  3   4.916742  52.359073  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  4   4.913592  52.362348  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  5   4.907121  52.361002  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  6   4.897848  52.359411  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  7   4.892102  52.359505  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  8   4.887104  52.360973  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  9    4.88107  52.363208  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  10  4.874714  52.362616  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  11  4.865792  52.360364  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  12  4.860354   52.35905  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  13  4.850994  52.358073  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  14  4.839748  52.357957  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  15  4.833784    52.3579  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  16  4.825895  52.357812  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  17  4.809912   52.35637  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  18  4.808493  52.353842  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  19  4.801838  52.352438  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  20  4.794499  52.350952  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  21  4.788157  52.349699  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  22  4.783658  52.350198  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  23  4.777098  52.352828  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#  24  4.774504  52.353869  Tram 1: Amsterdam Muiderpoortstation =>Amsterd...
#
#     ref route         coordinate_value
#  0    1  tram  (4.9326128, 52.3607965)
#  1    1  tram  (4.9289422, 52.3609314)
#  2    1  tram  (4.9257029, 52.3601162)
#  3    1  tram  (4.9167422, 52.3590732)
#  4    1  tram  (4.9135923, 52.3623479)
#  5    1  tram  (4.9071213, 52.3610021)
#  6    1  tram  (4.8978483, 52.3594109)
#  7    1  tram  (4.8921024, 52.3595051)
#  8    1  tram   (4.887104, 52.3609734)
#  9    1  tram  (4.8810698, 52.3632085)
#  10   1  tram  (4.8747145, 52.3626163)
#  11   1  tram   (4.8657924, 52.360364)
#  12   1  tram  (4.8603541, 52.3590503)
#  13   1  tram  (4.8509943, 52.3580728)
#  14   1  tram  (4.8397482, 52.3579573)
#  15   1  tram  (4.8337835, 52.3579004)
#  16   1  tram  (4.8258953, 52.3578123)
#  17   1  tram    (4.8099119, 52.35637)
#  18   1  tram  (4.8084929, 52.3538423)
#  19   1  tram  (4.8018381, 52.3524376)
#  20   1  tram  (4.7944986, 52.3509515)
#  21   1  tram  (4.7881565, 52.3496994)
#  22   1  tram  (4.7836582, 52.3501979)
#  23   1  tram   (4.7770976, 52.352828)
#  24   1  tram  (4.7745043, 52.3538687)  ,
#  'Tram 1: Amsterdam Osdorp de Aker => Amsterdam Muiderpoortstation':     id                              name                      geometry  \
#  0    5                        Matterhorn  POINT (4.7747567 52.3537327)
#  1   13                           Pilatus   POINT (4.776554 52.3530108)
#  2   14                       Inaristraat  POINT (4.7829483 52.3504489)
#  3    6                          Ecuplein  POINT (4.7888748 52.3498075)
#  4    7                   Baden Powellweg  POINT (4.7951129 52.3510417)
#  5    8                          Hoekenes  POINT (4.8025242 52.3525411)
#  6    9                Louis Davidsstraat  POINT (4.8090899 52.3539266)
#  7    3                     Meer en Vaart  POINT (4.8107529 52.3565093)
#  8   17                Johan Huizingalaan  POINT (4.8262383 52.3577873)
#  9    2                  Station Lelylaan   POINT (4.834559 52.3578798)
#  10   1                 Derkinderenstraat  POINT (4.8401257 52.3579358)
#  11   0                     Surinameplein  POINT (4.8521827 52.3580481)
#  12  10              Rhijnvis Feithstraat  POINT (4.8596776 52.3588447)
#  13  12            Jan Pieter Heijestraat  POINT (4.8666219 52.3605256)
#  14  16  Eerste Constantijn Huygensstraat   POINT (4.874895 52.3626351)
#  15  11                       Leidseplein  POINT (4.8830722 52.3634714)
#  16  21                       Rijksmuseum  POINT (4.8873395 52.3608307)
#  17  23                      Vijzelgracht  POINT (4.8925358 52.3594772)
#  18  22                    Frederiksplein  POINT (4.9000102 52.3596835)
#  19   4                      Weesperplein  POINT (4.9091584 52.3614042)
#  20  24         Korte 's-Gravesandestraat  POINT (4.9141489 52.3624363)
#  21  18                         Beukenweg  POINT (4.9172481 52.3582391)
#  22  20                    Linnaeusstraat  POINT (4.9249118 52.3599165)
#  23  19                      Dapperstraat  POINT (4.9297575 52.3610986)
#  24  15                Muiderpoortstation  POINT (4.9336328 52.3611749)
#
#         geo_x      geo_y                                    route_name_list  \
#  0   4.774757  52.353733  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  1   4.776554  52.353011  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  2   4.782948  52.350449  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  3   4.788875  52.349807  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  4   4.795113  52.351042  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  5   4.802524  52.352541  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  6    4.80909  52.353927  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  7   4.810753  52.356509  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  8   4.826238  52.357787  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  9   4.834559   52.35788  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  10  4.840126  52.357936  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  11  4.852183  52.358048  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  12  4.859678  52.358845  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  13  4.866622  52.360526  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  14  4.874895  52.362635  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  15  4.883072  52.363471  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  16   4.88734  52.360831  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  17  4.892536  52.359477  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  18   4.90001  52.359684  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  19  4.909158  52.361404  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  20  4.914149  52.362436  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  21  4.917248  52.358239  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  22  4.924912  52.359916  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  23  4.929758  52.361099  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#  24  4.933633  52.361175  Tram 1: Amsterdam Osdorp de Aker => Amsterdam ...
#
#     ref route         coordinate_value
#  0    1  tram  (4.7747567, 52.3537327)
#  1    1  tram   (4.776554, 52.3530108)
#  2    1  tram  (4.7829483, 52.3504489)
#  3    1  tram  (4.7888748, 52.3498075)
#  4    1  tram  (4.7951129, 52.3510417)
#  5    1  tram  (4.8025242, 52.3525411)
#  6    1  tram  (4.8090899, 52.3539266)
#  7    1  tram  (4.8107529, 52.3565093)
#  8    1  tram  (4.8262383, 52.3577873)
#  9    1  tram   (4.834559, 52.3578798)
#  10   1  tram  (4.8401257, 52.3579358)
#  11   1  tram  (4.8521827, 52.3580481)
#  12   1  tram  (4.8596776, 52.3588447)
#  13   1  tram  (4.8666219, 52.3605256)
#  14   1  tram   (4.874895, 52.3626351)
#  15   1  tram  (4.8830722, 52.3634714)
#  16   1  tram  (4.8873395, 52.3608307)
#  17   1  tram  (4.8925358, 52.3594772)
#  18   1  tram  (4.9000102, 52.3596835)
#  19   1  tram  (4.9091584, 52.3614042)
#  20   1  tram  (4.9141489, 52.3624363)
#  21   1  tram  (4.9172481, 52.3582391)
#  22   1  tram  (4.9249118, 52.3599165)
#  23   1  tram  (4.9297575, 52.3610986)
#  24   1  tram  (4.9336328, 52.3611749)  ,
#  'Tram 12: Amsterdam Centraal Station => Amsterdam Amstelstation':     id                  name                      geometry     geo_x  \
#  0   15      Centraal Station  POINT (4.8992878 52.3783193)  4.899288
#  1    6      Nieuwezijds Kolk  POINT (4.8930014 52.3758615)  4.893001
#  2    4                   Dam   POINT (4.8908314 52.373751)  4.890831
#  3   18          Paleisstraat   POINT (4.890644 52.3719008)  4.890644
#  4   16          Koningsplein  POINT (4.8893427 52.3677188)  4.889343
#  5    2         Keizersgracht  POINT (4.8863435 52.3659309)  4.886343
#  6    1         Prinsengracht  POINT (4.8843839 52.3650035)  4.884384
#  7   12           Leidseplein  POINT (4.8810698 52.3632085)   4.88107
#  8   17           Museumplein  POINT (4.8806042 52.3587143)  4.880604
#  9    5         Concertgebouw     POINT (4.8798 52.3564107)    4.8798
#  10   0      Roelof Hartplein  POINT (4.8820871 52.3531224)  4.882087
#  11   9               De Pijp  POINT (4.8905961 52.3527058)  4.890596
#  12   8  Cornelis Troostplein   POINT (4.8915363 52.350302)  4.891536
#  13  10         Scheldestraat  POINT (4.8911566 52.3474774)  4.891157
#  14  14            Maasstraat  POINT (4.8947303 52.3468163)   4.89473
#  15   3            Waalstraat  POINT (4.8997164 52.3465631)  4.899716
#  16  11         Victorieplein  POINT (4.9063478 52.3464278)  4.906348
#  17   7            Amsteldijk  POINT (4.9111583 52.3471037)  4.911158
#  18  13         Amstelstation   POINT (4.9178945 52.347445)  4.917895
#
#          geo_y                                    route_name_list ref route  \
#  0   52.378319  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  1   52.375861  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  2   52.373751  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  3   52.371901  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  4   52.367719  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  5   52.365931  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  6   52.365004  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  7   52.363208  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  8   52.358714  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  9   52.356411  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  10  52.353122  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  11  52.352706  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  12  52.350302  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  13  52.347477  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  14  52.346816  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  15  52.346563  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  16  52.346428  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  17  52.347104  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#  18  52.347445  Tram 12: Amsterdam Centraal Station => Amsterd...  12  tram
#
#             coordinate_value
#  0   (4.8992878, 52.3783193)
#  1   (4.8930014, 52.3758615)
#  2    (4.8908314, 52.373751)
#  3    (4.890644, 52.3719008)
#  4   (4.8893427, 52.3677188)
#  5   (4.8863435, 52.3659309)
#  6   (4.8843839, 52.3650035)
#  7   (4.8810698, 52.3632085)
#  8   (4.8806042, 52.3587143)
#  9      (4.8798, 52.3564107)
#  10  (4.8820871, 52.3531224)
#  11  (4.8905961, 52.3527058)
#  12   (4.8915363, 52.350302)
#  13  (4.8911566, 52.3474774)
#  14  (4.8947303, 52.3468163)
#  15  (4.8997164, 52.3465631)
#  16  (4.9063478, 52.3464278)
#  17  (4.9111583, 52.3471037)
#  18   (4.9178945, 52.347445)  ,
#  'Tram 12: Amsterdam Amstelstation => Amsterdam Centraal Station':     id                 name                      geometry     geo_x  \
#  0   13        Amstelstation   POINT (4.9178945 52.347445)  4.917895
#  1    2           Amsteldijk  POINT (4.9109989 52.3471106)  4.910999
#  2    6        Victorieplein  POINT (4.9056743 52.3463657)  4.905674
#  3    3           Waalstraat  POINT (4.9003351 52.3468171)  4.900335
#  4   14           Maasstraat  POINT (4.8954127 52.3470662)  4.895413
#  5    4        Scheldestraat  POINT (4.8915256 52.3472646)  4.891526
#  6   18  v. Hilligaertstraat  POINT (4.8914549 52.3494092)  4.891455
#  7   12              De Pijp  POINT (4.8901771 52.3526769)  4.890177
#  8   17     Roelof Hartplein  POINT (4.8828562 52.3527563)  4.882856
#  9    0        Concertgebouw  POINT (4.8796377 52.3566951)  4.879638
#  10   1          Museumplein   POINT (4.8812446 52.358854)  4.881245
#  11  10          Leidseplein  POINT (4.8829633 52.3642229)  4.882963
#  12  11        Prinsengracht  POINT (4.8845404 52.3650457)   4.88454
#  13   9        Keizersgracht  POINT (4.8865383 52.3659919)  4.886538
#  14   7         Koningsplein   POINT (4.8889206 52.368085)  4.888921
#  15   8         Paleisstraat    POINT (4.890657 52.372357)  4.890657
#  16   5     Nieuwezijds Kolk  POINT (4.8934715 52.3761313)  4.893472
#  17  16     Centraal Station  POINT (4.8988712 52.3786582)  4.898871
#
#          geo_y                                    route_name_list ref route  \
#  0   52.347445  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  1   52.347111  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  2   52.346366  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  3   52.346817  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  4   52.347066  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  5   52.347265  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  6   52.349409  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  7   52.352677  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  8   52.352756  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  9   52.356695  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  10  52.358854  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  11  52.364223  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  12  52.365046  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  13  52.365992  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  14  52.368085  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  15  52.372357  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  16  52.376131  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#  17  52.378658  Tram 12: Amsterdam Amstelstation => Amsterdam ...  12  tram
#
#             coordinate_value
#  0    (4.9178945, 52.347445)
#  1   (4.9109989, 52.3471106)
#  2   (4.9056743, 52.3463657)
#  3   (4.9003351, 52.3468171)
#  4   (4.8954127, 52.3470662)
#  5   (4.8915256, 52.3472646)
#  6   (4.8914549, 52.3494092)
#  7   (4.8901771, 52.3526769)
#  8   (4.8828562, 52.3527563)
#  9   (4.8796377, 52.3566951)
#  10   (4.8812446, 52.358854)
#  11  (4.8829633, 52.3642229)
#  12  (4.8845404, 52.3650457)
#  13  (4.8865383, 52.3659919)
#  14   (4.8889206, 52.368085)
#  15    (4.890657, 52.372357)
#  16  (4.8934715, 52.3761313)
#  17  (4.8988712, 52.3786582)  ,
#  'Tram 13: Amsterdam Centraal Station => Amsterdam Geuzenveld':     id                          name                      geometry     geo_x  \
#  0   18              Centraal Station   POINT (4.8992178 52.378303)  4.899218
#  1   11              Nieuwezijds Kolk  POINT (4.8930014 52.3758615)  4.893001
#  2    3                           Dam   POINT (4.8908314 52.373751)  4.890831
#  3   10                   Westermarkt  POINT (4.8837739 52.3740565)  4.883774
#  4    9                  Marnixstraat  POINT (4.8763385 52.3723364)  4.876339
#  5    0              Bilderdijkstraat  POINT (4.8708148 52.3710541)  4.870815
#  6    2         Willem de Zwijgerlaan  POINT (4.8636349 52.3706925)  4.863635
#  7    1        Admiraal De Ruijterweg   POINT (4.8600128 52.371502)  4.860013
#  8    8              Marco Polostraat  POINT (4.8554942 52.3709604)  4.855494
#  9    7                 Mercatorplein  POINT (4.8507957 52.3701459)  4.850796
#  10  12       Admiraal Helfrichstraat  POINT (4.8438216 52.3694429)  4.843822
#  11  16             Jan Voermanstraat  POINT (4.8378389 52.3697121)  4.837839
#  12  15              Jan Tooropstraat   POINT (4.838103 52.3714267)  4.838103
#  13  17           Jan van Galenstraat  POINT (4.8350051 52.3732337)  4.835005
#  14   6    Burgemeester Rendorpstraat  POINT (4.8277027 52.3743645)  4.827703
#  15   5                Slotermeerlaan  POINT (4.8173607 52.3759547)  4.817361
#  16  13  Burgemeester Van Leeuwenlaan  POINT (4.8117554 52.3765095)  4.811755
#  17  14           Dr. H. Colijnstraat  POINT (4.8065746 52.3769374)  4.806575
#  18   4           Lambertus Zijlplein  POINT (4.8032895 52.3772583)  4.803289
#
#          geo_y                                    route_name_list ref route  \
#  0   52.378303  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  1   52.375861  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  2   52.373751  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  3   52.374057  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  4   52.372336  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  5   52.371054  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  6   52.370692  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  7   52.371502  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  8    52.37096  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  9   52.370146  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  10  52.369443  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  11  52.369712  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  12  52.371427  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  13  52.373234  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  14  52.374364  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  15  52.375955  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
#  16  52.376509  Tram 13: Amsterdam Centraal Station => Amsterd...  13  tram
# ...
#  1   (4.9424082, 52.3771086)
#  2   (4.9373557, 52.3766138)
#  3   (4.9388462, 52.3735497)
#  4   (4.9383916, 52.3713357)
#  5   (4.9394896, 52.3676768)
#  6    (4.939513, 52.3654344)
#  7   (4.9395347, 52.3640185)
#  8   (4.9407792, 52.3588673)
#  9   (4.9396674, 52.3557118)
#  10  (4.9394469, 52.3534031)
#  11  (4.9339137, 52.3501391)
#  12   (4.9286576, 52.347239)
#  13   (4.9243303, 52.345937)
#  14  (4.9193827, 52.3468042)
#  15   (4.9109862, 52.347133)
#  16  (4.9056648, 52.3463845)
#  17  (4.9005987, 52.3444516)
#  18  (4.8963085, 52.3428958)
#  19  (4.8930026, 52.3419109)
#  20  (4.8908081, 52.3444479)
#  21  (4.8896383, 52.3473897)
#  22   (4.881967, 52.3481494)
#  23   (4.8782207, 52.346969)
#  24  (4.8768476, 52.3466757)
#  25  (4.8767388, 52.3426122)
#  26  (4.8736017, 52.3408906)  ,
#  'Bus 65: Amsterdam Station Zuid => Amsterdam KNSM Eiland':     id                 name                      geometry     geo_x  \
#  0   46           Azartplein  POINT (4.9373557 52.3766138)  4.937356
#  1   33         Station Zuid   POINT (4.873716 52.3407537)  4.873716
#  2    0  Prinses Irenestraat  POINT (4.8768182 52.3431077)  4.876818
#  3    1           Stadionweg  POINT (4.8769021 52.3466735)  4.876902
#  4   18           Apollolaan  POINT (4.8822279 52.3482857)  4.882228
#  5   20        Scheldestraat   POINT (4.889616 52.3470291)  4.889616
#  6   31         Scheldeplein  POINT (4.8909465 52.3436421)  4.890947
#  7   42         Dintelstraat  POINT (4.8933247 52.3419034)  4.893325
#  8   41           Maasstraat  POINT (4.8968547 52.3430956)  4.896855
#  9   11           Waalstraat  POINT (4.9010625 52.3446215)  4.901063
#  10   4        Victorieplein  POINT (4.9063597 52.3464044)   4.90636
#  11   3           Amsteldijk  POINT (4.9111659 52.3470823)  4.911166
#  12  32        Amstelstation  POINT (4.9194545 52.3466842)  4.919454
#  13   5         Fizeaustraat  POINT (4.9246384 52.3459384)  4.924638
#  14  17        Maxwellstraat  POINT (4.9301749 52.3480727)  4.930175
#  15  21            Middenweg  POINT (4.9344611 52.3504337)  4.934461
#  16  24             Radioweg   POINT (4.939831 52.3536187)  4.939831
#  17  25        Archimedesweg  POINT (4.9396674 52.3557118)  4.939667
#  18  15        Valentijnkade   POINT (4.940737 52.3589863)  4.940737
#  19  26            Javaplein  POINT (4.9395334 52.3641038)  4.939533
#  20   7        Zeeburgerdijk   POINT (4.9395115 52.365531)  4.939512
#  21   6              Veelaan  POINT (4.9394683 52.3684403)  4.939468
#  22  16           Borneolaan     POINT (4.9386 52.3708048)    4.9386
#  23  48  C. van Eesterenlaan  POINT (4.9388462 52.3735497)  4.938846
#  24  29          Levantplein   POINT (4.9427778 52.377078)  4.942778
#  25  30            KNSM-laan  POINT (4.9459361 52.3771048)  4.945936
#
#          geo_y                                    route_name_list ref route  \
#  0   52.376614  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  1   52.340754  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  2   52.343108  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  3   52.346674  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  4   52.348286  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  5   52.347029  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  6   52.343642  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  7   52.341903  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  8   52.343096  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  9   52.344622  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  10  52.346404  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  11  52.347082  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  12  52.346684  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  13  52.345938  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  14  52.348073  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  15  52.350434  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  16  52.353619  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  17  52.355712  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  18  52.358986  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  19  52.364104  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  20  52.365531  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  21   52.36844  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  22  52.370805  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  23   52.37355  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  24  52.377078  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#  25  52.377105  Bus 65: Amsterdam Station Zuid => Amsterdam KN...  65   bus
#
#             coordinate_value
#  0   (4.9373557, 52.3766138)
#  1    (4.873716, 52.3407537)
#  2   (4.8768182, 52.3431077)
#  3   (4.8769021, 52.3466735)
#  4   (4.8822279, 52.3482857)
#  5    (4.889616, 52.3470291)
#  6   (4.8909465, 52.3436421)
#  7   (4.8933247, 52.3419034)
#  8   (4.8968547, 52.3430956)
#  9   (4.9010625, 52.3446215)
#  10  (4.9063597, 52.3464044)
#  11  (4.9111659, 52.3470823)
#  12  (4.9194545, 52.3466842)
#  13  (4.9246384, 52.3459384)
#  14  (4.9301749, 52.3480727)
#  15  (4.9344611, 52.3504337)
#  16   (4.939831, 52.3536187)
#  17  (4.9396674, 52.3557118)
#  18   (4.940737, 52.3589863)
#  19  (4.9395334, 52.3641038)
#  20   (4.9395115, 52.365531)
#  21  (4.9394683, 52.3684403)
#  22     (4.9386, 52.3708048)
#  23  (4.9388462, 52.3735497)
#  24   (4.9427778, 52.377078)
#  25  (4.9459361, 52.3771048)  ,
#  'Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ArenA':     id                     name                      geometry     geo_x  \
#  0   21     Pieter Martensstraat  POINT (5.0144582 52.3483266)  5.014458
#  1   24         Vennepluimstraat  POINT (4.9912925 52.3571984)  4.991293
#  2   23           Diemerparklaan  POINT (4.9957586 52.3548394)  4.995759
#  3   10            Lumièrestraat  POINT (5.0002141 52.3524736)  5.000214
#  4   22  Pieter Oosterhuisstraat  POINT (5.0075027 52.3518653)  5.007503
#  5   20      Diemen, Diemerknoop  POINT (5.0030154 52.3354164)  5.003015
#  6    7              Stammerkamp  POINT (4.9829371 52.3333748)  4.982937
#  7   18      Diemen, Stammerkamp  POINT (4.9829301 52.3333284)   4.98293
#  8    1               Vinkenbrug  POINT (4.9788636 52.3337164)  4.978864
#  9   19       Diemen, Vinkenburg  POINT (4.9788496 52.3336556)   4.97885
#  10   0           Provincialeweg  POINT (4.9718582 52.3276691)  4.971858
#  11  26   Diemen, Provincialeweg  POINT (4.9719251 52.3276346)  4.971925
#  12  27             Geldershoofd  POINT (4.9709355 52.3250219)  4.970936
#  13  29       Station Ganzenhoef  POINT (4.9729525 52.3224051)  4.972952
#  14   9        Annie Romeinplein  POINT (4.9700257 52.3214479)  4.970026
#  15   6               Tulastraat  POINT (4.9653709 52.3199551)  4.965371
#  16   4                  Florijn  POINT (4.9586722 52.3176176)  4.958672
#  17   5        Anton de Komplein  POINT (4.9541152 52.3160401)  4.954115
#  18  12             Bijlmerplein  POINT (4.9490731 52.3142965)  4.949073
#  19   2            Foppingadreef  POINT (4.9493119 52.3130617)  4.949312
#  20  11    Station Bijlmer ArenA  POINT (4.9474375 52.3113653)  4.947438
#
#          geo_y                                    route_name_list ref route  \
#  0   52.348327  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  1   52.357198  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  2   52.354839  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  3   52.352474  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  4   52.351865  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  5   52.335416  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  6   52.333375  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  7   52.333328  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  8   52.333716  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  9   52.333656  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  10  52.327669  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  11  52.327635  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  12  52.325022  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  13  52.322405  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  14  52.321448  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  15  52.319955  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  16  52.317618  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  17   52.31604  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  18  52.314296  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  19  52.313062  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#  20  52.311365  Bus 66: Amsterdam IJburg => Amsterdam Bijlmer ...  66   bus
#
#             coordinate_value
#  0   (5.0144582, 52.3483266)
#  1   (4.9912925, 52.3571984)
#  2   (4.9957586, 52.3548394)
#  3   (5.0002141, 52.3524736)
#  4   (5.0075027, 52.3518653)
#  5   (5.0030154, 52.3354164)
#  6   (4.9829371, 52.3333748)
#  7   (4.9829301, 52.3333284)
#  8   (4.9788636, 52.3337164)
#  9   (4.9788496, 52.3336556)
#  10  (4.9718582, 52.3276691)
#  11  (4.9719251, 52.3276346)
#  12  (4.9709355, 52.3250219)
#  13  (4.9729525, 52.3224051)
#  14  (4.9700257, 52.3214479)
#  15  (4.9653709, 52.3199551)
#  16  (4.9586722, 52.3176176)
#  17  (4.9541152, 52.3160401)
#  18  (4.9490731, 52.3142965)
#  19  (4.9493119, 52.3130617)
#  20  (4.9474375, 52.3113653)  ,
#  'Bus 66: Amsterdam Bijlmer ArenA => Amsterdam IJburg':     id                     name                      geometry     geo_x  \
#  0    3    Station Bijlmer ArenA  POINT (4.9474683 52.3113329)  4.947468
#  1   21            Foppingadreef  POINT (4.9498074 52.3127334)  4.949807
#  2    9             Bijlmerplein  POINT (4.9494963 52.3143341)  4.949496
#  3    2        Anton de Komplein  POINT (4.9558884 52.3164584)  4.955888
#  4   10                  Florijn  POINT (4.9596498 52.3177953)   4.95965
#  5    0               Tulastraat    POINT (4.96581 52.3198302)   4.96581
#  6    4        Annie Romeinplein  POINT (4.9715166 52.3216851)  4.971517
#  7   13       Station Ganzenhoef   POINT (4.9732278 52.323056)  4.973228
#  8   23             Geldershoofd  POINT (4.9707228 52.3252556)  4.970723
#  9    5   Diemen, Provincialeweg  POINT (4.9726754 52.3279964)  4.972675
#  10  15       Diemen, Vinkenburg  POINT (4.9783717 52.3336649)  4.978372
#  11   1              Stammerkamp  POINT (4.9833779 52.3331678)  4.983378
#  12  14      Diemen, Stammerkamp  POINT (4.9833777 52.3332213)  4.983378
#  13  16      Diemen, Diemerknoop  POINT (5.0027574 52.3353668)  5.002757
#  14  17     Pieter Martensstraat   POINT (5.0142692 52.348784)  5.014269
#  15  18  Pieter Oosterhuisstraat  POINT (5.0072883 52.3520178)  5.007288
#  16   7            Lumièrestraat  POINT (4.9991732 52.3532416)  4.999173
#  17  19           Diemerparklaan   POINT (4.9947414 52.355608)  4.994741
#  18  20         Vennepluimstraat  POINT (4.9912925 52.3571984)  4.991293
#
#          geo_y                                    route_name_list ref route  \
#  0   52.311333  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  1   52.312733  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  2   52.314334  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  3   52.316458  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  4   52.317795  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  5    52.31983  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  6   52.321685  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  7   52.323056  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  8   52.325256  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  9   52.327996  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  10  52.333665  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  11  52.333168  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  12  52.333221  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  13  52.335367  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  14  52.348784  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  15  52.352018  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  16  52.353242  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  17  52.355608  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#  18  52.357198  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...  66   bus
#
#             coordinate_value
#  0   (4.9474683, 52.3113329)
#  1   (4.9498074, 52.3127334)
#  2   (4.9494963, 52.3143341)
#  3   (4.9558884, 52.3164584)
#  4   (4.9596498, 52.3177953)
#  5     (4.96581, 52.3198302)
#  6   (4.9715166, 52.3216851)
#  7    (4.9732278, 52.323056)
#  8   (4.9707228, 52.3252556)
#  9   (4.9726754, 52.3279964)
#  10  (4.9783717, 52.3336649)
#  11  (4.9833779, 52.3331678)
#  12  (4.9833777, 52.3332213)
#  13  (5.0027574, 52.3353668)
#  14   (5.0142692, 52.348784)
#  15  (5.0072883, 52.3520178)
#  16  (4.9991732, 52.3532416)
#  17   (4.9947414, 52.355608)
#  18  (4.9912925, 52.3571984)  ,
#  'Bus 68: Amsterdam Riekerpolder => Amsterdam Henk Sneevlietweg':   id                 name                      geometry     geo_x      geo_y  \
#  0  4      Adam Smithplein  POINT (4.8216284 52.3396829)  4.821628  52.339683
#  1  2  John M. Keynesplein    POINT (4.824444 52.340413)  4.824444  52.340413
#  2  3                  IBM   POINT (4.827888 52.3410803)  4.827888   52.34108
#  3  0           Parkeerdek  POINT (4.8286682 52.3425954)  4.828668  52.342595
#  4  1    Henk Sneevlietweg  POINT (4.8330587 52.3457424)  4.833059  52.345742
#
#                                       route_name_list ref route  \
#  0  Bus 68: Amsterdam Riekerpolder => Amsterdam He...  68   bus
#  1  Bus 68: Amsterdam Riekerpolder => Amsterdam He...  68   bus
#  2  Bus 68: Amsterdam Riekerpolder => Amsterdam He...  68   bus
#  3  Bus 68: Amsterdam Riekerpolder => Amsterdam He...  68   bus
#  4  Bus 68: Amsterdam Riekerpolder => Amsterdam He...  68   bus
#
#            coordinate_value
#  0  (4.8216284, 52.3396829)
#  1    (4.824444, 52.340413)
#  2   (4.827888, 52.3410803)
#  3  (4.8286682, 52.3425954)
#  4  (4.8330587, 52.3457424)  ,
#  'Bus 68: Amsterdam Henk Sneevlietweg => Amsterdam Riekerpolder':   id                 name                      geometry     geo_x      geo_y  \
#  0  4      Adam Smithplein  POINT (4.8216284 52.3396829)  4.821628  52.339683
#  1  1    Henk Sneevlietweg  POINT (4.8330587 52.3457424)  4.833059  52.345742
#  2  0           Parkeerdek  POINT (4.8286682 52.3425954)  4.828668  52.342595
#  3  2                  IBM  POINT (4.8276171 52.3407116)  4.827617  52.340712
#  4  3  John M. Keynesplein   POINT (4.8252211 52.340147)  4.825221  52.340147
#
#                                       route_name_list ref route  \
#  0  Bus 68: Amsterdam Henk Sneevlietweg => Amsterd...  68   bus
#  1  Bus 68: Amsterdam Henk Sneevlietweg => Amsterd...  68   bus
#  2  Bus 68: Amsterdam Henk Sneevlietweg => Amsterd...  68   bus
#  3  Bus 68: Amsterdam Henk Sneevlietweg => Amsterd...  68   bus
#  4  Bus 68: Amsterdam Henk Sneevlietweg => Amsterd...  68   bus
#
#            coordinate_value
#  0  (4.8216284, 52.3396829)
#  1  (4.8330587, 52.3457424)
#  2  (4.8286682, 52.3425954)
#  3  (4.8276171, 52.3407116)
#  4   (4.8252211, 52.340147)  }

# %% [markdown]
# # Adding ref_transfer_all column and get three_network_nodes_transfer_all

# %%
# convert coordinates in station_df from degree to meter
def convert_deg_to_meter(new_nodes_df):
    # Convert the 'geometry' column to a Point object
    new_nodes_df['geometry'] = new_nodes_df.apply(lambda row: Point(row['geo_x'], row['geo_y']), axis=1)
    
    # Define the coordinate reference systems (CRS)
    crs_deg = 'EPSG:4326'  # WGS 84, the standard coordinate system for GPS
    crs_meter = 'EPSG:3857'  # World Mercator, commonly used for distance calculations

    # Create a transformer to convert from degrees to meters
    transformer = Transformer.from_crs(crs_deg, crs_meter, always_xy=True)

    # Apply the transformer to each Point in the 'geometry' column
    new_nodes_df['geometry'] = new_nodes_df['geometry'].apply(lambda point: Point(transformer.transform(point.x, point.y)))
    
    return new_nodes_df

# %%
def new_nodes_buffer(new_nodes_df,buffer_radius):
    new_nodes_df = convert_deg_to_meter(new_nodes_df)
    node_buffers = []

    for index, row in new_nodes_df.iterrows():
        point = row['geometry']
        buffer = point.buffer(buffer_radius)
        node_buffers.append(buffer)

    buffered_gdf = gpd.GeoDataFrame(geometry=node_buffers)
    buffered_df = pd.DataFrame(buffered_gdf).rename(columns={'geometry': 'buffer_geometry'})
    new_nodes_buffer_geometry = pd.concat([new_nodes_df,buffered_df],axis=1)
    return new_nodes_buffer_geometry

# %%
def add_footnote_to_new_nodes(new_nodes_df):
    new_nodes_df = convert_deg_to_meter(new_nodes_df)
    # create a exactly same dataframe with new_nodes_df but name columns by different transportation routes
    rename_cols = {
    "geometry": "geometry"+"_"+new_nodes_df.loc[0,'route'],
    "degree": "degree"+"_"+new_nodes_df.loc[0,'route'],
    "id": "id"+"_"+new_nodes_df.loc[0,'route'],
    "name": "name"+"_"+new_nodes_df.loc[0,'route'],
    "geo_x": "geo_x"+"_"+new_nodes_df.loc[0,'route'],
    "geo_y": "geo_y"+"_"+new_nodes_df.loc[0,'route'],
    "coordinate_value": "coordinate_value"+"_"+new_nodes_df.loc[0,'route'],
    "route_name_list": "route_name_list"+"_"+new_nodes_df.loc[0,'route'],
    "route": "route"+"_"+new_nodes_df.loc[0,'route'],
    "ref": "ref"+"_"+new_nodes_df.loc[0,'route'],
    "transfer": "transfer"+"_"+new_nodes_df.loc[0,'route']
    }
    new_nodes_ftn = new_nodes_df.rename(columns=rename_cols)
    return new_nodes_ftn

# %%
def transfer_A_to_B(A_new_nodes_buffer_geometry,B_new_nodes_ftn):
    transfer_stations_A_to_B = pd.DataFrame()
    
    for index, row in A_new_nodes_buffer_geometry.iterrows():
        each_transfer_stations_df = B_new_nodes_ftn[row['buffer_geometry'].intersects(B_new_nodes_ftn.iloc[:, 0])]
        
        if not each_transfer_stations_df.empty:
            replicated_row = pd.concat([row] * len(each_transfer_stations_df), axis=1).transpose()
            replicated_row.reset_index(drop=True, inplace=True)  # Reset the index
            each_transfer_stations_df.reset_index(drop=True, inplace=True)  # Reset the index
            co_df = pd.concat([replicated_row,each_transfer_stations_df], axis=1)
            transfer_stations_A_to_B = pd.concat([transfer_stations_A_to_B,co_df])
            
       

    return transfer_stations_A_to_B

# %%
def process_ref_transfer_all(cell_value):
    if pd.notna(cell_value):  # 检查是否是 NaN 值
        return set(filter(lambda x: x != 'nan', map(str.strip, cell_value.split(','))))
    else:
        return set()

# %%
def add_ref_transfer_all_to_new_nodes(transfer_stations_A_to_B, transfer_stations_A_to_C, A_new_nodes):

    selected_columns_to_B = transfer_stations_A_to_B.iloc[:, [0, 3, 9,21]]

    unique_rows_to_B = selected_columns_to_B.drop_duplicates(subset='geometry')

    unique_rows_to_B['ref_1'] = unique_rows_to_B.apply(lambda row: f"{row.iloc[2]}, {row.iloc[3]}", axis=1)


    transfer_ref_to_B = unique_rows_to_B[['name', 'ref_1']].drop_duplicates(subset='name')

    A_new_nodes_to_B = pd.merge(A_new_nodes,transfer_ref_to_B,on = 'name', how = 'left')

    
    selected_columns_to_C = transfer_stations_A_to_C.iloc[:, [0, 3, 9,21]]

    unique_rows_to_C = selected_columns_to_C.drop_duplicates(subset='geometry')

    unique_rows_to_C['ref_2'] = unique_rows_to_C.apply(lambda row: f"{row.iloc[2]}, {row.iloc[3]}", axis=1)


    transfer_ref_to_C = unique_rows_to_C[['name', 'ref_2']].drop_duplicates(subset='name')

    A_new_nodes_to_B_C = pd.merge(A_new_nodes_to_B,transfer_ref_to_C,on = 'name', how = 'left')
    

    A_new_nodes_to_B_C['ref_transfer_all'] = A_new_nodes_to_B_C.apply(lambda row: f"{row['ref']}, {row['ref_1']}, {row['ref_2']}", axis=1)
    
    A_new_nodes_to_B_C['ref_transfer_all'] = A_new_nodes_to_B_C['ref_transfer_all'].apply(process_ref_transfer_all)

    A_new_nodes_transfer_all = A_new_nodes_to_B_C
    

    return A_new_nodes_transfer_all

# %%
buffer_radius = 200

# %%
city_sub_new_nodes_buffer_geometry = new_nodes_buffer(city_sub_new_nodes,buffer_radius)

city_tram_new_nodes_ftn = add_footnote_to_new_nodes(city_tram_new_nodes)
transfer_stations_sub_to_tram = transfer_A_to_B(city_sub_new_nodes_buffer_geometry,city_tram_new_nodes_ftn)

city_bus_new_nodes_ftn = add_footnote_to_new_nodes(city_bus_new_nodes)
transfer_stations_sub_to_bus = transfer_A_to_B(city_sub_new_nodes_buffer_geometry,city_bus_new_nodes_ftn)

city_sub_new_nodes_transfer_all = add_ref_transfer_all_to_new_nodes(transfer_stations_sub_to_tram, transfer_stations_sub_to_bus, city_sub_new_nodes)
city_sub_new_nodes_transfer_all
# Out:
#                           geometry  degree   id                 name  \
# 0   POINT (555390.884 6853898.052)       2  328                 Gein
# 1   POINT (553703.169 6853757.861)       2  855           Reigersbos
# 2   POINT (552158.745 6854212.080)       2  854          Holendrecht
# 3   POINT (551268.501 6855802.630)       2  810            Bullewijk
# 4   POINT (550766.294 6856701.528)       2  809        Bijlmer ArenA
# ..                             ...     ...  ...                  ...
# 81  POINT (552961.225 6859717.546)       2  824    Verrijn Stuartweg
# 82  POINT (551775.962 6860088.944)       2  823  Station Diemen Zuid
# 83  POINT (550617.070 6859438.093)       2  829         Venserpolder
# 84  POINT (548836.771 6859966.806)       2  827      Van der Madeweg
# 85  POINT (547808.268 6861889.144)       2  833           Spaklerweg
#
#        geo_x      geo_y         coordinate_value  \
# 0   4.989161  52.296407  (4.9891612, 52.2964067)
# 1   4.974000  52.295637  (4.9740002, 52.2956365)
# 2   4.960126  52.298132  (4.9601264, 52.2981319)
# 3   4.952129  52.306869   (4.9521292, 52.306869)
# 4   4.947618  52.311806   (4.9476178, 52.311806)
# ..       ...        ...                      ...
# 81  4.967335  52.328367  (4.9673352, 52.3283668)
# 82  4.956688  52.330406  (4.9566878, 52.3304057)
# 83  4.946277  52.326833  (4.9462773, 52.3268326)
# 84  4.930285  52.329735  (4.9302846, 52.3297352)
# 85  4.921045  52.340287  (4.9210454, 52.3402871)
#
#                               route_name_list   route         ref    transfer  \
# 0               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# 1               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# 2               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# 3               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# 4               Metro 50: Gein => Isolatorweg  subway      50, 54      50, 54
# ..                                        ...     ...         ...         ...
# 81  Metro 53: Gaasperplas => Centraal Station  subway          53        None
# 82  Metro 53: Gaasperplas => Centraal Station  subway          53        None
# 83  Metro 53: Gaasperplas => Centraal Station  subway          53        None
# 84  Metro 53: Gaasperplas => Centraal Station  subway  50, 53, 54  50, 53, 54
# 85  Metro 53: Gaasperplas => Centraal Station  subway  51, 53, 54  51, 53, 54
#
#    ref_1                   ref_2          ref_transfer_all
# 0    NaN              50, 54, 47              {47, 50, 54}
# 1    NaN              50, 54, 47              {47, 50, 54}
# 2    NaN                     NaN                  {50, 54}
# 3    NaN                     NaN                  {50, 54}
# 4    NaN  50, 54, 44, 47, 49, 66  {54, 44, 50, 47, 66, 49}
# ..   ...                     ...                       ...
# 81   NaN                     NaN                      {53}
# 82   NaN                  53, 44                  {44, 53}
# 83   NaN                     NaN                      {53}
# 84   NaN                     NaN              {54, 50, 53}
# 85   NaN                     NaN              {51, 54, 53}
#
# [86 rows x 14 columns]

# %%
city_tram_new_nodes_buffer_geometry = new_nodes_buffer(city_tram_new_nodes,buffer_radius)

city_sub_new_nodes_ftn = add_footnote_to_new_nodes(city_sub_new_nodes)
transfer_stations_tram_to_sub = transfer_A_to_B(city_tram_new_nodes_buffer_geometry,city_sub_new_nodes_ftn)

city_bus_new_nodes_ftn = add_footnote_to_new_nodes(city_bus_new_nodes)
transfer_stations_tram_to_bus = transfer_A_to_B(city_tram_new_nodes_buffer_geometry,city_bus_new_nodes_ftn)

city_tram_new_nodes_transfer_all = add_ref_transfer_all_to_new_nodes(transfer_stations_tram_to_sub, transfer_stations_tram_to_bus, city_tram_new_nodes)
city_tram_new_nodes_transfer_all
# Out:
#                            geometry  degree    id                       name  \
# 0    POINT (549095.945 6865626.846)       2  1341         Muiderpoortstation
# 1    POINT (548687.336 6865651.437)       2  1503               Dapperstraat
# 2    POINT (548326.739 6865502.838)       2  1606             Linnaeusstraat
# 3    POINT (547329.238 6865312.719)       2  1612                  Beukenweg
# 4    POINT (546978.593 6865909.649)       2  1598  Korte 's-Gravesandestraat
# ..                              ...     ...   ...                        ...
# 413  POINT (548393.230 6866966.046)       2  1559      Eerste Coehoornstraat
# 414  POINT (548760.528 6867340.750)       2  1808    Eerste Leeghwaterstraat
# 415  POINT (549343.063 6867853.627)       2  1515               Rietlandpark
# 416  POINT (549714.592 6867935.478)       2  1751        C. van Eesterenlaan
# 417  POINT (549622.943 6868547.883)       2   414                 Azartplein
#
#         geo_x      geo_y         coordinate_value  \
# 0    4.932613  52.360796  (4.9326128, 52.3607965)
# 1    4.928942  52.360931  (4.9289422, 52.3609314)
# 2    4.925703  52.360116  (4.9257029, 52.3601162)
# 3    4.916742  52.359073  (4.9167422, 52.3590732)
# 4    4.913592  52.362348  (4.9135923, 52.3623479)
# ..        ...        ...                      ...
# 413  4.926300  52.368143  (4.9263002, 52.3681426)
# 414  4.929600  52.370198  (4.9295997, 52.3701978)
# 415  4.934833  52.373011  (4.9348327, 52.3730107)
# 416  4.938170  52.373460  (4.9381702, 52.3734596)
# 417  4.937347  52.376818  (4.9373469, 52.3768181)
#
#                                        route_name_list route       ref  \
# 0    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram      1, 3
# 1    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram      1, 3
# 2    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram      1, 3
# 3    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram      1, 3
# 4    Tram 1: Amsterdam Muiderpoortstation =>Amsterd...  tram  1, 19, 7
# ..                                                 ...   ...       ...
# 413  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram         7
# 414  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram         7
# 415  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram     26, 7
# 416  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram         7
# 417  Tram 7: Amsterdam Slotermeer => Amsterdam Azar...  tram         7
#
#      transfer ref_1                           ref_2  \
# 0        1, 3   NaN  1, 3, 22, 240, 245, 37, 40, 41
# 1        1, 3   NaN               1, 3, 245, 37, 41
# 2        1, 3   NaN               1, 3, 245, 37, 41
# 3        1, 3   NaN                             NaN
# 4    1, 19, 7   NaN                             NaN
# ..        ...   ...                             ...
# 413      None   NaN                           7, 22
# 414      None   NaN                             NaN
# 415     26, 7   NaN                             NaN
# 416      None   NaN                  7, 246, 43, 65
# 417      None   NaN                  7, 246, 43, 65
#
#                      ref_transfer_all
# 0    {245, 1, 240, 37, 40, 41, 22, 3}
# 1                 {245, 1, 37, 41, 3}
# 2                 {245, 1, 37, 41, 3}
# 3                              {3, 1}
# 4                          {19, 7, 1}
# ..                                ...
# 413                           {7, 22}
# 414                               {7}
# 415                           {7, 26}
# 416                  {246, 43, 7, 65}
# 417                  {246, 43, 7, 65}
#
# [418 rows x 14 columns]

# %%
city_bus_new_nodes_buffer_geometry = new_nodes_buffer(city_bus_new_nodes,buffer_radius)

sub_new_nodes_ftn = add_footnote_to_new_nodes(city_sub_new_nodes)
transfer_stations_bus_to_sub = transfer_A_to_B(city_bus_new_nodes_buffer_geometry,city_sub_new_nodes_ftn)

city_tram_new_nodes_ftn = add_footnote_to_new_nodes(city_tram_new_nodes)
transfer_stations_bus_to_tram = transfer_A_to_B(city_bus_new_nodes_buffer_geometry,city_tram_new_nodes_ftn)

city_bus_new_nodes_transfer_all = add_ref_transfer_all_to_new_nodes(transfer_stations_bus_to_sub, transfer_stations_bus_to_tram, city_bus_new_nodes)
city_bus_new_nodes_transfer_all
# Out:
#                            geometry  degree     id                   name  \
# 0    POINT (542352.511 6861986.021)       2  14779           Station Zuid
# 1    POINT (541935.542 6862364.157)       2  67476    Prinses Irenestraat
# 2    POINT (541665.280 6862982.298)       2  68204           Olympiaplein
# 3    POINT (540828.703 6862792.858)       2  68196             Olympiaweg
# 4    POINT (540749.065 6863516.510)       2  68341  Haarlemmermeerstation
# ..                              ...     ...    ...                    ...
# 752  POINT (556012.069 6864681.113)       2  67471         Diemerparklaan
# 753  POINT (537054.649 6861912.084)       3  15699    John M. Keynesplein
# 754  POINT (537438.034 6862033.668)       2  11244                    IBM
# 755  POINT (537524.885 6862309.730)       3  26843             Parkeerdek
# 756  POINT (538013.633 6862883.167)       2  31909      Henk Sneevlietweg
#
#         geo_x      geo_y         coordinate_value  \
# 0    4.872035  52.340819  (4.8720355, 52.3408188)
# 1    4.868290  52.342894  (4.8682898, 52.3428941)
# 2    4.865862  52.346286   (4.865862, 52.3462864)
# 3    4.858347  52.345247  (4.8583469, 52.3452468)
# 4    4.857632  52.349218  (4.8576315, 52.3492179)
# ..        ...        ...                      ...
# 752  4.994741  52.355608   (4.9947414, 52.355608)
# 753  4.824444  52.340413    (4.824444, 52.340413)
# 754  4.827888  52.341080   (4.827888, 52.3410803)
# 755  4.828668  52.342595  (4.8286682, 52.3425954)
# 756  4.833059  52.345742  (4.8330587, 52.3457424)
#
#                                        route_name_list route          ref  \
# 0    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus   15, 62, 65
# 1    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus  15, 246, 65
# 2    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus           15
# 3    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus           15
# 4    Bus 15: Amsterdam Station Zuid => Amsterdam St...   bus       15, 62
# ..                                                 ...   ...          ...
# 752  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...   bus           66
# 753  Bus 68: Amsterdam Riekerpolder => Amsterdam He...   bus      267, 68
# 754  Bus 68: Amsterdam Riekerpolder => Amsterdam He...   bus      267, 68
# 755  Bus 68: Amsterdam Riekerpolder => Amsterdam He...   bus           68
# 756  Bus 68: Amsterdam Riekerpolder => Amsterdam He...   bus           68
#
#         transfer       ref_1              ref_2     ref_transfer_all
# 0     15, 62, 65         NaN  15, 62, 65, 25, 5  {62, 5, 25, 15, 65}
# 1    15, 246, 65         NaN     15, 246, 65, 5     {246, 5, 15, 65}
# 2           None         NaN             15, 24             {24, 15}
# 3           None         NaN             15, 24             {24, 15}
# 4         15, 62         NaN                NaN             {62, 15}
# ..           ...         ...                ...                  ...
# 752         None         NaN             66, 26             {66, 26}
# 753      267, 68         NaN                NaN            {267, 68}
# 754      267, 68         NaN                NaN            {267, 68}
# 755         None         NaN                NaN                 {68}
# 756         None  68, 50, 51                NaN         {51, 50, 68}
#
# [757 rows x 14 columns]

# %%
three_networks_nodes_transfer_all = pd.concat([city_sub_new_nodes_transfer_all,city_tram_new_nodes_transfer_all,city_bus_new_nodes_transfer_all]).reset_index(drop=True)

# %%
three_networks_nodes_transfer_all
# Out:
#                             geometry  degree     id                 name  \
# 0     POINT (555390.884 6853898.052)       2    328                 Gein
# 1     POINT (553703.169 6853757.861)       2    855           Reigersbos
# 2     POINT (552158.745 6854212.080)       2    854          Holendrecht
# 3     POINT (551268.501 6855802.630)       2    810            Bullewijk
# 4     POINT (550766.294 6856701.528)       2    809        Bijlmer ArenA
# ...                              ...     ...    ...                  ...
# 1256  POINT (556012.069 6864681.113)       2  67471       Diemerparklaan
# 1257  POINT (537054.649 6861912.084)       3  15699  John M. Keynesplein
# 1258  POINT (537438.034 6862033.668)       2  11244                  IBM
# 1259  POINT (537524.885 6862309.730)       3  26843           Parkeerdek
# 1260  POINT (538013.633 6862883.167)       2  31909    Henk Sneevlietweg
#
#          geo_x      geo_y         coordinate_value  \
# 0     4.989161  52.296407  (4.9891612, 52.2964067)
# 1     4.974000  52.295637  (4.9740002, 52.2956365)
# 2     4.960126  52.298132  (4.9601264, 52.2981319)
# 3     4.952129  52.306869   (4.9521292, 52.306869)
# 4     4.947618  52.311806   (4.9476178, 52.311806)
# ...        ...        ...                      ...
# 1256  4.994741  52.355608   (4.9947414, 52.355608)
# 1257  4.824444  52.340413    (4.824444, 52.340413)
# 1258  4.827888  52.341080   (4.827888, 52.3410803)
# 1259  4.828668  52.342595  (4.8286682, 52.3425954)
# 1260  4.833059  52.345742  (4.8330587, 52.3457424)
#
#                                         route_name_list   route      ref  \
# 0                         Metro 50: Gein => Isolatorweg  subway   50, 54
# 1                         Metro 50: Gein => Isolatorweg  subway   50, 54
# 2                         Metro 50: Gein => Isolatorweg  subway   50, 54
# 3                         Metro 50: Gein => Isolatorweg  subway   50, 54
# 4                         Metro 50: Gein => Isolatorweg  subway   50, 54
# ...                                                 ...     ...      ...
# 1256  Bus 66: Amsterdam Bijlmer ArenA => Amsterdam I...     bus       66
# 1257  Bus 68: Amsterdam Riekerpolder => Amsterdam He...     bus  267, 68
# 1258  Bus 68: Amsterdam Riekerpolder => Amsterdam He...     bus  267, 68
# 1259  Bus 68: Amsterdam Riekerpolder => Amsterdam He...     bus       68
# 1260  Bus 68: Amsterdam Riekerpolder => Amsterdam He...     bus       68
#
#      transfer       ref_1                   ref_2          ref_transfer_all
# 0      50, 54         NaN              50, 54, 47              {47, 50, 54}
# 1      50, 54         NaN              50, 54, 47              {47, 50, 54}
# 2      50, 54         NaN                     NaN                  {50, 54}
# 3      50, 54         NaN                     NaN                  {50, 54}
# 4      50, 54         NaN  50, 54, 44, 47, 49, 66  {54, 44, 50, 47, 66, 49}
# ...       ...         ...                     ...                       ...
# 1256     None         NaN                  66, 26                  {66, 26}
# 1257  267, 68         NaN                     NaN                 {267, 68}
# 1258  267, 68         NaN                     NaN                 {267, 68}
# 1259     None         NaN                     NaN                      {68}
# 1260     None  68, 50, 51                     NaN              {51, 50, 68}
#
# [1261 rows x 14 columns]
