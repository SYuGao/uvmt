# %% [markdown]
# # Amsterdam subway

# %%
from generate import *

# %%
osm_path = "C:\\projects\\UTNCE\\data\\Amsterdam.large.pbf"

# %%
city_sub_stations, edges, nodes, city_sub_routes, check_name = prepare_metro(osm_path)
# Out:
# endpoints: 100%|██████████████████████████████████████████████████████████████████| 711/711 [00:00<00:00, 59231.93it/s]
# endpoints: 100%|██████████████████████████████████████████████████████████████████| 962/962 [00:00<00:00, 73961.95it/s]
# topology: 100%|████████████████████████████████████████████████████████████████████| 962/962 [00:00<00:00, 9071.13it/s]
# WARNING: skipped OSM feature

# %%
replacement_dict = {
     'Amsterdam Centraal': 'Centraal Station',
}

city_sub_routes, check_name = recheck_metro_routes(replacement_dict, city_sub_stations, city_sub_routes)

# %%
city_sub_shortest_path_pairs, city_sub_shortest_path_edges, city_sub_edges = metro(city_sub_stations, edges, nodes, city_sub_routes, city='Amsterdam')

# %% [markdown]
# # Rotterdam subway

# %%
from generate import *

# %%
osm_path = "C:\\projects\\UTNCE\\data\\rotterdam.large.pbf"

# %%
city_sub_stations, edges, nodes, city_sub_routes, check_name = prepare_metro(osm_path)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 city_sub_stations, edges, nodes, city_sub_routes, check_name = prepare_metro(osm_path)
#
# File C:\projects\UTNCE\src\utnce\generate.py:15, in prepare_metro(osm_path)
#      13 def prepare_metro(osm_path):
# ---> 15     city_sub_stations = sub_stations(osm_path)
#      18     city_sub_network = subway_network(osm_path)
#      21     edges, nodes = prepare_network(city_sub_network, city_sub_stations)
#
# File C:\projects\UTNCE\src\utnce\prepare.py:238, in sub_stations(osm_path)
#     227 """
#     228 Retrieves subway stations from an OpenStreetMap file.
#     229
#    (...)
#     234     pandas.DataFrame: A DataFrame containing subway stations from the OSM file.
#     235 """
#     237 # retrieve all public transportation stations from the OSM file and assigns the result to df_railway_stations
# --> 238 df_railway_stations = public_stations(osm_path)
#     240 # create sub_stations1 by filtering df_railway_stations to include only rows where the 'subway' column is 'yes'
#     241 sub_stations1 = df_railway_stations.loc[df_railway_stations.subway == 'yes']
#
# File C:\projects\UTNCE\src\utnce\prepare.py:224, in public_stations(osm_path)
#     214 def public_stations(osm_path):
#     215     """
#     216     Retrieves public transportation stations from an OpenStreetMap file.
#     217
#    (...)
#     222         list: A list of public transportation stations from the OSM file.
#     223     """
# --> 224     return retrieve(osm_path, 'points', ['public_transport', 'railway', 'tram', 'subway', 'highway', 'bus', 'name'])
#
# File C:\projects\UTNCE\src\utnce\prepare.py:88, in retrieve(osm_path, geoType, keyCol, **valConstraint)
#      86 data = driver.Open(osm_path)
#      87 query = query_b(geoType,keyCol,**valConstraint)
# ---> 88 sql_lyr = data.ExecuteSQL(query)
#      89 features =[]
#      90 # cl = columns
#
# AttributeError: 'NoneType' object has no attribute 'ExecuteSQL'

# %%
replacement_dict = {
     
}

city_sub_routes, check_name = recheck_metro_routes(replacement_dict, city_sub_stations, city_sub_routes)

# %%
city_sub_shortest_path_pairs, city_sub_shortest_path_edges, city_sub_edges = metro(city_sub_stations, edges, nodes, city_sub_routes, city='Rotterdam')

# %% [markdown]
# # Amsterdam Tram

# %%
from generate import *

# %%
osm_path = "C:\\projects\\UTNCE\\data\\Amsterdam.large.pbf"

# %%
city_tram_stations, edges, nodes, city_tram_routes = prepare_tram(osm_path)

# %%
city_tram_routes

# %%
city_tram_routes = city_tram_routes.loc[city_tram_routes.ref != 'EMA']

# %%
city_tram_routes, check_name = check_tram_routes(city_tram_stations, city_tram_routes)

# %%
replacement_dict = {
    ',': '',
    'Diemen': '',
    'Amsterdam': '',
    'Sloterdijk': 'Station Sloterdijk',
    'Osdorp Dijkgraafsplein': 'Dijkgraafplein',
    'Osdorp De Aker': 'Matterhorn'
}

city_tram_stations, city_tram_routes, check_name = recheck_tram_routes(replacement_dict, city_tram_stations, city_tram_routes)

# %%
replacement_dict = {
    'Amstelveen Westwijk': 'Westwijk'
}

city_tram_stations, city_tram_routes, check_name = recheck_tram_routes(replacement_dict, city_tram_stations, city_tram_routes)

# %%
city_tram_shortest_path_pairs, city_tram_shortest_path_edges, city_tram_edges = tram(city_tram_stations, edges, nodes, city_tram_routes, city='Amsterdam')

# %% [markdown]
# # Rotterdam Tram

# %%
from generate import *

# %%
osm_path = "C:\\projects\\UTNCE\\data\\rotterdam.tram.pbf"

# %%
city_tram_stations, edges, nodes, city_tram_routes = prepare_tram(osm_path)

# %%
city_tram_routes

# %%
city_tram_routes = city_tram_routes.loc[city_tram_routes.network == 'Rail Rotterdam']

# %%
city_tram_routes, check_name = check_tram_routes(city_tram_stations, city_tram_routes)

# %%
replacement_dict = {
    'Scheveningen, ': '',
    'Delft, ': '',
    'Den Haag, ': '',
    'Rotterdam, ': '',
    'Schiedam, ': '',
    'Nootdorp,': '',
    'Wateringen,': '',
    'Leidschendam,': '',
    'Vlaardingen, ': '',
    'Zoetermeer, ': '',
    'Barendrecht, ': '',
    'Beverwaard': 'P+R Beverwaard',
    'Molenlaan': 'Burg. Van Kempensingel',
    'Spangen': 'Spartastraat',
    'Lombardijen': 'Kreekhuizenlaan',
    'Woudestein': 'Burgemeester Oudlaan'  
    
}

city_tram_stations, city_tram_routes, check_name = recheck_tram_routes(replacement_dict, city_tram_stations, city_tram_routes)

# %%
city_tram_shortest_path_pairs, city_tram_shortest_path_edges, city_tram_edges = tram(city_tram_stations, edges, nodes, city_tram_routes, city='Rotterdam')

# %% [markdown]
# # Amsterdam Bus

# %%
from generate import *

# %%
osm_path = "C:\\projects\\UTNCE\\data\\Amsterdam.large.pbf"

# %%
city_bus_stations, edges, nodes, city_bus_routes = prepare_bus(osm_path)

# %%
city_bus_routes

# %%
city_bus_routes = city_bus_routes.loc[city_bus_routes.network == 'Stadsvervoer Amsterdam']
city_bus_routes = city_bus_routes.loc[city_bus_routes.service != 'night']

# %%
city_bus_routes, check_name = check_bus_routes(city_bus_stations, city_bus_routes)

# %%
replacement_dict = {
    'Amsterdam, ': '',
    'Amsterdam': '',
    'Weesp Station': 'Station',
    'Osdorp De Aker': 'Matterhorn',
    'Schiphol, Airport/Plaza': 'Schiphol, Airport',
    'De Boelelaan': 'De Boelelaan/De Klencke'
}
replacement_dict1 = {
    'Amsterdam, ': '',
    'Amsterdam': '',
}

city_bus_stations['name'] = city_bus_stations['name'].replace(replacement_dict1, regex=True).str.strip()

city_bus_stations, city_bus_routes, check_name = recheck_bus_routes(replacement_dict, city_bus_stations, city_bus_routes)

# %%
city_bus_shortest_path_pairs, city_bus_shortest_path_edges, city_bus_edges = bus(city_bus_stations, edges, nodes, city_bus_routes, city='Amsterdam')

# %% [markdown]
# # Rotterdam Bus

# %%
from generate import *

# %%
osm_path = "C:\\projects\\UTNCE\\data\\rotterdam.bus.largest.pbf"

# %%
city_bus_stations, edges, nodes, city_bus_routes = prepare_bus(osm_path)
# Out:
# endpoints: 100%|████████████████████████████████████████████████████████████| 115870/115870 [00:01<00:00, 58176.38it/s]
# endpoints: 100%|████████████████████████████████████████████████████████████| 164083/164083 [00:02<00:00, 66747.77it/s]
# topology: 100%|██████████████████████████████████████████████████████████████| 164083/164083 [00:18<00:00, 8826.10it/s]

# %%
city_bus_stations.to_excel('./city_bus_stations.xlsx',header = True, index = False)

# %%
city_bus_routes
# Out:
#         osm_id route                                    to  \
# 11      106785   bus                   Sassenheim, Station
# 57      358053   bus                        Gouda, Station
# 58      358496   bus           Rotterdam, Capelsebrug Laag
# 59      358963   bus  Dordrecht, Cort van der Lindenstraat
# 60      358964   bus            Dordrecht, Laan van Europa
# ...        ...   ...                                   ...
# 5088  14429055   bus                     Rhoon, Overhoeken
# 5111  15096071   bus                  Rozenburg, Volgerweg
# 5112  15096072   bus            Spijkenisse, Metro Centrum
# 5159  15797230   bus               Rotterdam, Slinge Metro
# 5160  15797231   bus           Rotterdam, Antony Fokkerweg
#
#                                                    name  ref  \
# 11     Bus 385: Den Haag Centraal => Sassenheim Station  385
# 57    Bus 106: Nieuwegein Stadscentrum => Gouda Station  106
# 58    Bus 295: Utrecht CS Jaarbeurszijde => Rotterda...  295
# 59    Bus 3: Dordrecht Stadspolders => Dordrecht Cra...    3
# 60    Bus 4: Dordrecht Staart-Oost => Dordrecht Amst...    4
# ...                                                 ...  ...
# 5088      Bus 612: Poortugaal Metro => Rhoon Overhoeken  612
# 5111  Bus 115: Spijkenisse Metro Centrum => Rozenbur...  115
# 5112  Bus 115: Rozenburg Volgerweg => Spijkenisse Me...  115
# 5159  Bus 668: Rotterdam STC Campus => Rotterdam Slinge  668
# 5160  Bus 668: Rotterdam Slinge => Rotterdam STC Campus  668
#
#                                      network service  \
# 11                        Zuid-Holland Noord    None
# 57                         Provincie Utrecht    None
# 58                         Provincie Utrecht    None
# 59    Drechtsteden, Molenlanden en Gorinchem    None
# 60    Drechtsteden, Molenlanden en Gorinchem    None
# ...                                      ...     ...
# 5088                           Bus Rotterdam    None
# 5111              Voorne-Putten en Rozenburg    None
# 5112              Voorne-Putten en Rozenburg    None
# 5159                           Bus Rotterdam    None
# 5160                           Bus Rotterdam    None
#
#                                                geometry
# 11    MULTILINESTRING ((4.32448 52.08038, 4.32444 52...
# 57    MULTILINESTRING ((4.72564 52.00631, 4.72624 52...
# 58    MULTILINESTRING ((4.73278 51.93043, 4.73245 51...
# 59    MULTILINESTRING ((4.71697 51.80245, 4.71700 51...
# 60    MULTILINESTRING ((4.71990 51.81472, 4.72051 51...
# ...                                                 ...
# 5088  MULTILINESTRING ((4.39564 51.86132, 4.39552 51...
# 5111  MULTILINESTRING ((4.33413 51.84657, 4.33424 51...
# 5112  MULTILINESTRING ((4.23578 51.90397, 4.23652 51...
# 5159  MULTILINESTRING ((4.44926 51.87833, 4.45010 51...
# 5160  MULTILINESTRING ((4.47808 51.87463, 4.47797 51...
#
# [453 rows x 8 columns]

# %%
city_bus_routes = city_bus_routes.loc[city_bus_routes.network == 'Bus Rotterdam']
city_bus_routes = city_bus_routes.loc[city_bus_routes.ref != '668']
city_bus_routes = city_bus_routes.loc[city_bus_routes.service != 'night'].reset_index(drop=True)

# %%
city_bus_routes
# Out:
#        osm_id route                                      to  \
# 0      382710   bus            Rotterdam, Capelsebrug Metro
# 1      382748   bus                  Rotterdam, Capelsebrug
# 2      382750   bus  Krimpen aan den IJssel, Van Ostadelaan
# 3      382822   bus               Rotterdam, Zuidplein Hoog
# 4      383137   bus               Rotterdam, Zuidplein Hoog
# ..        ...   ...                                     ...
# 110  13647648   bus                Ridderkerk, Koningsplein
# 111  13649635   bus                Slikkerveer, Sporttunnel
# 112  13649636   bus               Rotterdam, Zuidplein Hoog
# 113  14429054   bus            Poortugaal, Poortugaal Metro
# 114  14429055   bus                       Rhoon, Overhoeken
#
#                                                   name  ref        network  \
# 0    Bus 96: Rotterdam Capelsebrug => Krimpen aan d...   96  Bus Rotterdam
# 1    Bus 97: Rotterdam Capelsebrug => Krimpen aan d...   97  Bus Rotterdam
# 2    Bus 98: Krimpen aan den IJssel Van Ostadelaan ...   98  Bus Rotterdam
# 3    Bus 143: Ridderkerk Drievliet => Rotterdam Zui...  143  Bus Rotterdam
# 4    Bus 144: Ridderkerk Drievliet => Rotterdam Zui...  144  Bus Rotterdam
# ..                                                 ...  ...            ...
# 110  Bus 610: Barendrecht Station NS => Ridderkerk ...  610  Bus Rotterdam
# 111  Bus 142: Rotterdam Zuidplein => Slikkerveer Sp...  142  Bus Rotterdam
# 112  Bus 142: Slikkerveer Sporttunnel => Rotterdam ...  142  Bus Rotterdam
# 113       Bus 612: Rhoon Overhoeken => Portugaal Metro  612  Bus Rotterdam
# 114      Bus 612: Poortugaal Metro => Rhoon Overhoeken  612  Bus Rotterdam
#
#     service                                           geometry
# 0      None  MULTILINESTRING ((4.55790 51.92115, 4.55759 51...
# 1      None  MULTILINESTRING ((4.55790 51.92115, 4.55759 51...
# 2      None  MULTILINESTRING ((4.59888 51.90822, 4.59900 51...
# 3      None  MULTILINESTRING ((4.62011 51.86624, 4.61995 51...
# 4      None  MULTILINESTRING ((4.62080 51.86582, 4.62086 51...
# ..      ...                                                ...
# 110    None  MULTILINESTRING ((4.55173 51.85475, 4.55172 51...
# 111    None  MULTILINESTRING ((4.48914 51.88767, 4.48900 51...
# 112    None  MULTILINESTRING ((4.59611 51.87701, 4.59635 51...
# 113    None  MULTILINESTRING ((4.43351 51.86012, 4.43343 51...
# 114    None  MULTILINESTRING ((4.39564 51.86132, 4.39552 51...
#
# [115 rows x 8 columns]

# %%
city_bus_routes, check_name = check_bus_routes(city_bus_stations, city_bus_routes)

# %%
replacement_dict = {
    'Slikkerveer, Sporttunnel': 'Ridderkerk, Sporttunnel', # Sporttunnel
    'Dordrecht, Station': 'Dordrecht, Centraal Station',
    'Lansingerland-Zoetermeer Zuidplein': 'Station Lansingerland-Zoetermeer Zuidplein',
    'Ridderkerk, Donkersloot': 'Ridderkerk, Groenendijk', # Groenendijk
        
    'Rotterdam, Caïrostraat': 'Rotterdam, Marconiplein',
    'Schiedam, Nieuwe Maasstraat': 'Schiedam, Station Schiedam Centrum',
    'Rotterdam, Meeuwenstaart': 'Rotterdam, Sleephellingstraat Zuid', # 'Rotterdam, Station Blaak'   'Station Blaak'
    'Barendrecht, Station NS': 'Barendrecht, Station Barendrecht',
    
    'Rotterdam, Damstraat': 'Damstraat',
    'Rotterdam, Metro Pernis': 'Pernis Rotterdam, Pernis Metro', # Pernis Metro
    'Rotterdam, SS Rotterdam': 'SS Rotterdam',
    'Barendrecht, Station': 'Barendrecht, Station Barendrecht',
    'Rotterdam, Capelsebrug': 'Rotterdam, Capelsebrug Hoog',
    'Rotterdam, Zuidplein': 'Rotterdam, Zuidplein Hoog'
    
    
}


city_bus_stations, city_bus_routes, check_name = recheck_bus_routes(replacement_dict, city_bus_stations, city_bus_routes)

# %%
replacement_dict = {

    'Barendrecht, Station Barendrecht Barendrecht': 'Barendrecht, Station Barendrecht',
    'Rotterdam, Capelsebrug Hoog Metro': 'Rotterdam, Capelsebrug Metro', 
    'Rotterdam, Zuidplein Hoog Hoog': 'Rotterdam, Zuidplein Hoog'
    
    
}
city_bus_stations, city_bus_routes, check_name = recheck_bus_routes(replacement_dict, city_bus_stations, city_bus_routes)

# %%
check_name.to_excel('./check_name.xlsx',header = True, index = False)

# %%
city_bus_routes.to_excel('./city_bus_routes.xlsx',header = True, index = False)

# %%
city_bus_start_station_name_dict = start_station_dict(city_bus_routes)

city_bus_line_dict = line_dict(city_bus_routes)

city_bus_all_stations_name = all_station_list(city_bus_stations)

# %%
city_bus_start_station_name_dict
# Out:
# {'Bus 126: Maassluis West => Schiedam Centrum': 'Schiedam, Station Schiedam Centrum',
#  'Bus 126: Schiedam Centrum => Maassluis West': 'Maassluis, Station Maassluis West',
#  'Bus 140: Rotterdam Kralingse Zoom => Slikkerveer Dillenburgplein': 'Slikkerveer, Dillenburgplein',
#  'Bus 140: Slikkerveer Dillenburgplein => Rotterdam Kralingse Zoom': 'Rotterdam, Kralingse Zoom',
#  'Bus 142: Slikkerveer Sporttunnel => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 142: Rotterdam Zuidplein => Slikkerveer Sporttunnel': 'Ridderkerk, Sporttunnel',
#  'Bus 142: Slikkerveer Dillenburgplein => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 142: Rotterdam Zuidplein => Slikkerveer Dillenburgplein': 'Slikkerveer, Dillenburgplein',
#  'Bus 143: Ridderkerk Drievliet => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 143: Rotterdam Zuidplein => Ridderkerk Drievliet': 'Ridderkerk, Sporthal Drievliet',
#  'Bus 144: Ridderkerk Drievliet => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 144: Rotterdam Zuidplein => Ridderkerk Drievliet': 'Ridderkerk, Sporthal Drievliet',
#  'Bus 145: Dordrecht Station => Rotterdam Kralingse Zoom': 'Rotterdam, Kralingse Zoom',
#  'Bus 145: Rotterdam Kralingse Zoom => Dordrecht Station': 'Dordrecht, Centraal Station',
#  'Bus 146: Rotterdam Zuidplein => Ridderkerk Drievliet': 'Ridderkerk, Sporthal Drievliet',
#  'Bus 146: Ridderkerk Drievliet => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 156: Vlaardingen West => Vlaardingen Holy Noord': 'Vlaardingen, Begraafplaats Holy',
#  'Bus 156: Vlaardingen Holy Noord => Vlaardingen West': 'Vlaardingen, Station Vlaardingen West',
#  'Bus 170: Zoetermeer Centrum West => Berkel en Rodenrijs Rodenrijs Metro': 'Berkel en Rodenrijs, Rodenrijs Metro',
#  'Bus 170: Berkel en Rodenrijs Rodenrijs Metro => Zoetermeer Centrum West': 'Zoetermeer, Centrum West',
#  'Bus 173: Lansingerland-Zoetermeer => Berkel en Rodenrijs Rodenrijs Metro': 'Berkel en Rodenrijs, Rodenrijs Metro',
#  'Bus 173: Berkel en Rodenrijs Rodenrijs Metro => Lansingerland-Zoetermeer': 'Station Lansingerland-Zoetermeer Zuidplein',
#  'Bus 174: Delft Station Delft => Rotterdam Station Noord': 'Rotterdam, Station Noord',
#  'Bus 174: Rotterdam Station Noord => Delft Station Delft': 'Delft, Station Delft',
#  'Bus 183: Rotterdam Zuidplein => Rotterdam Kralingse Zoom': 'Rotterdam, Kralingse Zoom',
#  'Bus 183: Rotterdam Kralingse Zoom => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 187: Rotterdam Zuidplein => Ridderkerk Nieuw-Reijerwaard': 'Ridderkerk, Peterselieweg',
#  'Bus 187: Ridderkerk Nieuw-Reijerwaard => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 283: Rotterdam Kralingse Zoom => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 283: Rotterdam Zuidplein => Rotterdam Kralingse Zoom': 'Rotterdam, Kralingse Zoom',
#  'Bus 290: Rotterdam Zuidplein => Ridderkerk Donkersloot': 'Ridderkerk, Groenendijk',
#  'Bus 290: Ridderkerk Donkersloot => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 30: Capelle Schollevaar => Rotterdam Station Alexander': 'Rotterdam, Station Alexander',
#  'Bus 30: Rotterdam Station Alexander => Capelle Schollevaar': 'Capelle aan den IJssel, Operalaan',
#  'Bus 31: Rotterdam Station Alexander => Capelle Oostgaarde': 'Capelle aan den IJssel, Sint Annabaai',
#  'Bus 31: Capelle Oostgaarde => Rotterdam Station Alexander': 'Rotterdam, Station Alexander',
#  'Bus 32: Rotterdam Station Zuid => Rotterdam Overschie': 'Rotterdam, Van Noortwijckstraat',
#  'Bus 32: Rotterdam Overschie => Rotterdam Station Zuid': 'Rotterdam, Station Zuid/Steenplaat',
#  'Bus 33: Rotterdam Centraal => Rotterdam Meijersplein': 'Rotterdam, Meijersplein Metro',
#  'Bus 33: Rotterdam Centraal => Rotterdam Overschie': 'Rotterdam, West-Sidelinge',
#  'Bus 33: Rotterdam Meijersplein => Rotterdam Centraal': 'Rotterdam, Rotterdam Centraal',
#  'Bus 33: Rotterdam Overschie => Rotterdam Centraal': 'Rotterdam, Rotterdam Centraal',
#  'Bus 35: Rotterdam Station Alexander => Rotterdam Melanchthonweg': 'Rotterdam, Melanchthonweg',
#  'Bus 35: Rotterdam Melanchthonweg => Rotterdam Station Alexander': 'Rotterdam, Station Alexander',
#  'Bus 36: Rotterdam Station Alexander => Rotterdam Kralingse Zoom': 'Rotterdam, Kralingse Zoom',
#  'Bus 36: Rotterdam Kralingse Zoom => Rotterdam Station Alexander': 'Rotterdam, Station Alexander',
#  'Bus 38: Schiedam Centrum => Rotterdam Crooswijk': 'Rotterdam, Kerkhoflaan',
#  'Bus 38: Rotterdam Crooswijk => Schiedam Centrum': 'Schiedam, Station Schiedam Centrum',
#  'Bus 40: Delft Station Delft => Rotterdam Centraal': 'Rotterdam, Rotterdam Centraal',
#  'Bus 40: Rotterdam Centraal => Delft Station Delft': 'Delft, Station Delft',
#  'Bus 42: Rotterdam Marconiplein => Rotterdam Bedrijvenpark Noord-West': 'Rotterdam, Marconiplein',
#  'Bus 42: Rotterdam Bedrijvenpark Noord-West => Rotterdam Marconiplein': 'Rotterdam, Marconiplein',
#  'Bus 44: Rotterdam Zuidplein => Rotterdam Centraal': 'Rotterdam, Rotterdam Centraal',
#  'Bus 44: Rotterdam Centraal => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 51: Schiedam Woudhoek => Schiedam Centrum': 'Schiedam, Station Schiedam Centrum',
#  'Bus 51: Schiedam Centrum => Schiedam Woudhoek': 'Schiedam, Harreweg',
#  'Bus 53: Schiedam Woudhoek => Schiedam Centrum': 'Schiedam, Station Schiedam Centrum',
#  'Bus 53: Schiedam Centrum => Schiedam Woudhoek': 'Schiedam, Harreweg',
#  'Bus 54: Schiedam Centrum => Schiedam De Gorzen': 'Schiedam, Station Schiedam Centrum',
#  'Bus 54: Schiedam De Gorzen => Schiedam Centrum': 'Schiedam, Station Schiedam Centrum',
#  'Bus 547: Rotterdam Noordereiland => Rotterdam Noordereiland': 'Rotterdam, Sleephellingstraat Zuid',
#  'Bus 56: Vlaardingen West => Vlaardingen Holy Noord': 'Vlaardingen, Begraafplaats Holy',
#  'Bus 56: Vlaardingen Holy Noord => Vlaardingen West': 'Vlaardingen, Station Vlaardingen West',
#  'Bus 567: Rotterdam Slinge => Rotterdam Slinge': 'Rotterdam, Slinge Metro',
#  'Bus 602: Poortugaal Metro => Rhoon Portland': 'Rhoon, Kwartslaan',
#  'Bus 602: Rhoon Portland => Poortugaal Metro': 'Poortugaal, Poortugaal Metro',
#  'Bus 603: Barendrecht Carnisselande => Barendrecht Station': 'Barendrecht, Station Barendrecht',
#  'Bus 603: Barendrecht Station => Barendrecht Carnisselande': 'Barendrecht, Vrijheidsakker',
#  'Bus 605: Capelle Centrum => Capelle Centrum': 'Capelle aan den IJssel, Capelle Centrum',
#  'Bus 606: Capelle Centrum => Capelle Centrum': 'Capelle aan den IJssel, Capelle Centrum',
#  'Bus 607: Capelle Centrum => Rotterdam Capelsebrug': 'Rotterdam, Capelsebrug Metro',
#  'Bus 607: Rotterdam Capelsebrug => Capelle Centrum': 'Capelle aan den IJssel, Capelle Centrum',
#  'Bus 608: Ridderkerk Olmenlaan => Barendrecht Station NS': 'Barendrecht, Station Barendrecht',
#  'Bus 608: Barendrecht Station NS => Ridderkerk Olmenlaan': 'Ridderkerk, Olmenlaan',
#  'Bus 609: Barendrecht Station => Slikkerveer De Schans': 'Slikkerveer, De Schans',
#  'Bus 609: Slikkerveer De Schans => Barendrecht Station': 'Barendrecht, Station Barendrecht',
#  'Bus 61: Hoogvliet Metro => Hoogvliet Metro': 'Hoogvliet Rotterdam, Hoogvliet Metro',
#  'Bus 610: Barendrecht Station NS => Ridderkerk Koningsplein': 'Ridderkerk, Koningsplein',
#  'Bus 610: Ridderkerk Koningsplein => Barendrecht Station NS': 'Barendrecht, Station Barendrecht',
#  'Bus 612: Poortugaal Metro => Rhoon Overhoeken': 'Rhoon, Overhoeken',
#  'Bus 612: Rhoon Overhoeken => Portugaal Metro': 'Poortugaal, Poortugaal Metro',
#  'Bus 62: Hoogvliet Metro => Hoogvliet Metro': 'Hoogvliet Rotterdam, Hoogvliet Metro',
#  'Bus 63: Hoogvliet Metro => Hoogvliet Metro': 'Hoogvliet Rotterdam, Hoogvliet Metro',
#  'Bus 65: Poortugaal Metro => Poortugaal Metro': 'Poortugaal, Poortugaal Metro',
#  'Bus 66: Rotterdam Zuidplein => Rotterdam Feijenoord': 'Damstraat',
#  'Bus 66: Rotterdam Feijenoord => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 67: Rotterdam Zuidplein => Rotterdam Pendrecht': 'Rotterdam, Nieuw-Vossemeerweg',
#  'Bus 67: Rotterdam Pendrecht => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 68: Rotterdam Zuidplein => Rotterdam Heijplaat': 'Rotterdam, RDM Campus',
#  'Bus 68: Rotterdam Heijplaat => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 69: Rotterdam Zuidplein => Rotterdam Metro Pernis': 'Pernis Rotterdam, Pernis Metro',
#  'Bus 69: Rotterdam Metro Pernis => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 70: Rotterdam Charlois => Rotterdam Keizerswaard': 'Rotterdam, Keizerswaard',
#  'Bus 70: Rotterdam Keizerswaard => Rotterdam Charlois': 'Rotterdam, Garage Sluisjesdijk',
#  'Bus 72: Rotterdam Sluisjesdijk => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 72: Rotterdam Zuidplein => Rotterdam Sluisjesdijk': 'Rotterdam, Willem Egmondstraat',
#  'Bus 75: Rotterdam Kralingse Zoom => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 75: Rotterdam Zuidplein => Rotterdam Kralingse Zoom': 'Rotterdam, Kralingse Zoom',
#  'Bus 76: Rotterdam Keizerswaard => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 76: Rotterdam Zuidplein => Rotterdam Keizerswaard': 'Rotterdam, Keizerswaard',
#  'Bus 77: Rotterdam Zuidplein => Rotterdam Katendrecht': 'SS Rotterdam',
#  'Bus 77: Rotterdam Katendrecht => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 79: Poortugaal Metro => Poortugaal Psychiatrisch Centrum': 'Poortugaal, De Kijvelanden',
#  'Bus 79: Poortugaal Psychiatrisch Centrum => Poortugaal Metro': 'Poortugaal Metro',
#  'Bus 82: Rotterdam Zuidplein => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 83: Rotterdam Kralingse Zoom => Rotterdam Keizerswaard': 'Rotterdam, Keizerswaard',
#  'Bus 83: Rotterdam Keizerswaard => Rotterdam Kralingse Zoom': 'Rotterdam, Kralingse Zoom',
#  'Bus 84: Rotterdam Zuidplein => Barendrecht Station': 'Barendrecht, Station Barendrecht',
#  'Bus 84: Barendrecht Station => Rotterdam Zuidplein': 'Rotterdam, Zuidplein Hoog',
#  'Bus 96: Rotterdam Capelsebrug => Krimpen aan den IJssel Stormpolder => Rotterdam Capelsebrug': 'Rotterdam, Capelsebrug Metro',
#  'Bus 97: Rotterdam Capelsebrug => Krimpen aan den IJssel => Rotterdam Capelsebrug': 'Rotterdam, Capelsebrug Hoog',
#  'Bus 98: Krimpen aan den IJssel Van Ostadelaan => Krimpen aan den IJssel => Krimpen aan den IJssel Van Ostadelaan': 'Krimpen aan den IJssel, Van Ostadelaan'}

# %%
city_bus_all_stations_name.to_excel('./city_bus_all_stations_name.xlsx',header = True, index = False)

# %%
len(city_bus_all_stations_name)
# Out:
# 7718

# %%
len(city_bus_routes)
# Out:
# 115

# %%
len(city_bus_line_dict)
# Out:
# 112

# %%
len(city_bus_start_station_name_dict)
# Out:
# 112

# %%
def order_stations_inline(tram_line_dict, all_tram_stations_name, tram_routes, tram_start_station_name_dict):
    """
    Orders the tram stations based on the tram line routes and start station names.

    Args:
        tram_line_dict (dict): A dictionary containing tram line information.
        all_tram_stations_name (DataFrame): A DataFrame containing all tram station names.
        tram_routes (DataFrame): A DataFrame containing tram route information.
        tram_start_station_name_dict (dict): A dictionary mapping tram line names to their respective start station names.

    Returns:
        dict: A dictionary containing ordered tram station routes for each tram line.
    """
    
    # Create a copy of the tram_line_dict dictionary
    tram_stations_dict = tram_line_dict.copy()

    # Iterate over each key-value pair in tram_stations_dict
    for key, value in tram_stations_dict.items():
        value1 = value
        # Filter the all_tram_stations_name DataFrame to include only stations within the buffer of the corresponding tram route
        value2 = all_tram_stations_name.loc[all_tram_stations_name.within(tram_routes.iloc[value1].geometry.buffer(0.000068))]
        # Assign new IDs to the filtered stations
        value2['id'] = value2.reset_index().index
        # Update the value in tram_stations_dict to include only necessary columns and reset the index
        tram_stations_dict[key] = value2[['id', 'name', 'geometry', 'geo_x', 'geo_y']].reset_index(drop=True)

    # Create copies of tram_line_dict for storing tram stations in order and ordered routes
    tram_stations_inorder_dict = tram_line_dict.copy()
    tram_order_route_dict = tram_line_dict.copy()

    # Iterate over each line in tram_stations_inorder_dict
    for line in tram_stations_inorder_dict.keys():
        tram_stations_inorder = tram_stations_dict[line]
        # Find the start station for the current line and update tram_stations_inorder_dict with only that station
        for i in range(len(tram_stations_inorder)):
            if tram_stations_inorder.iloc[i]['name'] == tram_start_station_name_dict[line]:
                tram_stations_inorder_dict[line] = pd.DataFrame(tram_stations_inorder.iloc[i]).T
                print(tram_stations_inorder_dict[line])
        # Call the order_route function to order the remaining stations and store the result in tram_order_route_dict
        tram_order_route_dict[line] = order_route(tram_stations_inorder_dict[line], tram_stations_dict[line])

    return tram_order_route_dict

# %%
city_bus_stations_inline = order_stations_inline(city_bus_line_dict, city_bus_all_stations_name, city_bus_routes, city_bus_start_station_name_dict)
# Out:
#     id                                name                    geometry  \
# 49  49  Schiedam, Station Schiedam Centrum  POINT (4.40766 51.9216446)
#
#       geo_x      geo_y
# 49  4.40766  51.921645
#     id                               name                      geometry  \
# 49  49  Maassluis, Station Maassluis West  POINT (4.2362522 51.9260742)
#
#        geo_x      geo_y
# 49  4.236252  51.926074
#     id                               name                     geometry  \
# 53  53  Maassluis, Station Maassluis West  POINT (4.236197 51.9261117)
#
#        geo_x      geo_y
# 53  4.236197  51.926112
#     id                          name                      geometry     geo_x  \
# 35  35  Slikkerveer, Dillenburgplein  POINT (4.6039447 51.8855064)  4.603945
#
#         geo_y
# 35  51.885506
#     id                          name                      geometry     geo_x  \
# 36  36  Slikkerveer, Dillenburgplein  POINT (4.6046059 51.8851123)  4.604606
#
#         geo_y
# 36  51.885112
#     id                       name                      geometry     geo_x  \
# 28  28  Rotterdam, Kralingse Zoom  POINT (4.5327285 51.9217497)  4.532729
#
#        geo_y
# 28  51.92175
#     id                       name                     geometry     geo_x  \
# 14  14  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 14  51.887005
#     id                     name                      geometry     geo_x  \
# 29  29  Ridderkerk, Sporttunnel  POINT (4.5961121 51.8770125)  4.596112
#
#         geo_y
# 29  51.877012
#     id                     name                      geometry     geo_x  \
# 30  30  Ridderkerk, Sporttunnel  POINT (4.5957716 51.8768809)  4.595772
#
#         geo_y
# 30  51.876881
#     id                       name                     geometry     geo_x  \
# 12  12  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 12  51.887005
#     id                          name                      geometry     geo_x  \
# 38  38  Slikkerveer, Dillenburgplein  POINT (4.6039447 51.8855064)  4.603945
#
#         geo_y
# 38  51.885506
#     id                          name                      geometry     geo_x  \
# 39  39  Slikkerveer, Dillenburgplein  POINT (4.6046059 51.8851123)  4.604606
#
#         geo_y
# 39  51.885112
#     id                       name                     geometry     geo_x  \
# 18  18  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 18  51.887005
#     id                            name                      geometry  \
# 33  33  Ridderkerk, Sporthal Drievliet  POINT (4.6194177 51.8662374)
#
#        geo_x      geo_y
# 33  4.619418  51.866237
#     id                       name                     geometry     geo_x  \
# 25  25  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 25  51.887005
#     id                            name                      geometry  \
# 47  47  Ridderkerk, Sporthal Drievliet  POINT (4.6206793 51.8657129)
#
#        geo_x      geo_y
# 47  4.620679  51.865713
#     id                            name                      geometry   geo_x  \
# 48  48  Ridderkerk, Sporthal Drievliet  POINT (4.6207999 51.8658198)  4.6208
#
#        geo_y
# 48  51.86582
#     id                       name                      geometry     geo_x  \
# 48  48  Rotterdam, Kralingse Zoom  POINT (4.5327285 51.9217497)  4.532729
#
#        geo_y
# 48  51.92175
#     id                         name                      geometry     geo_x  \
# 22  22  Dordrecht, Centraal Station  POINT (4.6702424 51.8073603)  4.670242
#
#        geo_y
# 22  51.80736
#     id                         name                     geometry     geo_x  \
# 38  38  Dordrecht, Centraal Station  POINT (4.6708524 51.807476)  4.670852
#
#         geo_y
# 38  51.807476
#     id                         name                      geometry     geo_x  \
# 45  45  Dordrecht, Centraal Station  POINT (4.6700628 51.8075614)  4.670063
#
#         geo_y
# 45  51.807561
#     id                            name                      geometry  \
# 27  27  Ridderkerk, Sporthal Drievliet  POINT (4.6206793 51.8657129)
#
#        geo_x      geo_y
# 27  4.620679  51.865713
#     id                       name                     geometry     geo_x  \
# 18  18  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 18  51.887005
#     id                             name                      geometry  \
# 50  50  Vlaardingen, Begraafplaats Holy  POINT (4.3359951 51.9378332)
#
#        geo_x      geo_y
# 50  4.335995  51.937833
#     id                                   name                      geometry  \
# 49  49  Vlaardingen, Station Vlaardingen West  POINT (4.3149703 51.9044683)
#
#       geo_x      geo_y
# 49  4.31497  51.904468
#     id                                  name                      geometry  \
# 45  45  Berkel en Rodenrijs, Rodenrijs Metro  POINT (4.4618319 51.9756331)
#
#        geo_x      geo_y
# 45  4.461832  51.975633
#     id                                  name                      geometry  \
# 53  53  Berkel en Rodenrijs, Rodenrijs Metro  POINT (4.4615248 51.9754898)
#
#        geo_x     geo_y
# 53  4.461525  51.97549
#     id                      name                      geometry     geo_x  \
# 52  52  Zoetermeer, Centrum West  POINT (4.4823572 52.0611837)  4.482357
#
#         geo_y
# 52  52.061184
#     id                                  name                      geometry  \
# 39  39  Berkel en Rodenrijs, Rodenrijs Metro  POINT (4.4618319 51.9756331)
#
#        geo_x      geo_y
# 39  4.461832  51.975633
#     id                                  name                      geometry  \
# 56  56  Berkel en Rodenrijs, Rodenrijs Metro  POINT (4.4615248 51.9754898)
#
#        geo_x     geo_y
# 56  4.461525  51.97549
#     id                                        name  \
# 23  23  Station Lansingerland-Zoetermeer Zuidplein
#
#                         geometry    geo_x      geo_y
# 23  POINT (4.5172603 52.0402228)  4.51726  52.040223
#     id                                        name  \
# 57  57  Station Lansingerland-Zoetermeer Zuidplein
#
#                         geometry     geo_x      geo_y
# 57  POINT (4.5171986 52.0402415)  4.517199  52.040242
#     id                                        name  \
# 58  58  Station Lansingerland-Zoetermeer Zuidplein
#
#                        geometry     geo_x      geo_y
# 58  POINT (4.517732 52.0401911)  4.517732  52.040191
#     id                                        name  \
# 59  59  Station Lansingerland-Zoetermeer Zuidplein
#
#                         geometry     geo_x      geo_y
# 59  POINT (4.5173893 52.0403909)  4.517389  52.040391
#     id                      name                     geometry     geo_x  \
# 59  59  Rotterdam, Station Noord  POINT (4.4813935 51.941748)  4.481394
#
#         geo_y
# 59  51.941748
#       id                      name                      geometry     geo_x  \
# 109  109  Rotterdam, Station Noord  POINT (4.4814383 51.9428843)  4.481438
#
#          geo_y
# 109  51.942884
#       id                      name                     geometry     geo_x  \
# 110  110  Rotterdam, Station Noord  POINT (4.481086 51.9425485)  4.481086
#
#          geo_y
# 110  51.942549
#     id                  name                      geometry     geo_x  \
# 84  84  Delft, Station Delft  POINT (4.3568162 52.0067921)  4.356816
#
#         geo_y
# 84  52.006792
#     id                       name                      geometry     geo_x  \
# 86  86  Rotterdam, Kralingse Zoom  POINT (4.5327285 51.9217497)  4.532729
#
#        geo_y
# 86  51.92175
#     id                       name                     geometry     geo_x  \
# 39  39  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 39  51.887005
#     id                       name                    geometry    geo_x  \
# 28  28  Ridderkerk, Peterselieweg  POINT (4.56844 51.8649709)  4.56844
#
#         geo_y
# 28  51.864971
#     id                       name                     geometry     geo_x  \
# 29  29  Ridderkerk, Peterselieweg  POINT (4.5686379 51.865086)  4.568638
#
#         geo_y
# 29  51.865086
#     id                       name                     geometry     geo_x  \
# 17  17  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 17  51.887005
#     id                       name                     geometry     geo_x  \
# 45  45  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 45  51.887005
#     id                       name                      geometry     geo_x  \
# 92  92  Rotterdam, Kralingse Zoom  POINT (4.5327285 51.9217497)  4.532729
#
#        geo_y
# 92  51.92175
#     id                     name                      geometry     geo_x  \
# 28  28  Ridderkerk, Groenendijk  POINT (4.6130186 51.8726872)  4.613019
#
#         geo_y
# 28  51.872687
#     id                     name                    geometry    geo_x     geo_y
# 29  29  Ridderkerk, Groenendijk  POINT (4.61234 51.8726798)  4.61234  51.87268
#     id                       name                     geometry     geo_x  \
# 12  12  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 12  51.887005
#     id                          name                      geometry     geo_x  \
# 16  16  Rotterdam, Station Alexander  POINT (4.5522106 51.9521068)  4.552211
#
#         geo_y
# 16  51.952107
#     id                               name                     geometry  \
# 14  14  Capelle aan den IJssel, Operalaan  POINT (4.5877891 51.950952)
#
#        geo_x      geo_y
# 14  4.587789  51.950952
#     id                               name                      geometry  \
# 21  21  Capelle aan den IJssel, Operalaan  POINT (4.5879362 51.9513509)
#
#        geo_x      geo_y
# 21  4.587936  51.951351
#     id                                   name                      geometry  \
# 38  38  Capelle aan den IJssel, Sint Annabaai  POINT (4.6082201 51.9301868)
#
#       geo_x      geo_y
# 38  4.60822  51.930187
#     id                          name                      geometry     geo_x  \
# 18  18  Rotterdam, Station Alexander  POINT (4.5522106 51.9521068)  4.552211
#
#         geo_y
# 18  51.952107
#     id                             name                      geometry  \
# 47  47  Rotterdam, Van Noortwijckstraat  POINT (4.4254798 51.9346127)
#
#       geo_x      geo_y
# 47  4.42548  51.934613
#     id                                name                     geometry  \
# 39  39  Rotterdam, Station Zuid/Steenplaat  POINT (4.5126255 51.903532)
#
#        geo_x      geo_y
# 39  4.512626  51.903532
#     id                           name                      geometry     geo_x  \
# 24  24  Rotterdam, Meijersplein Metro  POINT (4.4618241 51.9558838)  4.461824
#
#         geo_y
# 24  51.955884
#     id                       name                    geometry     geo_x  \
# 21  21  Rotterdam, West-Sidelinge  POINT (4.4260777 51.94136)  4.426078
#
#        geo_y
# 21  51.94136
#     id                       name                      geometry     geo_x  \
# 30  30  Rotterdam, West-Sidelinge  POINT (4.4259391 51.9413077)  4.425939
#
#         geo_y
# 30  51.941308
#     id                           name                      geometry     geo_x  \
# 21  21  Rotterdam, Rotterdam Centraal  POINT (4.4668877 51.9236997)  4.466888
#
#       geo_y
# 21  51.9237
#     id                           name                      geometry     geo_x  \
# 22  22  Rotterdam, Rotterdam Centraal  POINT (4.4672355 51.9237505)  4.467236
#
#        geo_y
# 22  51.92375
#     id                           name                      geometry     geo_x  \
# 23  23  Rotterdam, Rotterdam Centraal  POINT (4.4683738 51.9239825)  4.468374
#
#         geo_y
# 23  51.923983
#     id                           name                      geometry     geo_x  \
# 24  24  Rotterdam, Rotterdam Centraal  POINT (4.4677818 51.9238613)  4.467782
#
#         geo_y
# 24  51.923861
#     id                           name                      geometry     geo_x  \
# 11  11  Rotterdam, Rotterdam Centraal  POINT (4.4668877 51.9236997)  4.466888
#
#       geo_y
# 11  51.9237
#     id                           name                      geometry     geo_x  \
# 12  12  Rotterdam, Rotterdam Centraal  POINT (4.4672355 51.9237505)  4.467236
#
#        geo_y
# 12  51.92375
#     id                           name                      geometry     geo_x  \
# 13  13  Rotterdam, Rotterdam Centraal  POINT (4.4683738 51.9239825)  4.468374
#
#         geo_y
# 13  51.923983
#     id                           name                      geometry     geo_x  \
# 14  14  Rotterdam, Rotterdam Centraal  POINT (4.4677818 51.9238613)  4.467782
#
#         geo_y
# 14  51.923861
#     id                       name                     geometry     geo_x  \
# 22  22  Rotterdam, Melanchthonweg  POINT (4.465322 51.9486231)  4.465322
#
#         geo_y
# 22  51.948623
#     id                          name                    geometry     geo_x  \
# 38  38  Rotterdam, Station Alexander  POINT (4.551148 51.952015)  4.551148
#
#         geo_y
# 38  51.952015
#     id                       name                      geometry     geo_x  \
# 19  19  Rotterdam, Kralingse Zoom  POINT (4.5327285 51.9217497)  4.532729
#
#        geo_y
# 19  51.92175
#     id                          name                      geometry     geo_x  \
# 20  20  Rotterdam, Station Alexander  POINT (4.5522106 51.9521068)  4.552211
#
#         geo_y
# 20  51.952107
#     id                    name                      geometry    geo_x  \
# 62  62  Rotterdam, Kerkhoflaan  POINT (4.4924397 51.9374524)  4.49244
#
#         geo_y
# 62  51.937452
#     id                                name                      geometry  \
# 45  45  Schiedam, Station Schiedam Centrum  POINT (4.4096667 51.9212407)
#
#        geo_x      geo_y
# 45  4.409667  51.921241
#     id                                name                      geometry  \
# 47  47  Schiedam, Station Schiedam Centrum  POINT (4.4090742 51.9213762)
#
#        geo_x      geo_y
# 47  4.409074  51.921376
#     id                           name                      geometry     geo_x  \
# 58  58  Rotterdam, Rotterdam Centraal  POINT (4.4668877 51.9236997)  4.466888
#
#       geo_y
# 58  51.9237
#     id                           name                      geometry     geo_x  \
# 59  59  Rotterdam, Rotterdam Centraal  POINT (4.4672355 51.9237505)  4.467236
#
#        geo_y
# 59  51.92375
#     id                           name                      geometry     geo_x  \
# 62  62  Rotterdam, Rotterdam Centraal  POINT (4.4684164 51.9237139)  4.468416
#
#         geo_y
# 62  51.923714
#     id                           name                      geometry     geo_x  \
# 63  63  Rotterdam, Rotterdam Centraal  POINT (4.4683738 51.9239825)  4.468374
#
#         geo_y
# 63  51.923983
#     id                           name                      geometry     geo_x  \
# 64  64  Rotterdam, Rotterdam Centraal  POINT (4.4677818 51.9238613)  4.467782
#
#         geo_y
# 64  51.923861
#     id                  name                      geometry     geo_x  \
# 63  63  Delft, Station Delft  POINT (4.3568162 52.0067921)  4.356816
#
#         geo_y
# 63  52.006792
#   id                     name                      geometry     geo_x  \
# 8  8  Rotterdam, Marconiplein  POINT (4.4316822 51.9136058)  4.431682
#
#        geo_y
# 8  51.913606
#   id                     name                      geometry     geo_x  \
# 5  5  Rotterdam, Marconiplein  POINT (4.4316822 51.9136058)  4.431682
#
#        geo_y
# 5  51.913606
#     id                           name                      geometry     geo_x  \
# 23  23  Rotterdam, Rotterdam Centraal  POINT (4.4668877 51.9236997)  4.466888
#
#       geo_y
# 23  51.9237
#     id                           name                      geometry     geo_x  \
# 24  24  Rotterdam, Rotterdam Centraal  POINT (4.4672355 51.9237505)  4.467236
#
#        geo_y
# 24  51.92375
#     id                           name                      geometry     geo_x  \
# 25  25  Rotterdam, Rotterdam Centraal  POINT (4.4684164 51.9237139)  4.468416
#
#         geo_y
# 25  51.923714
#     id                           name                      geometry     geo_x  \
# 26  26  Rotterdam, Rotterdam Centraal  POINT (4.4683738 51.9239825)  4.468374
#
#         geo_y
# 26  51.923983
#     id                           name                      geometry     geo_x  \
# 27  27  Rotterdam, Rotterdam Centraal  POINT (4.4677818 51.9238613)  4.467782
#
#         geo_y
# 27  51.923861
#     id                           name                      geometry     geo_x  \
# 28  28  Rotterdam, Rotterdam Centraal  POINT (4.4678361 51.9236014)  4.467836
#
#         geo_y
# 28  51.923601
#     id                       name                     geometry     geo_x  \
# 20  20  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 20  51.887005
#     id                                name                    geometry  \
# 26  26  Schiedam, Station Schiedam Centrum  POINT (4.40766 51.9216446)
#
#       geo_x      geo_y
# 26  4.40766  51.921645
#     id                name                      geometry     geo_x      geo_y
# 23  23  Schiedam, Harreweg  POINT (4.3749283 51.9442744)  4.374928  51.944274
#   id                                name                    geometry    geo_x  \
# 5  5  Schiedam, Station Schiedam Centrum  POINT (4.40766 51.9216446)  4.40766
#
#        geo_y
# 5  51.921645
#   id                name                      geometry     geo_x      geo_y
# 7  7  Schiedam, Harreweg  POINT (4.3749283 51.9442744)  4.374928  51.944274
#   id                                name                    geometry    geo_x  \
# 9  9  Schiedam, Station Schiedam Centrum  POINT (4.40766 51.9216446)  4.40766
#
#        geo_y
# 9  51.921645
#     id                                name                      geometry  \
# 10  10  Schiedam, Station Schiedam Centrum  POINT (4.4090742 51.9213762)
#
#        geo_x      geo_y
# 10  4.409074  51.921376
#     id                                name                     geometry  \
# 11  11  Schiedam, Station Schiedam Centrum  POINT (4.408814 51.9213724)
#
#        geo_x      geo_y
# 11  4.408814  51.921372
#   id                                name                    geometry    geo_x  \
# 9  9  Schiedam, Station Schiedam Centrum  POINT (4.40766 51.9216446)  4.40766
#
#        geo_y
# 9  51.921645
#   id                                name                      geometry  \
# 7  7  Rotterdam, Sleephellingstraat Zuid  POINT (4.4921701 51.9107843)
#
#      geo_x      geo_y
# 7  4.49217  51.910784
#     id                             name                      geometry  \
# 53  53  Vlaardingen, Begraafplaats Holy  POINT (4.3359951 51.9378332)
#
#        geo_x      geo_y
# 53  4.335995  51.937833
#     id                                   name                      geometry  \
# 52  52  Vlaardingen, Station Vlaardingen West  POINT (4.3149703 51.9044683)
#
#       geo_x      geo_y
# 52  4.31497  51.904468
#     id                     name                     geometry     geo_x  \
# 13  13  Rotterdam, Slinge Metro  POINT (4.478188 51.8743719)  4.478188
#
#         geo_y
# 13  51.874372
#     id                     name                      geometry     geo_x  \
# 15  15  Rotterdam, Slinge Metro  POINT (4.4780762 51.8746273)  4.478076
#
#         geo_y
# 15  51.874627
#     id                     name                      geometry     geo_x  \
# 25  25  Rotterdam, Slinge Metro  POINT (4.4769271 51.8740373)  4.476927
#
#         geo_y
# 25  51.874037
#     id                     name                      geometry     geo_x  \
# 26  26  Rotterdam, Slinge Metro  POINT (4.4771434 51.8738897)  4.477143
#
#        geo_y
# 26  51.87389
#     id               name                      geometry     geo_x      geo_y
# 26  26  Rhoon, Kwartslaan  POINT (4.4833223 51.8535285)  4.483322  51.853529
#     id               name                      geometry     geo_x      geo_y
# 27  27  Rhoon, Kwartslaan  POINT (4.4839475 51.8532991)  4.483948  51.853299
#     id                          name                      geometry     geo_x  \
# 35  35  Poortugaal, Poortugaal Metro  POINT (4.3956379 51.8613193)  4.395638
#
#         geo_y
# 35  51.861319
#     id                              name                      geometry  \
# 35  35  Barendrecht, Station Barendrecht  POINT (4.5516312 51.8547407)
#
#        geo_x      geo_y
# 35  4.551631  51.854741
#     id                              name                      geometry  \
# 46  46  Barendrecht, Station Barendrecht  POINT (4.5531322 51.8536107)
#
#        geo_x      geo_y
# 46  4.553132  51.853611
#     id                         name                      geometry     geo_x  \
# 31  31  Barendrecht, Vrijheidsakker  POINT (4.4886559 51.8596416)  4.488656
#
#         geo_y
# 31  51.859642
#     id                         name                     geometry    geo_x  \
# 45  45  Barendrecht, Vrijheidsakker  POINT (4.4887797 51.860685)  4.48878
#
#         geo_y
# 45  51.860685
#     id                                     name                      geometry  \
# 32  32  Capelle aan den IJssel, Capelle Centrum  POINT (4.5905636 51.9319109)
#
#        geo_x      geo_y
# 32  4.590564  51.931911
#     id                                     name                      geometry  \
# 33  33  Capelle aan den IJssel, Capelle Centrum  POINT (4.5904339 51.9320735)
#
#        geo_x      geo_y
# 33  4.590434  51.932074
#     id                                     name                      geometry  \
# 34  34  Capelle aan den IJssel, Capelle Centrum  POINT (4.5905636 51.9319109)
#
#        geo_x      geo_y
# 34  4.590564  51.931911
#     id                                     name                      geometry  \
# 35  35  Capelle aan den IJssel, Capelle Centrum  POINT (4.5904339 51.9320735)
#
#        geo_x      geo_y
# 35  4.590434  51.932074
#     id                          name                      geometry     geo_x  \
# 28  28  Rotterdam, Capelsebrug Metro  POINT (4.5588845 51.9211893)  4.558884
#
#         geo_y
# 28  51.921189
#     id                                     name                      geometry  \
# 29  29  Capelle aan den IJssel, Capelle Centrum  POINT (4.5905636 51.9319109)
#
#        geo_x      geo_y
# 29  4.590564  51.931911
#     id                                     name                      geometry  \
# 30  30  Capelle aan den IJssel, Capelle Centrum  POINT (4.5904339 51.9320735)
#
#        geo_x      geo_y
# 30  4.590434  51.932074
#     id                              name                      geometry  \
# 56  56  Barendrecht, Station Barendrecht  POINT (4.5517251 51.8547459)
#
#        geo_x      geo_y
# 56  4.551725  51.854746
#     id                   name                      geometry     geo_x  \
# 55  55  Ridderkerk, Olmenlaan  POINT (4.5842576 51.8740566)  4.584258
#
#         geo_y
# 55  51.874057
#     id                    name                      geometry     geo_x  \
# 56  56  Slikkerveer, De Schans  POINT (4.6173386 51.8864309)  4.617339
#
#         geo_y
# 56  51.886431
#     id                              name                      geometry  \
# 47  47  Barendrecht, Station Barendrecht  POINT (4.5517251 51.8547459)
#
#        geo_x      geo_y
# 47  4.551725  51.854746
#     id                                  name                     geometry  \
# 37  37  Hoogvliet Rotterdam, Hoogvliet Metro  POINT (4.366064 51.8607875)
#
#        geo_x      geo_y
# 37  4.366064  51.860788
#     id                                  name                      geometry  \
# 38  38  Hoogvliet Rotterdam, Hoogvliet Metro  POINT (4.3661088 51.8608415)
#
#        geo_x      geo_y
# 38  4.366109  51.860841
#     id                                  name                      geometry  \
# 60  60  Hoogvliet Rotterdam, Hoogvliet Metro  POINT (4.3663864 51.8609357)
#
#        geo_x      geo_y
# 60  4.366386  51.860936
#     id                      name                     geometry     geo_x  \
# 15  15  Ridderkerk, Koningsplein  POINT (4.600817 51.8708585)  4.600817
#
#         geo_y
# 15  51.870858
#     id                      name                      geometry     geo_x  \
# 18  18  Ridderkerk, Koningsplein  POINT (4.6007545 51.8709185)  4.600754
#
#         geo_y
# 18  51.870919
#     id                              name                      geometry  \
# 18  18  Barendrecht, Station Barendrecht  POINT (4.5517251 51.8547459)
#
#        geo_x      geo_y
# 18  4.551725  51.854746
#     id               name                      geometry   geo_x      geo_y
# 47  47  Rhoon, Overhoeken  POINT (4.4331001 51.8606157)  4.4331  51.860616
#     id                          name                      geometry     geo_x  \
# 40  40  Poortugaal, Poortugaal Metro  POINT (4.3956379 51.8613193)  4.395638
#
#         geo_y
# 40  51.861319
#     id                                  name                      geometry  \
# 36  36  Hoogvliet Rotterdam, Hoogvliet Metro  POINT (4.3660178 51.8607373)
#
#        geo_x      geo_y
# 36  4.366018  51.860737
#     id                                  name                     geometry  \
# 37  37  Hoogvliet Rotterdam, Hoogvliet Metro  POINT (4.366064 51.8607875)
#
#        geo_x      geo_y
# 37  4.366064  51.860788
#     id                                  name                      geometry  \
# 59  59  Hoogvliet Rotterdam, Hoogvliet Metro  POINT (4.3663864 51.8609357)
#
#        geo_x      geo_y
# 59  4.366386  51.860936
#     id                                  name                      geometry  \
# 11  11  Hoogvliet Rotterdam, Hoogvliet Metro  POINT (4.3661088 51.8608415)
#
#        geo_x      geo_y
# 11  4.366109  51.860841
#     id                                  name                     geometry  \
# 12  12  Hoogvliet Rotterdam, Hoogvliet Metro  POINT (4.366141 51.8608928)
#
#        geo_x      geo_y
# 12  4.366141  51.860893
#     id                                  name                      geometry  \
# 24  24  Hoogvliet Rotterdam, Hoogvliet Metro  POINT (4.3663864 51.8609357)
#
#        geo_x      geo_y
# 24  4.366386  51.860936
#   id                          name                      geometry     geo_x  \
# 6  6  Poortugaal, Poortugaal Metro  POINT (4.3956379 51.8613193)  4.395638
#
#        geo_y
# 6  51.861319
#     id                          name                      geometry     geo_x  \
# 15  15  Poortugaal, Poortugaal Metro  POINT (4.3964862 51.8598555)  4.396486
#
#         geo_y
# 15  51.859856
#     id       name                     geometry     geo_x      geo_y
# 12  12  Damstraat  POINT (4.507475 51.9084554)  4.507475  51.908455
#   id                       name                     geometry     geo_x  \
# 9  9  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#        geo_y
# 9  51.887005
#     id                           name                     geometry     geo_x  \
# 12  12  Rotterdam, Nieuw-Vossemeerweg  POINT (4.465237 51.8694297)  4.465237
#
#        geo_y
# 12  51.86943
#   id                       name                     geometry     geo_x  \
# 9  9  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#        geo_y
# 9  51.887005
#     id                   name                    geometry    geo_x      geo_y
# 29  29  Rotterdam, RDM Campus  POINT (4.42055 51.8964408)  4.42055  51.896441
#     id                       name                     geometry     geo_x  \
# 17  17  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 17  51.887005
#     id                            name                      geometry  \
# 27  27  Pernis Rotterdam, Pernis Metro  POINT (4.3818714 51.8852036)
#
#        geo_x      geo_y
# 27  4.381871  51.885204
#     id                       name                     geometry     geo_x  \
# 23  23  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 23  51.887005
#     id                     name                      geometry    geo_x  \
# 36  36  Rotterdam, Keizerswaard  POINT (4.5484099 51.8856617)  4.54841
#
#         geo_y
# 36  51.885662
#     id                     name                      geometry     geo_x  \
# 37  37  Rotterdam, Keizerswaard  POINT (4.5479311 51.8856622)  4.547931
#
#         geo_y
# 37  51.885662
#     id                     name                      geometry     geo_x  \
# 49  49  Rotterdam, Keizerswaard  POINT (4.5489717 51.8872989)  4.548972
#
#         geo_y
# 49  51.887299
#     id                            name                      geometry  \
# 57  57  Rotterdam, Garage Sluisjesdijk  POINT (4.4610736 51.8942826)
#
#        geo_x      geo_y
# 57  4.461074  51.894283
#     id                       name                     geometry     geo_x  \
# 20  20  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 20  51.887005
#     id                            name                      geometry  \
# 27  27  Rotterdam, Willem Egmondstraat  POINT (4.4399733 51.8981724)
#
#        geo_x      geo_y
# 27  4.439973  51.898172
#   id                       name                     geometry     geo_x  \
# 8  8  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#        geo_y
# 8  51.887005
#     id                       name                      geometry     geo_x  \
# 13  13  Rotterdam, Kralingse Zoom  POINT (4.5327285 51.9217497)  4.532729
#
#        geo_y
# 13  51.92175
#     id                       name                     geometry     geo_x  \
# 19  19  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 19  51.887005
#     id                     name                      geometry     geo_x  \
# 27  27  Rotterdam, Keizerswaard  POINT (4.5489717 51.8872989)  4.548972
#
#         geo_y
# 27  51.887299
#     id          name                      geometry     geo_x      geo_y
# 11  11  SS Rotterdam  POINT (4.4763844 51.8981963)  4.476384  51.898196
#     id                       name                     geometry     geo_x  \
# 15  15  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 15  51.887005
#     id                        name                      geometry    geo_x  \
# 20  20  Poortugaal, De Kijvelanden  POINT (4.3886401 51.8462278)  4.38864
#
#         geo_y
# 20  51.846228
#   id              name                      geometry     geo_x      geo_y
# 5  5  Poortugaal Metro  POINT (4.3956568 51.8613541)  4.395657  51.861354
#     id                       name                     geometry     geo_x  \
# 19  19  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 19  51.887005
#     id                     name                      geometry     geo_x  \
# 11  11  Rotterdam, Keizerswaard  POINT (4.5489717 51.8872989)  4.548972
#
#         geo_y
# 11  51.887299
#   id                       name                      geometry     geo_x  \
# 8  8  Rotterdam, Kralingse Zoom  POINT (4.5327285 51.9217497)  4.532729
#
#       geo_y
# 8  51.92175
#     id                              name                      geometry  \
# 48  48  Barendrecht, Station Barendrecht  POINT (4.5518348 51.8547553)
#
#        geo_x      geo_y
# 48  4.551835  51.854755
#     id                              name                      geometry  \
# 52  52  Barendrecht, Station Barendrecht  POINT (4.5531322 51.8536107)
#
#        geo_x      geo_y
# 52  4.553132  51.853611
#     id                       name                     geometry     geo_x  \
# 30  30  Rotterdam, Zuidplein Hoog  POINT (4.488119 51.8870046)  4.488119
#
#         geo_y
# 30  51.887005
#     id                          name                      geometry     geo_x  \
# 10  10  Rotterdam, Capelsebrug Metro  POINT (4.5588845 51.9211893)  4.558884
#
#         geo_y
# 10  51.921189
#     id                         name                      geometry     geo_x  \
# 30  30  Rotterdam, Capelsebrug Hoog  POINT (4.5575924 51.9210525)  4.557592
#
#         geo_y
# 30  51.921053
#     id                         name                      geometry     geo_x  \
# 31  31  Rotterdam, Capelsebrug Hoog  POINT (4.5578975 51.9211507)  4.557898
#
#         geo_y
# 31  51.921151
#     id                         name                      geometry     geo_x  \
# 32  32  Rotterdam, Capelsebrug Hoog  POINT (4.5571963 51.9209242)  4.557196
#
#         geo_y
# 32  51.920924
#     id                         name                      geometry     geo_x  \
# 33  33  Rotterdam, Capelsebrug Hoog  POINT (4.5569058 51.9208259)  4.556906
#
#         geo_y
# 33  51.920826
#     id                                    name                      geometry  \
# 20  20  Krimpen aan den IJssel, Van Ostadelaan  POINT (4.5995715 51.9083574)
#
#        geo_x      geo_y
# 20  4.599571  51.908357

# %%
city_bus_order_id_pairs = id_pairs_inline(city_bus_line_dict,city_bus_stations_inline, nodes)

# %%
G = create_ground_graph(edges, nodes)


city_bus_shortest_path_pairs = city_bus_order_id_pairs.copy()

city_bus_duplicate_row_count = city_bus_order_id_pairs.copy()

city_bus_shortest_path_edges = city_bus_order_id_pairs.copy()

city_bus_edges = city_bus_order_id_pairs.copy()

for line in city_bus_order_id_pairs.keys():
    
    city_bus_shortest_path_pairs[line] = all_shortest_paths(G, city_bus_order_id_pairs[line],edges)

# %%
empty_keys = []
for key, value in city_bus_shortest_path_pairs.items():
    if value is None:
        empty_keys.append(key)

print(empty_keys)
# Out:
# []

# %%
city_bus_shortest_path_pairs['Bus 30: Capelle Schollevaar => Rotterdam Station Alexander']
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
city_bus_shortest_path_pairs['Bus 36: Rotterdam Station Alexander => Rotterdam Kralingse Zoom']
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
city_bus_shortest_path_pairs
# Out:
# {'Bus 126: Maassluis West => Schiedam Centrum':             osm_id                                           geometry  \
#  22027      7533084  LINESTRING (4.4063871 51.9219505, 4.406766 51....
#  39894     48275863  LINESTRING (4.4033065 51.9227802, 4.4034417 51...
#  103476   520548832  LINESTRING (4.4027375 51.9214414, 4.4027841 51...
#  103478   520548833  LINESTRING (4.4026187 51.9212013, 4.4026684 51...
#  103479   520549217  LINESTRING (4.4029344 51.9218933, 4.4032079 51...
#  124342   729551878  LINESTRING (4.4049476 51.9223364, 4.4058381 51...
#  124343   729551878  LINESTRING (4.4059931 51.922052, 4.4063871 51....
#  124347   729665620  LINESTRING (4.406766 51.9218573, 4.40766 51.92...
#  39160     47272538  LINESTRING (4.4022857 51.9195074, 4.402264 51....
#  42140     64194434  LINESTRING (4.4022934 51.9194298, 4.4022857 51...
#  78633    299349714  LINESTRING (4.5371503 51.911592, 4.5375151 51....
#  91719    413670972  LINESTRING (4.5420148 51.9046341, 4.5429314 51...
#  91720    413670973  LINESTRING (4.5417446 51.9050158, 4.5420148 51...
#  100421   487805985  LINESTRING (4.5488177 51.8968981, 4.5487476 51...
#  125459   741676698  LINESTRING (4.5429314 51.9033389, 4.5437917 51...
#  127388   763194611  LINESTRING (4.545124 51.8977958, 4.5451662 51....
#  157223  1144818732  LINESTRING (4.5282028 51.9137148, 4.5283951 51...
#  161279  1168323085  LINESTRING (4.5462845 51.8967191, 4.5461268 51...
#
#                highway      id  from_id   to_id    distance      time  weights  \
#  6357     unclassified    6357     5723    5724   97.024192  0.004851       97
#  76506    unclassified   76506     5724    5710   69.868413  0.003493       69
#  76507    unclassified   76507     5710   71867   34.448116  0.001722       34
#  92523    unclassified   92523    71867   88088   42.369080  0.002118       42
#  103791   unclassified  103791   163731   99274   53.327726  0.002666       53
#  126384   unclassified  126384    99274    5723   15.438124  0.000772       15
#  5791        secondary    5791   161100    6555   66.955070  0.003348       66
#  5792        secondary    5792     6555    5270  137.374318  0.006869      137
#  6990           busway    6990     6314  160901   95.977527  0.004799       95
#  7024    motorway_link    7024     6359    6360   65.769374  0.003288       65
#  7025    motorway_link    7025     6361    6362  139.558932  0.006978      139
#  7026    motorway_link    7026     6363    6364  175.029395  0.008751      175
#  7031    motorway_link    7031     6368    6361   16.179054  0.000809       16
#  7314        secondary    7314     6562   35540   17.636596  0.000882       17
#  7317        secondary    7317     6565    6566   14.430982  0.000722       14
#  39704    primary_link   39704    35540    5270    8.639570  0.000432        8
#  41389        motorway   41389    37885   37886  503.953662  0.025198      503
#  43235       secondary   43235     6566    6562   54.652917  0.002733       54
#  44167    primary_link   44167     6565   40579   23.587825  0.001179       23
#  44169        motorway   44169    40582    6363   32.855340  0.001643       32
#  52603        motorway   52603    48611   37885   95.937563  0.004797       95
#  52666        motorway   52666    48688   40582  482.065633  0.024103      482
#  67235          busway   67235    62346   39835  461.325193  0.023066      461
#  76519   motorway_link   76519    39835   71873  170.127003  0.008506      170
#  78632   motorway_link   78632    71873   77552  127.381420  0.006369      127
#  78633   motorway_link   78633    77552   48611  197.040935  0.009852      197
#  91719        motorway   91719    87391   87392  157.272876  0.007864      157
#  91720        motorway   91720    37886   87391   46.350795  0.002318       46
#  100421  motorway_link  100421     6364    6359  118.036429  0.005902      118
#  125459       motorway  125459    87392   48688  150.191100  0.007510      150
#  127388  motorway_link  127388     6362    6314   14.988640  0.000749       14
#  157223         busway  157223    40579   62346   15.906127  0.000795       15
#  161279  motorway_link  161279     6360    6368   11.021891  0.000551       11
#
#                  to_from          from_to
#  6357       (5723, 5724)     (5724, 5723)
#  76506      (5724, 5710)     (5710, 5724)
#  76507     (5710, 71867)    (71867, 5710)
#  92523    (71867, 88088)   (88088, 71867)
#  103791  (163731, 99274)  (99274, 163731)
#  126384    (99274, 5723)    (5723, 99274)
#  5791     (161100, 6555)   (6555, 161100)
#  5792       (6555, 5270)     (5270, 6555)
#  6990     (6314, 160901)   (160901, 6314)
#  7024       (6359, 6360)     (6360, 6359)
#  7025       (6361, 6362)     (6362, 6361)
#  7026       (6363, 6364)     (6364, 6363)
#  7031       (6368, 6361)     (6361, 6368)
#  7314      (6562, 35540)    (35540, 6562)
#  7317       (6565, 6566)     (6566, 6565)
#  39704     (35540, 5270)    (5270, 35540)
#  41389    (37885, 37886)   (37886, 37885)
#  43235      (6566, 6562)     (6562, 6566)
#  44167     (6565, 40579)    (40579, 6565)
#  44169     (40582, 6363)    (6363, 40582)
#  52603    (48611, 37885)   (37885, 48611)
#  52666    (48688, 40582)   (40582, 48688)
#  67235    (62346, 39835)   (39835, 62346)
#  76519    (39835, 71873)   (71873, 39835)
#  78632    (71873, 77552)   (77552, 71873)
#  78633    (77552, 48611)   (48611, 77552)
#  91719    (87391, 87392)   (87392, 87391)
#  91720    (37886, 87391)   (87391, 37886)
#  100421     (6364, 6359)     (6359, 6364)
#  125459   (87392, 48688)   (48688, 87392)
#  127388     (6362, 6314)     (6314, 6362)
#  157223   (40579, 62346)   (62346, 40579)
#  161279     (6360, 6368)     (6368, 6360)  ,
#  'Bus 140: Slikkerveer Dillenburgplein => Rotterdam Kralingse Zoom':            osm_id                                           geometry  \
#  103788  525204698  LINESTRING (4.607836 51.8818742, 4.6077279 51....
#  103789  525204698  LINESTRING (4.6074034 51.8821562, 4.6071762 51...
#  103790  525204698  LINESTRING (4.6068286 51.8825525, 4.6067423 51...
#  141884  982886028  LINESTRING (4.6033405 51.87898, 4.6036146 51.8...
#  141885  982886028  LINESTRING (4.6039892 51.8794064, 4.6040936 51...
#  141886  982886028  LINESTRING (4.6040936 51.8794735, 4.604826 51....
#  6357      7322426  LINESTRING (4.6063082 51.8832146, 4.6060496 51...
#  76506   269942994  LINESTRING (4.6057053 51.884003, 4.6056788 51....
#  76507   269942994  LINESTRING (4.60526 51.8845674, 4.6052174 51.8...
#  92523   424481872  LINESTRING (4.6050497 51.8848484, 4.6048545 51...
#  103791  525204698  LINESTRING (4.6067423 51.8826579, 4.606712 51....
#  126384  749068454  LINESTRING (4.6064073 51.8830901, 4.6063082 51...
#
#               highway      id  from_id   to_id    distance      time  weights  \
#  103788  unclassified  103788    99273  163732   43.254025  0.002163       43
#  103789  unclassified  103789   163732   71741   59.365040  0.002968       59
#  103790  unclassified  103790    71741  163731   13.143683  0.000657       13
#  141884  unclassified  141884   162851  163730   65.153853  0.003258       65
#  141885  unclassified  141885   163730   99254   10.361983  0.000518       10
#  141886  unclassified  141886    99254   99273  371.069289  0.018553      371
#  6357    unclassified    6357     5723    5724   97.024192  0.004851       97
#  76506   unclassified   76506     5724    5710   69.868413  0.003493       69
#  76507   unclassified   76507     5710   71867   34.448116  0.001722       34
#  92523   unclassified   92523    71867   88088   42.369080  0.002118       42
#  103791  unclassified  103791   163731   99274   53.327726  0.002666       53
#  126384  unclassified  126384    99274    5723   15.438124  0.000772       15
#
#                   to_from           from_to
#  103788   (99273, 163732)   (163732, 99273)
#  103789   (163732, 71741)   (71741, 163732)
#  103790   (71741, 163731)   (163731, 71741)
#  141884  (162851, 163730)  (163730, 162851)
#  141885   (163730, 99254)   (99254, 163730)
#  141886    (99254, 99273)    (99273, 99254)
#  6357        (5723, 5724)      (5724, 5723)
#  76506       (5724, 5710)      (5710, 5724)
#  76507      (5710, 71867)     (71867, 5710)
#  92523     (71867, 88088)    (88088, 71867)
#  103791   (163731, 99274)   (99274, 163731)
#  126384     (99274, 5723)     (5723, 99274)  ,
#  'Bus 142: Slikkerveer Sporttunnel => Rotterdam Zuidplein':             osm_id                                           geometry  \
#  18911      7512763  LINESTRING (4.4915151 51.8850126, 4.4914496 51...
#  44561     88432502  LINESTRING (4.4919345 51.8850267, 4.4919 51.88...
#  61644    150619266  LINESTRING (4.4914496 51.8849914, 4.4913767 51...
#  61646    150638751  LINESTRING (4.4875884 51.8846005, 4.4875868 51...
#  102118   502645551  LINESTRING (4.4988998 51.8824401, 4.4985384 51...
#  ...            ...                                                ...
#  128968   785363479  LINESTRING (4.5963493 51.8771313, 4.5971302 51...
#  128969   785363480  LINESTRING (4.5974007 51.877677, 4.5981919 51....
#  141883   982886028  LINESTRING (4.602167 51.8779919, 4.6022069 51....
#  141884   982886028  LINESTRING (4.6033405 51.87898, 4.6036146 51.8...
#  144158  1019448731  LINESTRING (4.5961121 51.8770125, 4.5963493 51...
#
#               highway      id  from_id   to_id    distance      time  weights  \
#  18911      secondary   18911    17411   17412    5.088169  0.000254        5
#  44561      secondary   44561    17420   17411   29.288702  0.001464       29
#  61644      secondary   61644    17412   56716   34.185687  0.001709       34
#  61646         busway   61646    17399  163709   29.215725  0.001461       29
#  102118         trunk  102118    97553   97554  258.043013  0.012902      258
#  ...              ...     ...      ...     ...         ...       ...      ...
#  128968      tertiary  128968   121686    5690   70.222186  0.003511       70
#  128969      tertiary  128969     5691    5688   70.844266  0.003542       70
#  141883  unclassified  141883    36286  162851  136.984323  0.006849      136
#  141884  unclassified  141884   162851  163730   65.153853  0.003258       65
#  144158      tertiary  144158   137143  121686   21.007932  0.001050       21
#
#                   to_from           from_to
#  18911     (17411, 17412)    (17412, 17411)
#  44561     (17420, 17411)    (17411, 17420)
#  61644     (17412, 56716)    (56716, 17412)
#  61646    (17399, 163709)   (163709, 17399)
#  102118    (97553, 97554)    (97554, 97553)
#  ...                  ...               ...
#  128968    (121686, 5690)    (5690, 121686)
#  128969      (5691, 5688)      (5688, 5691)
#  141883   (36286, 162851)   (162851, 36286)
#  141884  (162851, 163730)  (163730, 162851)
#  144158  (137143, 121686)  (121686, 137143)
#
#  [76 rows x 11 columns],
#  'Bus 142: Rotterdam Zuidplein => Slikkerveer Sporttunnel':             osm_id                                           geometry  \
#  103788   525204698  LINESTRING (4.607836 51.8818742, 4.6077279 51....
#  103789   525204698  LINESTRING (4.6074034 51.8821562, 4.6071762 51...
#  103790   525204698  LINESTRING (4.6068286 51.8825525, 4.6067423 51...
#  141884   982886028  LINESTRING (4.6033405 51.87898, 4.6036146 51.8...
#  141885   982886028  LINESTRING (4.6039892 51.8794064, 4.6040936 51...
#  ...            ...                                                ...
#  149851  1075480173  LINESTRING (4.4885658 51.8846861, 4.4885933 51...
#  153148  1103306440  LINESTRING (4.4885611 51.8847576, 4.4885658 51...
#  153150  1103306443  LINESTRING (4.4888165 51.88444, 4.4889772 51.8...
#  162759  1175138306  LINESTRING (4.4886203 51.8854195, 4.4885574 51...
#  162761  1175138308  LINESTRING (4.4882398 51.8863472, 4.4882017 51...
#
#               highway      id  from_id   to_id   distance      time  weights  \
#  103788  unclassified  103788    99273  163732  43.254025  0.002163       43
#  103789  unclassified  103789   163732   71741  59.365040  0.002968       59
#  103790  unclassified  103790    71741  163731  13.143683  0.000657       13
#  141884  unclassified  141884   162851  163730  65.153853  0.003258       65
#  141885  unclassified  141885   163730   99254  10.361983  0.000518       10
#  ...              ...     ...      ...     ...        ...       ...      ...
#  149851  unclassified  149851    56694  115637  33.017803  0.001651       33
#  153148  unclassified  153148   132051   56694   7.959880  0.000398        7
#  153150     secondary  153150   115637  115631  20.563255  0.001028       20
#  162759  unclassified  162759   132049  132050  14.318827  0.000716       14
#  162761        busway  162761    66016   17406   9.865553  0.000493        9
#
#                   to_from           from_to
#  103788   (99273, 163732)   (163732, 99273)
#  103789   (163732, 71741)   (71741, 163732)
#  103790   (71741, 163731)   (163731, 71741)
#  141884  (162851, 163730)  (163730, 162851)
#  141885   (163730, 99254)   (99254, 163730)
#  ...                  ...               ...
#  149851   (56694, 115637)   (115637, 56694)
#  153148   (132051, 56694)   (56694, 132051)
#  153150  (115637, 115631)  (115631, 115637)
#  162759  (132049, 132050)  (132050, 132049)
#  162761    (66016, 17406)    (17406, 66016)
#
#  [69 rows x 11 columns],
#  'Bus 142: Slikkerveer Dillenburgplein => Rotterdam Zuidplein':             osm_id                                           geometry  \
#  18911      7512763  LINESTRING (4.4915151 51.8850126, 4.4914496 51...
#  44561     88432502  LINESTRING (4.4919345 51.8850267, 4.4919 51.88...
#  61644    150619266  LINESTRING (4.4914496 51.8849914, 4.4913767 51...
#  61646    150638751  LINESTRING (4.4875884 51.8846005, 4.4875868 51...
#  102118   502645551  LINESTRING (4.4988998 51.8824401, 4.4985384 51...
#  118155   681382458  LINESTRING (4.4927243 51.8847411, 4.4925054 51...
#  121904   706076943  LINESTRING (4.5003939 51.8813366, 4.4998929 51...
#  121916   706080168  LINESTRING (4.493938 51.8842707, 4.4935654 51....
#  121917   706080170  LINESTRING (4.4958108 51.8837108, 4.4954828 51...
#  121918   706080170  LINESTRING (4.4954828 51.8838064, 4.4949383 51...
#  121919   706080170  LINESTRING (4.494222 51.8841872, 4.493938 51.8...
#  121920   706080933  LINESTRING (4.4909987 51.8848631, 4.4905852 51...
#  121921   706080934  LINESTRING (4.4896597 51.8846539, 4.4890968 51...
#  121923   706080938  LINESTRING (4.4900594 51.8846937, 4.4899058 51...
#  161011  1165338331  LINESTRING (4.4899058 51.8846784, 4.4896597 51...
#  7532       7330931  LINESTRING (4.5104149 51.8756502, 4.5085323 51...
#  128387    (60485, 58822)    (58822, 60485)  ,
#  'Bus 142: Rotterdam Zuidplein => Slikkerveer Dillenburgplein':             osm_id                                           geometry  \
#  6357       7322426  LINESTRING (4.6063082 51.8832146, 4.6060496 51...
#  76506    269942994  LINESTRING (4.6057053 51.884003, 4.6056788 51....
#  76507    269942994  LINESTRING (4.60526 51.8845674, 4.6052174 51.8...
#  92523    424481872  LINESTRING (4.6050497 51.8848484, 4.6048545 51...
#  103791   525204698  LINESTRING (4.6067423 51.8826579, 4.606712 51....
#  ...            ...                                                ...
#  149851  1075480173  LINESTRING (4.4885658 51.8846861, 4.4885933 51...
#  153148  1103306440  LINESTRING (4.4885611 51.8847576, 4.4885658 51...
#  153150  1103306443  LINESTRING (4.4888165 51.88444, 4.4889772 51.8...
#  162759  1175138306  LINESTRING (4.4886203 51.8854195, 4.4885574 51...
#  162761  1175138308  LINESTRING (4.4882398 51.8863472, 4.4882017 51...
#
#               highway      id  from_id   to_id   distance      time  weights  \
#  6357    unclassified    6357     5723    5724  97.024192  0.004851       97
#  76506   unclassified   76506     5724    5710  69.868413  0.003493       69
#  76507   unclassified   76507     5710   71867  34.448116  0.001722       34
#  92523   unclassified   92523    71867   88088  42.369080  0.002118       42
#  103791  unclassified  103791   163731   99274  53.327726  0.002666       53
#  ...              ...     ...      ...     ...        ...       ...      ...
#  149851  unclassified  149851    56694  115637  33.017803  0.001651       33
#  153148  unclassified  153148   132051   56694   7.959880  0.000398        7
#  153150     secondary  153150   115637  115631  20.563255  0.001028       20
#  162759  unclassified  162759   132049  132050  14.318827  0.000716       14
#  162761        busway  162761    66016   17406   9.865553  0.000493        9
#
#                   to_from           from_to
#  6357        (5723, 5724)      (5724, 5723)
#  76506       (5724, 5710)      (5710, 5724)
#  76507      (5710, 71867)     (71867, 5710)
#  92523     (71867, 88088)    (88088, 71867)
#  103791   (163731, 99274)   (99274, 163731)
#  ...                  ...               ...
#  149851   (56694, 115637)   (115637, 56694)
#  153148   (132051, 56694)   (56694, 132051)
#  153150  (115637, 115631)  (115631, 115637)
#  162759  (132049, 132050)  (132050, 132049)
#  162761    (66016, 17406)    (17406, 66016)
#
#  [63 rows x 11 columns],
#  'Bus 143: Ridderkerk Drievliet => Rotterdam Zuidplein':            osm_id                                           geometry  \
#  18911     7512763  LINESTRING (4.4915151 51.8850126, 4.4914496 51...
#  44561    88432502  LINESTRING (4.4919345 51.8850267, 4.4919 51.88...
#  61644   150619266  LINESTRING (4.4914496 51.8849914, 4.4913767 51...
#  61646   150638751  LINESTRING (4.4875884 51.8846005, 4.4875868 51...
# ...
#  6609       7324369  LINESTRING (4.5760795 51.9065347, 4.5754 51.90...
#  6610       7324369  LINESTRING (4.5754 51.9070771, 4.5744361 51.90...
#  6611       7324369  LINESTRING (4.5744361 51.9078535, 4.5740503 51...
#  6573       7324264  LINESTRING (4.5755664 51.905298, 4.575402 51.9...
#  6575       7324265  LINESTRING (4.5752734 51.9050339, 4.5751694 51...
#  48741        service   48741    44840   44841   33.646017  0.001682       33
#  48742   unclassified   48742     5962    5984  112.365760  0.005618      112
#  6595    unclassified    6595     5779  163446   50.172674  0.002509       50
#  6606        tertiary    6606   163441    5779  158.343518  0.007917      158
#  6402        tertiary    6402     5779    5780  104.526517  0.005226      104
#  6458        tertiary    6458     5855    5856   37.138969  0.001857       37
#  6461        tertiary    6461     5780  109972    9.284023  0.000464        9
#  6462        tertiary    6462   109972    5855   37.216456  0.001861       37
#  6595    unclassified    6595     5779  163446   50.172674  0.002509       50
#  6596    unclassified    6596   163446    5964  144.411729  0.007221      144
#  6597    unclassified    6597     5964  163445   77.752959  0.003888       77
#  56407        primary   56407    51883   51884   76.063088  0.003803       76
#  88801       tertiary   88801    51884  162948   51.680540  0.002584       51
#  88802       tertiary   88802   162948   84086   62.945673  0.003147       62
#  153609       primary  153609   161558  146516    7.725304  0.000386        7
#  153610       primary  153610   146516  146517   24.445695  0.001222       24
#  153611       primary  153611   146517   51883   99.720868  0.004986       99
#  153613      tertiary  153613    84086  146518   57.745062  0.002887       57
#  153614      tertiary  153614   146518  115558   53.484857  0.002674       53
#  153617      tertiary  153617   146520   45505   51.350778  0.002568       51
#  153618      tertiary  153618     5870  146520   16.359895  0.000818       16
#  153619      tertiary  153619     5872    5870   33.065392  0.001653       33
#  153620      tertiary  153620     5856    5872   60.383993  0.003019       60
#  153621      tertiary  153621     5864  115558   75.838094  0.003792       75
#  153624      tertiary  153624    45505    5864   48.638214  0.002432       48
#  6485        tertiary    6485   161206    5878  110.177775  0.005509      110
#  56407        primary   56407    51883   51884   76.063088  0.003803       76
#  88803        primary   88803    51884    5878   13.511559  0.000676       13
#  153609       primary  153609   161558  146516    7.725304  0.000386        7
#  153610       primary  153610   146516  146517   24.445695  0.001222       24
#  153611       primary  153611   146517   51883   99.720868  0.004986       99
#
#                   to_from           from_to
#  40662     (37163, 37164)    (37164, 37163)
#  46225      (37163, 4300)     (4300, 37163)
#  6599      (5977, 163444)    (163444, 5977)
#  6608      (163443, 5944)    (5944, 163443)
#  6609        (5944, 5942)      (5942, 5944)
#  6610      (5942, 147485)    (147485, 5942)
#  6611      (147485, 5977)    (5977, 147485)
#  6573       (44841, 5962)     (5962, 44841)
#  6575     (163442, 44840)   (44840, 163442)
#  6607      (5984, 163443)    (163443, 5984)
#  48741     (44840, 44841)    (44841, 44840)
#  48742       (5962, 5984)      (5984, 5962)
#  6595      (5779, 163446)    (163446, 5779)
#  6606      (163441, 5779)    (5779, 163441)
#  6402        (5779, 5780)      (5780, 5779)
#  6458        (5855, 5856)      (5856, 5855)
#  6461      (5780, 109972)    (109972, 5780)
#  6462      (109972, 5855)    (5855, 109972)
#  6595      (5779, 163446)    (163446, 5779)
#  6596      (163446, 5964)    (5964, 163446)
#  6597      (5964, 163445)    (163445, 5964)
#  56407     (51883, 51884)    (51884, 51883)
#  88801    (51884, 162948)   (162948, 51884)
#  88802    (162948, 84086)   (84086, 162948)
#  153609  (161558, 146516)  (146516, 161558)
#  4743        (4314, 4304)      (4304, 4314)
#  4744        (4315, 4316)      (4316, 4315)
#  6506        (5897, 5898)      (5898, 5897)
#  41224       (5897, 4223)      (4223, 5897)
#  46196     (42448, 37163)    (37163, 42448)
#  46223      (4305, 42448)     (42448, 4305)
#  46224     (42448, 37163)    (37163, 42448)
#  46225      (37163, 4300)     (4300, 37163)
#  46480      (42698, 4315)     (4315, 42698)
#  88911     (84199, 84200)    (84200, 84199)
#  92520     (88086, 88087)    (88087, 88086)
#  105990  (101095, 101096)  (101096, 101095)
#  110508     (88087, 4228)     (4228, 88087)
#  113457    (4224, 107950)    (107950, 4224)
#  113458  (107950, 107951)  (107951, 107950)
#  115519      (4316, 4314)      (4314, 4316)
#  121774    (84197, 42698)    (42698, 84197)
#  121778   (84197, 115542)   (115542, 84197)
#  121781    (84200, 88086)    (88086, 84200)
#  121782   (115542, 84199)   (84199, 115542)
#  121788    (4230, 115548)    (115548, 4230)
#  121789  (115548, 115549)  (115549, 115548)
#  121793    (115551, 4227)    (4227, 115551)
#  121794    (4227, 115552)    (115552, 4227)
#  121810    (5898, 101095)    (101095, 5898)
#  121812   (51874, 115561)   (115561, 51874)
#  121813   (101096, 51874)   (51874, 101096)
#  121830   (107951, 42135)   (42135, 107951)
#  153608  (115561, 161558)  (161558, 115561)
#  157233   (40946, 115551)   (115551, 40946)
#  157234  (115549, 150173)  (150173, 115549)
#  157235   (150173, 40946)   (40946, 150173)
#  157238   (115552, 42135)   (42135, 115552)  ,
#  'Bus 98: Krimpen aan den IJssel Van Ostadelaan => Krimpen aan den IJssel => Krimpen aan den IJssel Van Ostadelaan': Empty DataFrame
#  Columns: []
#  Index: []}

# %%
G = create_ground_graph(edges, nodes)


city_bus_shortest_path_pairs = city_bus_order_id_pairs.copy()

city_bus_duplicate_row_count = city_bus_order_id_pairs.copy()

city_bus_shortest_path_edges = city_bus_order_id_pairs.copy()

city_bus_edges = city_bus_order_id_pairs.copy()

for line in city_bus_order_id_pairs.keys():
    
    city_bus_shortest_path_pairs[line] = all_shortest_paths(G, city_bus_order_id_pairs[line],edges)
    
    city_bus_duplicate_row_count[line], city_bus_shortest_path_edges[line], city_bus_edges[line] = edges_with_count_weight(city_bus_shortest_path_pairs[line], edges)

# %%
city_bus_order_id_pairs['Bus 30: Capelle Schollevaar => Rotterdam Station Alexander']
# Out:
#       s_id    e_id
# 0   163458  160340
# 1   160340  162316
# 2   162316  156884
# 3   156884  156843
# 4   156843  157527
# 5   157527  157283
# 6   157283  157545
# 7   157545  163456
# 8   163456  157504
# 9   157504  162453
# 10  162453  157537
# 11  157537  157516
# 12  157516  157506
# 13  157506  157265
# 14  157265  163537
# 15  163537  157501

# %%
city_bus_shortest_path_pairs['Bus 30: Capelle Schollevaar => Rotterdam Station Alexander']
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
city_bus_shortest_path_pairs['Bus 30: Capelle Schollevaar => Rotterdam Station Alexander'] = all_shortest_paths(G, city_bus_order_id_pairs['Bus 30: Capelle Schollevaar => Rotterdam Station Alexander'],edges)

# %%
city_bus_shortest_path_pairs['Bus 30: Capelle Schollevaar => Rotterdam Station Alexander']
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
city_bus_start_station_name_dict = start_station_dict(city_bus_routes)

city_bus_line_dict = line_dict(city_bus_routes)

city_bus_all_stations_name = all_station_list(city_bus_stations)

city_bus_order_route_dict = order_stations_inline(city_bus_line_dict,city_bus_all_stations_name,city_bus_routes,city_bus_start_station_name_dict)

city_bus_order_id_pairs = id_pairs_inline(city_bus_line_dict,city_bus_order_route_dict, nodes)


G = create_ground_graph(edges, nodes)


city_bus_shortest_path_pairs = city_bus_order_id_pairs.copy()

city_bus_duplicate_row_count = city_bus_order_id_pairs.copy()

city_bus_shortest_path_edges = city_bus_order_id_pairs.copy()

city_bus_edges = city_bus_order_id_pairs.copy()

for line in city_bus_order_id_pairs.keys():
    
    city_bus_shortest_path_pairs[line] = all_shortest_paths(G, city_bus_order_id_pairs[line],edges)
    
    city_bus_duplicate_row_count[line], city_bus_shortest_path_edges[line], city_bus_edges[line] = edges_with_count_weight(city_bus_shortest_path_pairs[line], edges)

# plot_routes_even(city_bus_routes, edges, city_bus_shortest_path_edges)

# plot_routes_odd(city_bus_routes, edges, city_bus_shortest_path_edges)

plot_routes(city_bus_routes, edges, city_bus_shortest_path_edges)

# %%
city_bus_shortest_path_pairs, city_bus_shortest_path_edges, city_bus_edges = bus(city_bus_stations, edges, nodes, city_bus_routes, city='Rotterdam')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 city_bus_shortest_path_pairs, city_bus_shortest_path_edges, city_bus_edges = bus(city_bus_stations, edges, nodes, city_bus_routes, city='Rotterdam')
#
# File C:\projects\UTNCE\src\utnce\generate.py:224, in bus(city_bus_stations, edges, nodes, city_bus_routes, city)
#     220 city_bus_line_dict = line_dict(city_bus_routes)
#     222 city_bus_all_stations_name = all_station_list(city_bus_stations)
# --> 224 city_bus_order_route_dict = order_stations_inline(city_bus_line_dict,city_bus_all_stations_name,city_bus_routes,city_bus_start_station_name_dict)
#     226 city_bus_order_id_pairs = id_pairs_inline(city_bus_line_dict,city_bus_order_route_dict, nodes)
#     229 G = create_ground_graph(edges, nodes)
#
# File C:\projects\UTNCE\src\utnce\prepare.py:751, in order_stations_inline(tram_line_dict, all_tram_stations_name, tram_routes, tram_start_station_name_dict)
#     749 value1 = value
#     750 # Filter the all_tram_stations_name DataFrame to include only stations within the buffer of the corresponding tram route
# --> 751 value2 = all_tram_stations_name.loc[all_tram_stations_name.within(tram_routes.iloc[value1].geometry.buffer(0.000001))]
#     752 # Assign new IDs to the filtered stations
#     753 value2['id'] = value2.reset_index().index
#
# File ~\Miniconda3\envs\py_s\lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\Miniconda3\envs\py_s\lib\site-packages\pandas\core\indexing.py:1656, in _iLocIndexer._getitem_axis(self, key, axis)
#    1653     raise TypeError("Cannot index by location index with a non-integer key")
#    1655 # validate the location
# -> 1656 self._validate_integer(key, axis)
#    1658 return self.obj._ixs(key, axis=axis)
#
# File ~\Miniconda3\envs\py_s\lib\site-packages\pandas\core\indexing.py:1589, in _iLocIndexer._validate_integer(self, key, axis)
#    1587 len_axis = len(self.obj._get_axis(axis))
#    1588 if key >= len_axis or key < -len_axis:
# -> 1589     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
